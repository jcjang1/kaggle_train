# %% [markdown]
# <a href="https://colab.research.google.com/github/heokwon/i-seg-you/blob/main/fast_ai_starter_efficientnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Tue Sep 13 13:31:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Download

# %%
# !pip install rasterio efficientnet_pytorch wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 3.6 MB/s
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Collecting wandb
#   Downloading wandb-0.13.3-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 51.2 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio) (57.4.0)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2022.6.15)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.21.6)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (22.1.0)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.12.1+cu113)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 49.7 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 60.4 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 66.8 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 49.4 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 45.9 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 57.4 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 64.3 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 65.3 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 66.4 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 59.7 MB/s
# Building wheels for collected packages: efficientnet-pytorch, pathtools
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=2c37f4bbf78d78472de73c0970476d68c67d51f328a63bc307369eac4ff42077
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=082a0a6665a934ad83da883c714a09716a7a1b38cd3baf070821e36739329135
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built efficientnet-pytorch pathtools
# Installing collected packages: smmap, gitdb, snuggs, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, cligj, click-plugins, affine, wandb, rasterio, efficientnet-pytorch
# Successfully installed GitPython-3.1.27 affine-2.3.1 click-plugins-1.1.1 cligj-0.7.2 docker-pycreds-0.4.0 efficientnet-pytorch-0.7.1 gitdb-4.0.9 pathtools-0.1.2 rasterio-1.2.10 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 snuggs-1.4.7 wandb-0.13.3

# %%
# !git clone https://github.com/albumentations-team/albumentations.git
# Out:
# Cloning into 'albumentations'...
# remote: Enumerating objects: 5139, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 5139 (delta 110), reused 85 (delta 54), pack-reused 4960
# Receiving objects: 100% (5139/5139), 99.74 MiB | 23.63 MiB/s, done.
# Resolving deltas: 100% (3545/3545), done.

# %% [markdown]
# # Wandb login

# %%
import os

os.environ["WANDB_NOTEBOOK_NAME"] = "effib4_LPB_768_r2_4172_augp10_diceth.ipynb"

# %%
import wandb
wandb.login()
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find effib4_LPB_768_r2_4172_augp10_diceth.ipynb.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Project Name

# %%
from fastai.callback.wandb import *

# start logging a wandb run
wandb.init(project='HuBMAP + HPA - Hacking the Human Body => Main_testing(LPB_test)')
wandb.run.name = 'effib4_LPB_768_r2_4172_augp10_diceth'
# Out:
# wandb: Currently logged in as: jcjang. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>/content/wandb/run-20220913_133232-13qp45qk</code>
# Syncing run <strong><a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing%28LPB_test%29/runs/13qp45qk" target="_blank">amber-spaceship-2</a></strong> to <a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing%28LPB_test%29" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# # Load Dataset

# %%
import zipfile

zip_path = '/content/drive/MyDrive/Colab Notebooks/alpaco/Team_1. CODEnter [ Save Form : Name_FileName_Date ]/3. 공모전/참고/Dataset/Converting/Main_dataset/conv_origin_768_r2_binary_dataset.zip'
fantasy_zip = zipfile.ZipFile(zip_path)
fantasy_zip.extractall('/content')

fantasy_zip.close()

# %%
# !gdown 18_7ODC8sz98M0FUHMz5WRHVkEvojEUbB
# !unzip /content/LPB_768_r2_dataset2.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: lpb_conv_768_r2_dataset2/masks/16728_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25298_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2447_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1731_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10044_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29180_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32151_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30500_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24100_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24100_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13942_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17187_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24782_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9517_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16711_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18426_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15192_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/62_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22236_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25641_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8231_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8894_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15860_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25298_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7706_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26319_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13507_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30194_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13189_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2447_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22995_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16216_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30080_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11448_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30474_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19048_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18426_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2344_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16711_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25689_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12244_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8502_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21021_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1220_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8116_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27471_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12233_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21812_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31139_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10651_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23665_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22995_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22995_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19507_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2279_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18121_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31675_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23760_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30581_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1184_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6794_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10971_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22016_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26886_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2279_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30080_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22718_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31139_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28436_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24522_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8343_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26982_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10274_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12174_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29820_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/928_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2668_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18445_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20831_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30424_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26101_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22016_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31800_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19084_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6390_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4301_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23094_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2696_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21358_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/351_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2696_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25689_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/62_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11662_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5995_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12483_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28052_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20428_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3057_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29610_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23243_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22741_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29820_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32325_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4265_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32741_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24522_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4777_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26319_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27879_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8231_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23252_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12174_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8402_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/351_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31675_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20563_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2668_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8151_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1123_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28262_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7902_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30194_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11662_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10488_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22236_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22133_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9904_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21021_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19569_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29690_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31898_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6121_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10992_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7970_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8842_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17126_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16728_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12827_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30474_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5932_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9470_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5287_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2874_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24194_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18445_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31571_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30224_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12476_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21129_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14183_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29307_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7569_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30194_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17143_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20478_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2874_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30876_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1955_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11448_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28052_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1500_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11890_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13260_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30224_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14674_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22995_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24961_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21321_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25516_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10488_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16362_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30194_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3057_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/144_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23094_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16890_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8222_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17422_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4062_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15005_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13189_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8116_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6807_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17187_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22544_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15005_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4944_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27616_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31733_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22718_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32325_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6722_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6318_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21501_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6121_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30581_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19084_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23828_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27298_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30355_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11662_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4776_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7970_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32741_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10971_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2500_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24222_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8638_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1229_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23959_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4066_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32412_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23051_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26664_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22544_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7397_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17143_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20478_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28622_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3083_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15005_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19084_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11645_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9437_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9791_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27616_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21812_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/203_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/737_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7359_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14756_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7970_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10992_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20302_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19997_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20955_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18792_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19179_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21812_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/676_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29213_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24100_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22133_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28126_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/164_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2668_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30765_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10912_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27471_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2696_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23243_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28189_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28189_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29307_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4944_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12174_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10488_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9777_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20831_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16711_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21129_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18449_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23961_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27340_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16564_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/127_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27861_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32527_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20955_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6611_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10488_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6318_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31675_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21129_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26101_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31709_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27298_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28657_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4066_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19507_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28318_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4639_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11448_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26886_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5287_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14388_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26480_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8116_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21086_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8231_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23243_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26319_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5832_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22016_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12244_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1157_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10971_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30876_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4776_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19533_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16728_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20520_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/928_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6318_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7359_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15842_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13483_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8894_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18422_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31958_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20478_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2424_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12174_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11629_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23640_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23961_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12026_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1229_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21021_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24222_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28940_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10703_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20563_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6730_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25689_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23961_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5777_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27616_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24100_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3959_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1157_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32527_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11890_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15067_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11629_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16711_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26174_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27298_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10703_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1690_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5317_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20831_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2344_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22953_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28791_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22310_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31571_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31898_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19048_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8116_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1690_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27861_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9437_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16216_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10488_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21155_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22741_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17455_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25516_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2344_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30355_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30080_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18401_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19377_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27471_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4062_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31290_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2447_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10992_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16711_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1184_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5785_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27232_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19377_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16362_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30765_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10703_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1123_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27616_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30414_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8343_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16564_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5099_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7970_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5552_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2874_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5086_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/686_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18121_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18900_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20794_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6390_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/435_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15551_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14674_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8638_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24833_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30474_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16149_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16216_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18426_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14388_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17828_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2447_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28940_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11629_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21155_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14396_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23665_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13942_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8116_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29610_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10274_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28429_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6722_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21358_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27781_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5086_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21812_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16149_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21039_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15787_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31406_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23961_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5932_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28045_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21501_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2174_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27587_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6794_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15787_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4066_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19360_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3303_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21321_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27232_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10992_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11497_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21021_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23252_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22059_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10392_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15329_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19507_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19533_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9470_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10666_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15842_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9777_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28262_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/737_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22133_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8222_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17187_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17828_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19179_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8151_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24961_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12233_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14674_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21112_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30250_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7569_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22016_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12784_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30294_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21501_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17187_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7970_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10488_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6121_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28823_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/660_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25641_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12452_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9904_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12174_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15067_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4412_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11645_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6730_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25641_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29296_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24222_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16728_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30224_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30424_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22718_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31727_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15842_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1229_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16362_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1123_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8752_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15192_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4412_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13260_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22035_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30765_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11890_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8388_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10666_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22035_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1123_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31727_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22236_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/928_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27350_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23961_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16659_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25298_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27350_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29690_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18422_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8388_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25516_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23760_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14183_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32412_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31799_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4412_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8638_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24100_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32151_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4777_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27128_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28791_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18422_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20520_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27298_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23880_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7397_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22133_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27616_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3959_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18401_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19048_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/127_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28126_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22953_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21112_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5102_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3409_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15067_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6120_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24100_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31800_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19179_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15192_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31799_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22741_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27861_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/144_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8752_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30084_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10392_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24100_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29809_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/127_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4561_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15842_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29180_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4639_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1878_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/62_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30194_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29223_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6120_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7970_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/203_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9777_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16564_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9450_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5777_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13507_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1955_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15860_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21195_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1123_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24782_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2424_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29809_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16564_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22236_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31733_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/144_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/737_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22995_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32009_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20440_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18777_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19507_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5777_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9450_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15551_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20794_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4658_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28748_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28657_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18426_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29213_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17455_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8222_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28940_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31139_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27587_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28622_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11890_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6611_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12233_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11662_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8116_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29809_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10274_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9470_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11497_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24097_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25641_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16362_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27861_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7970_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25945_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8502_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29610_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3054_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22544_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29238_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18777_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11497_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31800_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12784_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15329_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19360_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/676_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20794_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3959_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4404_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30201_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25298_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32325_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5932_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9358_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10666_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29820_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27879_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32151_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4658_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28940_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12784_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11064_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29610_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25689_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8227_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8894_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18422_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/17126_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23961_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21195_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2874_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28748_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22741_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28189_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23760_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28262_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30194_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20428_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1878_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11645_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/928_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11497_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11064_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22953_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30355_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27616_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6318_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4639_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/31898_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28045_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13942_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21321_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22016_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30394_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27781_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25620_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5995_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23009_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13189_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28052_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5287_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25430_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23828_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8752_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18121_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26780_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22133_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1731_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/27232_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23760_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23880_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4944_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1850_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29296_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25620_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18121_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1168_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29424_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/676_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2696_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9777_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19048_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/7359_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18422_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/928_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8402_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30250_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21112_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6807_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30355_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30500_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/13260_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28189_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12471_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4802_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5583_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/15499_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28748_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21358_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30084_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9437_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/9791_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8876_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22059_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2447_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18792_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/20478_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30500_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14396_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8151_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14674_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/25430_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1123_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/1229_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8876_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/11629_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/21039_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12244_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5102_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16728_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14407_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24241_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4301_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8151_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/18449_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/14756_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/127_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8502_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3959_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23252_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12784_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23961_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23880_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22544_0008.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10274_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/19507_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/3054_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8402_0011.png
#   inflating: lpb_conv_768_r2_dataset2/masks/28823_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5317_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/32231_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/22718_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16890_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/2447_0003.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5832_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/676_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23051_0000.png
#   inflating: lpb_conv_768_r2_dataset2/masks/4561_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/30765_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/16149_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/26780_0009.png
#   inflating: lpb_conv_768_r2_dataset2/masks/8894_0001.png
#   inflating: lpb_conv_768_r2_dataset2/masks/12174_0010.png
#   inflating: lpb_conv_768_r2_dataset2/masks/6121_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10611_0002.png
#   inflating: lpb_conv_768_r2_dataset2/masks/10611_0005.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24194_0007.png
#   inflating: lpb_conv_768_r2_dataset2/masks/24782_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/23665_0004.png
#   inflating: lpb_conv_768_r2_dataset2/masks/5287_0006.png
#   inflating: lpb_conv_768_r2_dataset2/masks/29610_0011.png
# ...
#   inflating: lpb_conv_768_r2_dataset2/images/6120_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/7970_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/203_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/9777_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/16564_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/9450_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/5777_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/13507_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/1955_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/15860_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/21195_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/1123_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/24782_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/2424_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/29809_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/16564_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/22236_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/31733_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/144_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/737_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/22995_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/32009_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/20440_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/18777_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/19507_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/5777_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/9450_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/15551_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/20794_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/4658_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/28748_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/28657_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/18426_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/29213_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/17455_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/8222_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/28940_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/31139_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/27587_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/28622_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/11890_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/6611_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/12233_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/11662_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/8116_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/29809_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/10274_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/9470_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/11497_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/24097_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/25641_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/16362_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/27861_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/7970_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/25945_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/8502_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/29610_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/3054_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/22544_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/29238_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/18777_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/11497_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/31800_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/12784_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/15329_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/19360_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/676_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/20794_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/3959_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/4404_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/30201_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/25298_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/32325_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/5932_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/9358_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/10666_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/29820_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/27879_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/32151_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/4658_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/28940_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/12784_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/11064_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/29610_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/25689_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/8227_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/8894_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/18422_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/17126_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/23961_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/21195_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/2874_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/28748_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/22741_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/28189_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/23760_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/28262_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/30194_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/20428_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/1878_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/11645_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/928_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/11497_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/11064_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/22953_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/30355_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/27616_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/6318_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/4639_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/31898_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/28045_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/13942_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/21321_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/22016_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/30394_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/27781_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/25620_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/5995_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/23009_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/13189_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/28052_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/5287_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/25430_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/23828_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/8752_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/18121_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/26780_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/22133_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/1731_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/27232_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/23760_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/23880_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/4944_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/1850_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/29296_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/25620_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/18121_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/1168_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/29424_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/676_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/2696_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/9777_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/19048_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/7359_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/18422_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/928_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/8402_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/30250_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/21112_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/6807_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/30355_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/30500_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/13260_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/28189_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/12471_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/4802_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/5583_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/15499_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/28748_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/21358_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/30084_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/9437_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/9791_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/8876_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/22059_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/2447_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/18792_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/20478_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/30500_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/14396_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/8151_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/14674_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/25430_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/1123_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/1229_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/8876_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/11629_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/21039_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/12244_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/5102_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/16728_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/14407_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/24241_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/4301_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/8151_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/18449_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/14756_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/127_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/8502_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/3959_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/23252_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/12784_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/23961_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/23880_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/22544_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/10274_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/19507_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/3054_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/8402_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/28823_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/5317_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/32231_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/22718_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/16890_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/2447_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/5832_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/676_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/23051_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/4561_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/30765_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/16149_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/26780_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/8894_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/12174_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/6121_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/10611_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/10611_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/24194_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/24782_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/23665_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/5287_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/29610_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/31406_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/15860_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/19569_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/24269_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/9445_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/31799_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/1690_0001.png
#   inflating: lpb_conv_768_r2_dataset2/images/29180_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/22310_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/25298_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/8842_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/14388_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/32126_0003.png
#   inflating: lpb_conv_768_r2_dataset2/images/30581_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/22718_0000.png
#   inflating: lpb_conv_768_r2_dataset2/images/8894_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/4265_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/5777_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/4658_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/12244_0005.png
#   inflating: lpb_conv_768_r2_dataset2/images/26982_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/29424_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/8894_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/10892_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/4802_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/10044_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/31958_0011.png
#   inflating: lpb_conv_768_r2_dataset2/images/28052_0004.png
#   inflating: lpb_conv_768_r2_dataset2/images/10703_0006.png
#   inflating: lpb_conv_768_r2_dataset2/images/29690_0009.png
#   inflating: lpb_conv_768_r2_dataset2/images/27340_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/9769_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/10610_0007.png
#   inflating: lpb_conv_768_r2_dataset2/images/1123_0008.png
#   inflating: lpb_conv_768_r2_dataset2/images/9791_0010.png
#   inflating: lpb_conv_768_r2_dataset2/images/15551_0002.png
#   inflating: lpb_conv_768_r2_dataset2/images/1731_0011.png

# %%
# train csv
# !gdown 1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# To: /content/train.csv
# 100% 16.4M/16.4M [00:00<00:00, 116MB/s]

# %%
# b0 ~ b7
# !gdown 1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# !unzip ./encoder.zip -d ./encoder
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# To: /content/encoder.zip
# 100% 720M/720M [00:05<00:00, 138MB/s]
# Archive:  ./encoder.zip
#   inflating: ./encoder/efficientnet-b0-08094119.pth
#   inflating: ./encoder/efficientnet-b1-dbc7070a.pth
#   inflating: ./encoder/efficientnet-b2-27687264.pth
#   inflating: ./encoder/efficientnet-b3-c8376fa2.pth
#   inflating: ./encoder/efficientnet-b4-e116e8b3.pth
#   inflating: ./encoder/efficientnet-b5-586e6cc6.pth
#   inflating: ./encoder/efficientnet-b6-c76e70fd.pth
#   inflating: ./encoder/efficientnet-b7-dcc49843.pth

# %% [markdown]
# # Import

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision.all import *
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import os
import cv2
import gc
import random
from albumentations import *
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from lovasz import lovasz_hinge
import rasterio
from rasterio.windows import Window
from tqdm.notebook import tqdm

from PIL import Image
import tifffile as tiff

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Parameter & Etc..

# %%
dataset_name = 'effib4_LPB_768_r2_4172_augp10_diceth'
head_epochs = 5
full_epochs = 50
lr_max = 0.5e-2
lr_slice = slice(2e-4,2e-3)
bs = 4
nfolds = 4
fold = 0
SEED = 2020
TRAIN = '/content/lpb_conv_768_r2_dataset2/images'
MASKS = '/content/lpb_conv_768_r2_dataset2/masks'
LABELS = './train.csv'
NUM_WORKERS = 4
mean = np.array([0.78054955, 0.7566257, 0.7735184]) 
std = np.array([0.25334089, 0.26656769, 0.26202731])

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    #the following line gives ~10% speedup
    #but may lead to some stochasticity in the results 
    torch.backends.cudnn.benchmark = True
    
seed_everything(SEED)

# %% [markdown]
# # Data preprocessing

# %%
# # https://www.kaggle.com/iafoss/256x256-images
# mean = np.array([0.65459856,0.48386562,0.69428385])
# std = np.array([0.15167958,0.23584107,0.13146145])


# https://www.kaggle.com/datasets/thedevastator/hubmap-2022-256x256
def img2tensor(img,dtype:np.dtype=np.float32):
    if img.ndim==2 : img = np.expand_dims(img,2)
    img = np.transpose(img,(2,0,1))
    return torch.from_numpy(img.astype(dtype, copy=False))



class HuBMAPDataset(Dataset):
    def __init__(self, fold=fold, train=True, tfms=None):
        ids = pd.read_csv(LABELS).id.astype(str).values
        kf = KFold(n_splits=nfolds,random_state=SEED,shuffle=True)
        ids = set(ids[list(kf.split(ids))[fold][0 if train else 1]])
        self.fnames = [fname for fname in os.listdir(TRAIN) if fname.split('_')[0] in ids]
        self.train = train
        self.tfms = tfms
        
    def __len__(self):
        return len(self.fnames)
    
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.cvtColor(cv2.imread(os.path.join(TRAIN,fname)), cv2.COLOR_BGR2RGB)
        mask = cv2.imread(os.path.join(MASKS,fname),cv2.IMREAD_GRAYSCALE)
        if self.tfms is not None:
            augmented = self.tfms(image=img,mask=mask)
            img,mask = augmented['image'],augmented['mask']
        return img2tensor((img/255.0 - mean)/std),img2tensor(mask)
    


# version 1 0.65 version
def get_aug(p=1.0):
    return Compose([
        HorizontalFlip(p=0.5),
        VerticalFlip(),
        # GridDropout(ratio=0.4),
        RandomRotate90(p=1),
        #Morphology
        ShiftScaleRotate(shift_limit=0, scale_limit=(-0.2,0.2), rotate_limit=(-30,30), 
                         interpolation=1, border_mode=0, value=(0,0,0), p=0.5),
        GaussNoise(var_limit=(0,50.0), mean=0, p=0.5),
        GaussianBlur(blur_limit=(3,7), p=0.5),
        #Color
        RandomBrightnessContrast(brightness_limit=0.35, contrast_limit=0.5, 
                                 brightness_by_max=True,p=0.5),
        HueSaturationValue(hue_shift_limit=30, sat_shift_limit=30, 
                           val_shift_limit=0, p=0.5),
        OneOf([
            OpticalDistortion(p=0.3),
            GridDistortion(p=.1),
            IAAPiecewiseAffine(p=0.3),
        ], p=0.3),
    ], p=p)

# %%
#example of train images with masks
ds = HuBMAPDataset(tfms=get_aug(p=1.0))
dl = DataLoader(ds,batch_size=8,shuffle=False,num_workers=NUM_WORKERS)
imgs,masks = next(iter(dl))

plt.figure(figsize=(16,16))
for i,(img,mask) in enumerate(zip(imgs,masks)):
    img = ((img.permute(1,2,0)*std + mean)*255.0).numpy().astype(np.uint8)
    plt.subplot(8,8,i+1)
    plt.imshow(img,vmin=0,vmax=255)
    plt.imshow(mask.squeeze().numpy(), alpha=0.2)
    plt.axis('off')
    plt.subplots_adjust(wspace=None, hspace=None)
    
del ds,dl,imgs,masks

# %% [markdown]
# # Model - EfficientUnet

# %%
class FPN(nn.Module):
    def __init__(self, input_channels:list, output_channels:list):
        super().__init__()
        self.convs = nn.ModuleList(
            [nn.Sequential(nn.Conv2d(in_ch, out_ch*2, kernel_size=3, padding=1),
             nn.ReLU(inplace=True), nn.BatchNorm2d(out_ch*2),
             nn.Conv2d(out_ch*2, out_ch, kernel_size=3, padding=1))
            for in_ch, out_ch in zip(input_channels, output_channels)])
        
    def forward(self, xs:list, last_layer):
        hcs = [F.interpolate(c(x),scale_factor=2**(len(self.convs)-i),mode='bilinear') 
               for i,(c,x) in enumerate(zip(self.convs, xs))]
        hcs.append(last_layer)
        return torch.cat(hcs, dim=1)

class UnetBlock(Module):
    def __init__(self, up_in_c:int, x_in_c:int, nf:int=None, blur:bool=False,
                 self_attention:bool=False, **kwargs):
        super().__init__()
        self.shuf = PixelShuffle_ICNR(up_in_c, up_in_c//2, blur=blur, **kwargs)
        self.bn = nn.BatchNorm2d(x_in_c)
        ni = up_in_c//2 + x_in_c
        nf = nf if nf is not None else max(up_in_c//2,32)
        self.conv1 = ConvLayer(ni, nf, norm_type=None, **kwargs)
        self.conv2 = ConvLayer(nf, nf, norm_type=None,
            xtra=SelfAttention(nf) if self_attention else None, **kwargs)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, up_in:Tensor, left_in:Tensor) -> Tensor:
        s = left_in
        up_out = self.shuf(up_in)
        cat_x = self.relu(torch.cat([up_out, self.bn(s)], dim=1))
        return self.conv2(self.conv1(cat_x))
        
class _ASPPModule(nn.Module):
    def __init__(self, inplanes, planes, kernel_size, padding, dilation, groups=1):
        super().__init__()
        self.atrous_conv = nn.Conv2d(inplanes, planes, kernel_size=kernel_size,
                stride=1, padding=padding, dilation=dilation, bias=False, groups=groups)
        self.bn = nn.BatchNorm2d(planes)
        self.relu = nn.ReLU()

        self._init_weight()

    def forward(self, x):
        x = self.atrous_conv(x)
        x = self.bn(x)

        return self.relu(x)

    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

class ASPP(nn.Module):
    def __init__(self, inplanes=512, mid_c=256, dilations=[6, 12, 18, 24], out_c=None):
        super().__init__()
        self.aspps = [_ASPPModule(inplanes, mid_c, 1, padding=0, dilation=1)] + \
            [_ASPPModule(inplanes, mid_c, 3, padding=d, dilation=d,groups=4) for d in dilations]
        self.aspps = nn.ModuleList(self.aspps)
        self.global_pool = nn.Sequential(nn.AdaptiveMaxPool2d((1, 1)),
                        nn.Conv2d(inplanes, mid_c, 1, stride=1, bias=False),
                        nn.BatchNorm2d(mid_c), nn.ReLU())
        out_c = out_c if out_c is not None else mid_c
        self.out_conv = nn.Sequential(nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False),
                                    nn.BatchNorm2d(out_c), nn.ReLU(inplace=True))
        self.conv1 = nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False)
        self._init_weight()

    def forward(self, x):
        x0 = self.global_pool(x)
        xs = [aspp(x) for aspp in self.aspps]
        x0 = F.interpolate(x0, size=xs[0].size()[2:], mode='bilinear', align_corners=True)
        x = torch.cat([x0] + xs, dim=1)
        return self.out_conv(x)
    
    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
pretrained_root = './encoder/'
efficient_net_encoders = {
    "efficientnet-b0": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (3, 5, 9, 16),
        "weight_path": pretrained_root + "efficientnet-b0-08094119.pth"
    },
    "efficientnet-b1": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b1-dbc7070a.pth"
    },
    "efficientnet-b2": {
        "out_channels": (3, 32, 24, 48, 120, 352),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b2-27687264.pth"
    },
    "efficientnet-b3": {
        "out_channels": (3, 40, 32, 48, 136, 384),
        "stage_idxs": (5, 8, 18, 26),
        "weight_path": pretrained_root + "efficientnet-b3-c8376fa2.pth"
    },
    "efficientnet-b4": {
        "out_channels": (3, 48, 32, 56, 160, 448),
        "stage_idxs": (6, 10, 22, 32),
        "weight_path": pretrained_root + "efficientnet-b4-e116e8b3.pth"
    },
    "efficientnet-b5": {
        "out_channels": (3, 48, 40, 64, 176, 512),
        "stage_idxs": (8, 13, 27, 39),
        "weight_path": pretrained_root + "efficientnet-b5-586e6cc6.pth"
    },
    "efficientnet-b6": {
        "out_channels": (3, 56, 40, 72, 200, 576),
        "stage_idxs": (9, 15, 31, 45),
        "weight_path": pretrained_root + "efficientnet-b6-c76e70fd.pth"
    },
    "efficientnet-b7": {
        "out_channels": (3, 64, 48, 80, 224, 640),
        "stage_idxs": (11, 18, 38, 55),
        "weight_path": pretrained_root + "efficientnet-b7-dcc49843.pth"
    }
}

# %%
import sys
# sys.path.insert(0, '../input/efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master')

from efficientnet_pytorch import EfficientNet
from efficientnet_pytorch.utils import url_map, url_map_advprop, get_model_params

class EfficientNetEncoder(EfficientNet):
    def __init__(self, stage_idxs, out_channels, model_name, depth=5):

        blocks_args, global_params = get_model_params(model_name, override_params=None)
        super().__init__(blocks_args, global_params)
        
        cfg = efficient_net_encoders[model_name]

        self._stage_idxs = stage_idxs
        self._out_channels = out_channels
        self._depth = depth
        self._in_channels = 3

        del self._fc
        self.load_state_dict(torch.load(cfg['weight_path']))

    def get_stages(self):
        return [
            nn.Identity(),
            nn.Sequential(self._conv_stem, self._bn0, self._swish),
            self._blocks[:self._stage_idxs[0]],
            self._blocks[self._stage_idxs[0]:self._stage_idxs[1]],
            self._blocks[self._stage_idxs[1]:self._stage_idxs[2]],
            self._blocks[self._stage_idxs[2]:],
        ]

    def forward(self, x):
        stages = self.get_stages()

        block_number = 0.
        drop_connect_rate = self._global_params.drop_connect_rate

        features = []
        for i in range(self._depth + 1):

            # Identity and Sequential stages
            if i < 2:
                x = stages[i](x)

            # Block stages need drop_connect rate
            else:
                for module in stages[i]:
                    drop_connect = drop_connect_rate * block_number / len(self._blocks)
                    block_number += 1.
                    x = module(x, drop_connect)

            features.append(x)

        return features

    def load_state_dict(self, state_dict, **kwargs):
        state_dict.pop("_fc.bias")
        state_dict.pop("_fc.weight")
        super().load_state_dict(state_dict, **kwargs)  
        

class EffUnet(nn.Module):
    def __init__(self, model_name, stride=1):
        super().__init__()
        
        cfg = efficient_net_encoders[model_name]
        stage_idxs = cfg['stage_idxs']
        out_channels = cfg['out_channels']
        
        self.encoder = EfficientNetEncoder(stage_idxs, out_channels, model_name)

        #aspp with customized dilatations
        self.aspp = ASPP(out_channels[-1], 256, out_c=384, 
                         dilations=[stride*1, stride*2, stride*3, stride*4])
        self.drop_aspp = nn.Dropout2d(0.5)
        #decoder
        self.dec4 = UnetBlock(384, out_channels[-2], 256)
        self.dec3 = UnetBlock(256, out_channels[-3], 128)
        self.dec2 = UnetBlock(128, out_channels[-4], 64)
        self.dec1 = UnetBlock(64, out_channels[-5], 32)
        self.fpn = FPN([384, 256, 128, 64], [16]*4)
        self.drop = nn.Dropout2d(0.1)
        self.final_conv = ConvLayer(32+16*4, 1, ks=1, norm_type=None, act_cls=None)
        
    def forward(self, x):
        enc0, enc1, enc2, enc3, enc4 = self.encoder(x)[-5:]
        enc5 = self.aspp(enc4)
        dec3 = self.dec4(self.drop_aspp(enc5), enc3)
        # dec3 = self.dec4(enc5, enc3)
        dec2 = self.dec3(dec3,enc2)
        dec1 = self.dec2(dec2,enc1)
        dec0 = self.dec1(dec1,enc0)
        x = self.fpn([enc5, dec3, dec2, dec1], dec0)
        x = self.final_conv(self.drop(x))
        # x = self.final_conv(x)
        x = F.interpolate(x,scale_factor=2,mode='bilinear')
        return x
    
#split the model to encoder and decoder for fast.ai
split_layers = lambda m: [
                list(m.encoder.parameters()),
                list(m.aspp.parameters())+list(m.dec4.parameters())+
                list(m.dec3.parameters())+list(m.dec2.parameters())+
                list(m.dec1.parameters())+list(m.fpn.parameters())+
                list(m.final_conv.parameters())
            ]

# %% [markdown]
# # Loss & Metrics

# %%
def symmetric_lovasz(outputs, targets):
    return 0.5*(lovasz_hinge(outputs, targets) + lovasz_hinge(-outputs, 1.0 - targets))

# %%
class Dice_soft(Metric):
    def __init__(self, axis=1): 
        self.axis = axis 
    def reset(self): self.inter,self.union = 0,0
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        self.inter += (pred*targ).float().sum().item()
        self.union += (pred+targ).float().sum().item()
    @property
    def value(self): return 2.0 * self.inter/self.union if self.union > 0 else None
    
# dice with automatic threshold selection
class Dice_th(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.05), axis=1): 
        self.axis = axis
        self.ths = ths
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 
                2.0*self.inter/self.union, torch.zeros_like(self.union))
        return dices.max()

# %% [markdown]
# # Model evaluation

# %%
#iterator like wrapper that returns predicted and gt masks
class Model_pred:
    def __init__(self, model, dl, tta:bool=True, half:bool=False):
        self.model = model
        self.dl = dl
        self.tta = tta
        self.half = half
        
    def __iter__(self):
        self.model.eval()
        name_list = self.dl.dataset.fnames
        count=0
        with torch.no_grad():
            for x,y in iter(self.dl):
                x = x.cuda()
                if self.half: x = x.half()
                p = self.model(x)
                py = torch.sigmoid(p).detach()
                if self.tta:
                    #x,y,xy flips as TTA
                    flips = [[-1],[-2],[-2,-1]]
                    for f in flips:
                        p = self.model(torch.flip(x,f))
                        p = torch.flip(p,f)
                        py += torch.sigmoid(p).detach()
                    py /= (1+len(flips))
                if y is not None and len(y.shape)==4 and py.shape != y.shape:
                    py = F.upsample(py, size=(y.shape[-2],y.shape[-1]), mode="bilinear")
                py = py.permute(0,2,3,1).float().cpu()
                batch_size = len(py)
                for i in range(batch_size):
                    taget = y[i].detach().cpu() if y is not None else None
                    yield py[i],taget,name_list[count]
                    count += 1
                    
    def __len__(self):
        return len(self.dl.dataset)
    
class Dice_th_pred(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.01), axis=1): 
        self.axis = axis
        self.ths = ths
        self.reset()
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self,p,t):
        pred,targ = flatten_check(p, t)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 2.0*self.inter/self.union, 
                            torch.zeros_like(self.union))
        return dices
    
def save_img(data,name,out):
    data = data.float().cpu().numpy()
    img = cv2.imencode('.png',(data*255).astype(np.uint8))[1]
    out.writestr(name, img)

# %% [markdown]
# # Train

# %%
# ## callbacks - early stopping, save model
# cbs=[EarlyStoppingCallback(monitor='valid_loss', min_delta=0, patience=5),
#      SaveModelCallback(monitor='dice_th',comp=np.greater)]

# %%
dice = Dice_th_pred(np.arange(0.2,0.7,0.01))
for fold in range(1):
    ds_t = HuBMAPDataset(fold=fold, train=True, tfms=get_aug(p=1.0))
    # ds_t = HuBMAPDataset(fold=fold, train=True)
    ds_v = HuBMAPDataset(fold=fold, train=False)
    data = ImageDataLoaders.from_dsets(ds_t,ds_v,bs=bs,
                num_workers=NUM_WORKERS,pin_memory=True).cuda()
    model = EffUnet('efficientnet-b4').cuda()
    learn = Learner(data, model, loss_func=symmetric_lovasz,
                metrics=[Dice_soft(),Dice_th()], 
                splitter=split_layers,
                cbs=WandbCallback())
    # .to_fp16(clip=0.5)
    
    #start with training the head
    learn.freeze_to(-1) #doesn't work
    for param in learn.opt.param_groups[0]['params']:
        param.requires_grad = False
    learn.fit_one_cycle(head_epochs, lr_max=lr_max)

    #continue training full model
    learn.unfreeze()
    learn.fit_one_cycle(full_epochs, lr_max=lr_slice,
        # cbs=SaveModelCallback(monitor='valid_loss',comp=np.less))
        cbs=SaveModelCallback(monitor='dice_th',comp=np.greater))
    torch.save(learn.model.state_dict(),f'model_{fold}.pth')
    
    #model evaluation on val and saving the masks
    mp = Model_pred(learn.model,learn.dls.loaders[1])
    with zipfile.ZipFile('val_masks_tta.zip', 'a') as out:
        for p in progress_bar(mp):
            dice.accumulate(p[0],p[1])
            save_img(p[0],p[2],out)
    gc.collect()
# Out:
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'HuBMAPDataset' object has no attribute 'items'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.675037</td>
#       <td>1.676272</td>
#       <td>0.278101</td>
#       <td>0.420934</td>
#       <td>08:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.599592</td>
#       <td>1.584543</td>
#       <td>0.275022</td>
#       <td>0.446821</td>
#       <td>08:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.543342</td>
#       <td>1.549629</td>
#       <td>0.299442</td>
#       <td>0.464236</td>
#       <td>08:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.522232</td>
#       <td>1.516689</td>
#       <td>0.311683</td>
#       <td>0.513246</td>
#       <td>08:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.516979</td>
#       <td>1.513174</td>
#       <td>0.314929</td>
#       <td>0.526808</td>
#       <td>08:33</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.516585</td>
#       <td>1.494854</td>
#       <td>0.328792</td>
#       <td>0.569797</td>
#       <td>11:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.507808</td>
#       <td>1.473672</td>
#       <td>0.336491</td>
#       <td>0.592658</td>
#       <td>10:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.463567</td>
#       <td>1.444748</td>
#       <td>0.376222</td>
#       <td>0.617394</td>
#       <td>10:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.441001</td>
#       <td>1.412006</td>
#       <td>0.409620</td>
#       <td>0.642777</td>
#       <td>10:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.415416</td>
#       <td>1.349795</td>
#       <td>0.443847</td>
#       <td>0.688363</td>
#       <td>10:44</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.361975</td>
#       <td>1.302800</td>
#       <td>0.485030</td>
#       <td>0.697851</td>
#       <td>10:51</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.311081</td>
#       <td>1.291349</td>
#       <td>0.501687</td>
#       <td>0.707211</td>
#       <td>11:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.272457</td>
#       <td>1.227098</td>
#       <td>0.540210</td>
#       <td>0.724377</td>
#       <td>10:56</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.209161</td>
#       <td>1.242104</td>
#       <td>0.593267</td>
#       <td>0.737396</td>
#       <td>10:50</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.244985</td>
#       <td>1.343884</td>
#       <td>0.512776</td>
#       <td>0.675385</td>
#       <td>11:02</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.247009</td>
#       <td>1.214823</td>
#       <td>0.522481</td>
#       <td>0.713210</td>
#       <td>11:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.199173</td>
#       <td>1.209357</td>
#       <td>0.607955</td>
#       <td>0.745571</td>
#       <td>10:54</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.186715</td>
#       <td>1.179841</td>
#       <td>0.580020</td>
#       <td>0.743937</td>
#       <td>11:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.137235</td>
#       <td>1.181148</td>
#       <td>0.591750</td>
#       <td>0.760633</td>
#       <td>11:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.111535</td>
#       <td>1.139651</td>
#       <td>0.614944</td>
#       <td>0.762928</td>
#       <td>11:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.151384</td>
#       <td>1.240882</td>
#       <td>0.497785</td>
#       <td>0.754522</td>
#       <td>10:52</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.093817</td>
#       <td>1.170264</td>
#       <td>0.604346</td>
#       <td>0.758524</td>
#       <td>10:56</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.131603</td>
#       <td>1.152160</td>
#       <td>0.620385</td>
#       <td>0.758034</td>
#       <td>10:54</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.100445</td>
#       <td>1.104718</td>
#       <td>0.602642</td>
#       <td>0.756679</td>
#       <td>10:54</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.027415</td>
#       <td>1.107207</td>
#       <td>0.643652</td>
#       <td>0.766972</td>
#       <td>11:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.022652</td>
#       <td>1.112570</td>
#       <td>0.565940</td>
#       <td>0.754107</td>
#       <td>11:04</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.037898</td>
#       <td>1.124490</td>
#       <td>0.593276</td>
#       <td>0.748257</td>
#       <td>11:04</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.029291</td>
#       <td>1.052279</td>
#       <td>0.622728</td>
#       <td>0.760215</td>
#       <td>10:56</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.989056</td>
#       <td>1.077578</td>
#       <td>0.583268</td>
#       <td>0.751990</td>
#       <td>11:08</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.021242</td>
#       <td>1.167923</td>
#       <td>0.612300</td>
#       <td>0.759319</td>
#       <td>11:09</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.965592</td>
#       <td>1.070196</td>
#       <td>0.622655</td>
#       <td>0.747057</td>
#       <td>10:57</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.992122</td>
#       <td>1.074455</td>
#       <td>0.614018</td>
#       <td>0.747649</td>
#       <td>11:05</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.948326</td>
#       <td>1.023718</td>
#       <td>0.601356</td>
#       <td>0.767376</td>
#       <td>11:14</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.989721</td>
#       <td>1.014958</td>
#       <td>0.624304</td>
#       <td>0.777402</td>
#       <td>11:10</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.948175</td>
#       <td>1.048732</td>
#       <td>0.659266</td>
#       <td>0.775401</td>
#       <td>11:12</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.964666</td>
#       <td>1.069965</td>
#       <td>0.622319</td>
#       <td>0.751532</td>
#       <td>10:59</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.883960</td>
#       <td>1.027220</td>
#       <td>0.628870</td>
#       <td>0.757311</td>
#       <td>10:58</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.859648</td>
#       <td>1.154236</td>
#       <td>0.678187</td>
#       <td>0.765358</td>
#       <td>10:53</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.890043</td>
#       <td>1.095514</td>
#       <td>0.636872</td>
#       <td>0.766860</td>
#       <td>10:53</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.887338</td>
#       <td>1.083359</td>
#       <td>0.659445</td>
#       <td>0.765233</td>
#       <td>10:51</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.844033</td>
#       <td>1.134093</td>
#       <td>0.648893</td>
#       <td>0.756361</td>
#       <td>10:52</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.853070</td>
#       <td>1.090523</td>
#       <td>0.661030</td>
#       <td>0.764151</td>
#       <td>10:53</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.855587</td>
#       <td>1.072930</td>
#       <td>0.658850</td>
#       <td>0.771975</td>
#       <td>10:54</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.832887</td>
#       <td>1.124438</td>
#       <td>0.662985</td>
#       <td>0.776536</td>
#       <td>10:51</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.841895</td>
#       <td>1.074267</td>
#       <td>0.656301</td>
#       <td>0.766627</td>
#       <td>10:54</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.813369</td>
#       <td>1.139358</td>
#       <td>0.668579</td>
#       <td>0.761210</td>
#       <td>10:54</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.788175</td>
#       <td>1.191181</td>
#       <td>0.679973</td>
#       <td>0.769793</td>
#       <td>10:53</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.854256</td>
#       <td>1.103974</td>
#       <td>0.665075</td>
#       <td>0.767794</td>
#       <td>10:44</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.798917</td>
#       <td>1.167039</td>
#       <td>0.679586</td>
#       <td>0.767061</td>
#       <td>10:55</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.785886</td>
#       <td>1.141242</td>
#       <td>0.681291</td>
#       <td>0.774570</td>
#       <td>10:44</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.784258</td>
#       <td>1.192878</td>
#       <td>0.687490</td>
#       <td>0.769681</td>
#       <td>10:55</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.793054</td>
#       <td>1.164511</td>
#       <td>0.674005</td>
#       <td>0.771475</td>
#       <td>10:50</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.822118</td>
#       <td>1.170100</td>
#       <td>0.679592</td>
#       <td>0.771669</td>
#       <td>10:58</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.749079</td>
#       <td>1.179080</td>
#       <td>0.683641</td>
#       <td>0.771870</td>
#       <td>10:43</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.762061</td>
#       <td>1.139292</td>
#       <td>0.677323</td>
#       <td>0.771332</td>
#       <td>10:55</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice_th value: 0.5697972774505615.
# Better model found at epoch 1 with dice_th value: 0.5926584005355835.
# Better model found at epoch 2 with dice_th value: 0.6173939108848572.
# Better model found at epoch 3 with dice_th value: 0.6427774429321289.
# Better model found at epoch 4 with dice_th value: 0.6883631348609924.
# Better model found at epoch 5 with dice_th value: 0.6978505253791809.
# Better model found at epoch 6 with dice_th value: 0.7072111368179321.
# Better model found at epoch 7 with dice_th value: 0.7243770360946655.
# Better model found at epoch 8 with dice_th value: 0.737395703792572.
# Better model found at epoch 11 with dice_th value: 0.7455708384513855.
# Better model found at epoch 13 with dice_th value: 0.7606329917907715.
# Better model found at epoch 14 with dice_th value: 0.7629281282424927.
# Better model found at epoch 19 with dice_th value: 0.7669722437858582.
# Better model found at epoch 27 with dice_th value: 0.7673761248588562.
# Better model found at epoch 28 with dice_th value: 0.7774017453193665.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1041' class='' max='1041' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1041/1041 04:28&lt;00:00]
#     </div>

# %%
dices = dice.value
noise_ths = dice.ths
best_dice = dices.max()
best_thr = noise_ths[dices.argmax()]
plt.figure(figsize=(8,4))
plt.plot(noise_ths, dices, color='blue')
plt.vlines(x=best_thr, ymin=dices.min(), ymax=dices.max(), colors='black')
d = dices.max() - dices.min()
plt.text(noise_ths[-1]-0.1, best_dice-0.1*d, f'DICE = {best_dice:.3f}', fontsize=12);
plt.text(noise_ths[-1]-0.1, best_dice-0.2*d, f'TH = {best_thr:.3f}', fontsize=12);
plt.show()

# %%
dataset_name =

# %%
# !mkdir {dataset_name}
# !mv ./model_0.pth ./{dataset_name}
# !mv ./model_1.pth ./{dataset_name}
# !mv ./model_2.pth ./{dataset_name}
# !mv ./model_3.pth ./{dataset_name}

# %%
# !zip /content/drive/MyDrive/data/kaggle/main_test/{dataset_name}.zip -r ./{dataset_name}
# Out:
#   adding: effib4_LPB_768_r2_4172_augp10_diceth/ (stored 0%)
#   adding: effib4_LPB_768_r2_4172_augp10_diceth/model_0.pth (deflated 7%)
