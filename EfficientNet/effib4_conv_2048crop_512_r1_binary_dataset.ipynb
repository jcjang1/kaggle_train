# %% [markdown]
# <a href="https://colab.research.google.com/github/heokwon/i-seg-you/blob/main/fast_ai_starter_efficientnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Thu Sep  8 12:37:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Download

# %%
# !pip install rasterio efficientnet_pytorch wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 5.0 MB/s
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Collecting wandb
#   Downloading wandb-0.13.2-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 53.1 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.21.6)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (22.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2022.6.15)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.12.1+cu113)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 86.3 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 75.9 MB/s
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 65.9 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 68.3 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 79.6 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 81.9 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 59.1 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 79.4 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 87.4 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 86.7 MB/s
# Building wheels for collected packages: efficientnet-pytorch, pathtools
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=20e37b3fbef65ed44eb25de4681466464ed2745fb5365bfac3af3de7cd19e7b3
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=431ef283bad9158326584cabbaba23e9666c8fe6faa2d31a2a47ce4ba5ea2c2e
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built efficientnet-pytorch pathtools
# Installing collected packages: smmap, gitdb, snuggs, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, cligj, click-plugins, affine, wandb, rasterio, efficientnet-pytorch
# Successfully installed GitPython-3.1.27 affine-2.3.1 click-plugins-1.1.1 cligj-0.7.2 docker-pycreds-0.4.0 efficientnet-pytorch-0.7.1 gitdb-4.0.9 pathtools-0.1.2 rasterio-1.2.10 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 snuggs-1.4.7 wandb-0.13.2

# %%
# !git clone https://github.com/albumentations-team/albumentations.git
# Out:
# Cloning into 'albumentations'...
# remote: Enumerating objects: 5186, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 5186 (delta 144), reused 130 (delta 87), pack-reused 4960
# Receiving objects: 100% (5186/5186), 99.74 MiB | 38.97 MiB/s, done.
# Resolving deltas: 100% (3578/3578), done.

# %% [markdown]
# # Wandb login

# %%
import os

os.environ["WANDB_NOTEBOOK_NAME"] = "effib4_conv_2048crop_512_r1_binary_dataset.ipynb"

# %%
import wandb
wandb.login()
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find effib4_conv_2048crop_512_r1_binary_dataset.ipynb.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Project Name

# %%
from fastai.callback.wandb import *

# start logging a wandb run
wandb.init(project='HuBMAP + HPA - Hacking the Human Body => Main_testing')
wandb.run.name = 'effib4_conv_2048crop_512_r1_binary_dataset_test5'
# Out:
# wandb: Currently logged in as: jcjang. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.2
# Run data is saved locally in <code>/content/wandb/run-20220908_123833-3ddpwbut</code>
# Syncing run <strong><a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing/runs/3ddpwbut" target="_blank">dulcet-fire-15</a></strong> to <a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# # Load Dataset

# %%
import zipfile

zip_path = '/content/drive/MyDrive/Colab Notebooks/alpaco/Team_1. CODEnter [ Save Form : Name_FileName_Date ]/3. 공모전/참고/Dataset/Converting/Main_dataset/conv_origin_768_r2_binary_dataset.zip'
fantasy_zip = zipfile.ZipFile(zip_path)
fantasy_zip.extractall('/content')

fantasy_zip.close()

# %%
# !gdown 1cDcjeFVfZplxoQzAQhXGylNnTfQOGvJE
# !unzip /content/conv_2048crop_512_r1_binary_dataset.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: crop_512_r1_conv_dataset/images/10666_0012.png
#   inflating: crop_512_r1_conv_dataset/images/25641_0003.png
#   inflating: crop_512_r1_conv_dataset/images/32151_0013.png
#   inflating: crop_512_r1_conv_dataset/images/29307_0012.png
#   inflating: crop_512_r1_conv_dataset/images/27587_0011.png
#   inflating: crop_512_r1_conv_dataset/images/11064_0008.png
#   inflating: crop_512_r1_conv_dataset/images/1955_0015.png
#   inflating: crop_512_r1_conv_dataset/images/10488_0002.png
#   inflating: crop_512_r1_conv_dataset/images/10611_0002.png
#   inflating: crop_512_r1_conv_dataset/images/14674_0000.png
#   inflating: crop_512_r1_conv_dataset/images/27781_0007.png
#   inflating: crop_512_r1_conv_dataset/images/17126_0008.png
#   inflating: crop_512_r1_conv_dataset/images/13483_0001.png
#   inflating: crop_512_r1_conv_dataset/images/2424_0000.png
#   inflating: crop_512_r1_conv_dataset/images/19507_0010.png
#   inflating: crop_512_r1_conv_dataset/images/31799_0008.png
#   inflating: crop_512_r1_conv_dataset/images/676_0007.png
#   inflating: crop_512_r1_conv_dataset/images/21112_0004.png
#   inflating: crop_512_r1_conv_dataset/images/24782_0012.png
#   inflating: crop_512_r1_conv_dataset/images/20247_0003.png
#   inflating: crop_512_r1_conv_dataset/images/4561_0005.png
#   inflating: crop_512_r1_conv_dataset/images/18121_0014.png
#   inflating: crop_512_r1_conv_dataset/images/686_0011.png
#   inflating: crop_512_r1_conv_dataset/images/1850_0010.png
#   inflating: crop_512_r1_conv_dataset/images/7359_0011.png
#   inflating: crop_512_r1_conv_dataset/images/31290_0006.png
#   inflating: crop_512_r1_conv_dataset/images/660_0005.png
#   inflating: crop_512_r1_conv_dataset/images/32151_0006.png
#   inflating: crop_512_r1_conv_dataset/images/19569_0003.png
#   inflating: crop_512_r1_conv_dataset/images/6121_0015.png
#   inflating: crop_512_r1_conv_dataset/images/20478_0008.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0006.png
#   inflating: crop_512_r1_conv_dataset/images/24222_0000.png
#   inflating: crop_512_r1_conv_dataset/images/3959_0015.png
#   inflating: crop_512_r1_conv_dataset/images/15860_0013.png
#   inflating: crop_512_r1_conv_dataset/images/2943_0003.png
#   inflating: crop_512_r1_conv_dataset/images/25620_0003.png
#   inflating: crop_512_r1_conv_dataset/images/5086_0014.png
#   inflating: crop_512_r1_conv_dataset/images/14396_0004.png
#   inflating: crop_512_r1_conv_dataset/images/15005_0002.png
#   inflating: crop_512_r1_conv_dataset/images/25430_0013.png
#   inflating: crop_512_r1_conv_dataset/images/28823_0005.png
#   inflating: crop_512_r1_conv_dataset/images/2174_0012.png
#   inflating: crop_512_r1_conv_dataset/images/15329_0003.png
#   inflating: crop_512_r1_conv_dataset/images/25430_0006.png
#   inflating: crop_512_r1_conv_dataset/images/32412_0003.png
#   inflating: crop_512_r1_conv_dataset/images/8151_0015.png
#   inflating: crop_512_r1_conv_dataset/images/22059_0007.png
#   inflating: crop_512_r1_conv_dataset/images/737_0001.png
#   inflating: crop_512_r1_conv_dataset/images/9517_0004.png
#   inflating: crop_512_r1_conv_dataset/images/20955_0008.png
#   inflating: crop_512_r1_conv_dataset/images/2696_0015.png
#   inflating: crop_512_r1_conv_dataset/images/26664_0009.png
#   inflating: crop_512_r1_conv_dataset/images/1955_0014.png
#   inflating: crop_512_r1_conv_dataset/images/660_0010.png
#   inflating: crop_512_r1_conv_dataset/images/26664_0010.png
#   inflating: crop_512_r1_conv_dataset/images/10892_0014.png
#   inflating: crop_512_r1_conv_dataset/images/2079_0007.png
#   inflating: crop_512_r1_conv_dataset/images/15124_0015.png
#   inflating: crop_512_r1_conv_dataset/images/6120_0013.png
#   inflating: crop_512_r1_conv_dataset/images/21086_0003.png
#   inflating: crop_512_r1_conv_dataset/images/29296_0001.png
#   inflating: crop_512_r1_conv_dataset/images/22133_0006.png
#   inflating: crop_512_r1_conv_dataset/images/9791_0001.png
#   inflating: crop_512_r1_conv_dataset/images/19048_0003.png
#   inflating: crop_512_r1_conv_dataset/images/5287_0011.png
#   inflating: crop_512_r1_conv_dataset/images/30500_0003.png
#   inflating: crop_512_r1_conv_dataset/images/28657_0007.png
#   inflating: crop_512_r1_conv_dataset/images/30500_0014.png
#   inflating: crop_512_r1_conv_dataset/images/1168_0011.png
#   inflating: crop_512_r1_conv_dataset/images/28657_0001.png
#   inflating: crop_512_r1_conv_dataset/images/2174_0013.png
#   inflating: crop_512_r1_conv_dataset/images/9231_0004.png
#   inflating: crop_512_r1_conv_dataset/images/9358_0005.png
#   inflating: crop_512_r1_conv_dataset/images/10488_0010.png
#   inflating: crop_512_r1_conv_dataset/images/7706_0003.png
#   inflating: crop_512_r1_conv_dataset/images/4639_0004.png
#   inflating: crop_512_r1_conv_dataset/images/5995_0009.png
#   inflating: crop_512_r1_conv_dataset/images/6021_0010.png
#   inflating: crop_512_r1_conv_dataset/images/21155_0004.png
#   inflating: crop_512_r1_conv_dataset/images/30876_0006.png
#   inflating: crop_512_r1_conv_dataset/images/737_0003.png
#   inflating: crop_512_r1_conv_dataset/images/1157_0002.png
#   inflating: crop_512_r1_conv_dataset/images/29307_0010.png
#   inflating: crop_512_r1_conv_dataset/images/31290_0010.png
#   inflating: crop_512_r1_conv_dataset/images/4412_0007.png
#   inflating: crop_512_r1_conv_dataset/images/1500_0013.png
#   inflating: crop_512_r1_conv_dataset/images/21086_0010.png
#   inflating: crop_512_r1_conv_dataset/images/31733_0002.png
#   inflating: crop_512_r1_conv_dataset/images/1229_0014.png
#   inflating: crop_512_r1_conv_dataset/images/15005_0004.png
#   inflating: crop_512_r1_conv_dataset/images/20794_0013.png
#   inflating: crop_512_r1_conv_dataset/images/31698_0000.png
#   inflating: crop_512_r1_conv_dataset/images/4658_0006.png
#   inflating: crop_512_r1_conv_dataset/images/15067_0010.png
#   inflating: crop_512_r1_conv_dataset/images/8116_0008.png
#   inflating: crop_512_r1_conv_dataset/images/3303_0015.png
#   inflating: crop_512_r1_conv_dataset/images/1731_0010.png
#   inflating: crop_512_r1_conv_dataset/images/30500_0005.png
#   inflating: crop_512_r1_conv_dataset/images/3057_0005.png
#   inflating: crop_512_r1_conv_dataset/images/31290_0000.png
#   inflating: crop_512_r1_conv_dataset/images/8402_0000.png
#   inflating: crop_512_r1_conv_dataset/images/8752_0003.png
#   inflating: crop_512_r1_conv_dataset/images/18426_0011.png
#   inflating: crop_512_r1_conv_dataset/images/5287_0004.png
#   inflating: crop_512_r1_conv_dataset/images/31571_0005.png
#   inflating: crop_512_r1_conv_dataset/images/4412_0008.png
#   inflating: crop_512_r1_conv_dataset/images/27350_0006.png
#   inflating: crop_512_r1_conv_dataset/images/16149_0007.png
#   inflating: crop_512_r1_conv_dataset/images/6121_0003.png
#   inflating: crop_512_r1_conv_dataset/images/8876_0008.png
#   inflating: crop_512_r1_conv_dataset/images/2696_0009.png
#   inflating: crop_512_r1_conv_dataset/images/8116_0014.png
#   inflating: crop_512_r1_conv_dataset/images/16149_0015.png
#   inflating: crop_512_r1_conv_dataset/images/11890_0009.png
#   inflating: crop_512_r1_conv_dataset/images/29143_0010.png
#   inflating: crop_512_r1_conv_dataset/images/18777_0009.png
#   inflating: crop_512_r1_conv_dataset/images/16362_0001.png
#   inflating: crop_512_r1_conv_dataset/images/10666_0010.png
#   inflating: crop_512_r1_conv_dataset/images/23094_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4802_0010.png
#   inflating: crop_512_r1_conv_dataset/images/30581_0011.png
#   inflating: crop_512_r1_conv_dataset/images/32325_0003.png
#   inflating: crop_512_r1_conv_dataset/images/29213_0001.png
#   inflating: crop_512_r1_conv_dataset/images/351_0003.png
#   inflating: crop_512_r1_conv_dataset/images/2874_0010.png
#   inflating: crop_512_r1_conv_dataset/images/1220_0014.png
#   inflating: crop_512_r1_conv_dataset/images/25430_0015.png
#   inflating: crop_512_r1_conv_dataset/images/27587_0014.png
#   inflating: crop_512_r1_conv_dataset/images/24522_0007.png
#   inflating: crop_512_r1_conv_dataset/images/21039_0003.png
#   inflating: crop_512_r1_conv_dataset/images/15005_0003.png
#   inflating: crop_512_r1_conv_dataset/images/24782_0015.png
#   inflating: crop_512_r1_conv_dataset/images/16214_0002.png
#   inflating: crop_512_r1_conv_dataset/images/19084_0006.png
#   inflating: crop_512_r1_conv_dataset/images/21039_0009.png
#   inflating: crop_512_r1_conv_dataset/images/25516_0007.png
#   inflating: crop_512_r1_conv_dataset/images/5832_0006.png
#   inflating: crop_512_r1_conv_dataset/images/2344_0006.png
#   inflating: crop_512_r1_conv_dataset/images/4412_0014.png
#   inflating: crop_512_r1_conv_dataset/images/22236_0011.png
#   inflating: crop_512_r1_conv_dataset/images/15192_0015.png
#   inflating: crop_512_r1_conv_dataset/images/14407_0007.png
#   inflating: crop_512_r1_conv_dataset/images/22016_0003.png
#   inflating: crop_512_r1_conv_dataset/images/29180_0008.png
#   inflating: crop_512_r1_conv_dataset/images/25620_0000.png
#   inflating: crop_512_r1_conv_dataset/images/9517_0000.png
#   inflating: crop_512_r1_conv_dataset/images/4265_0006.png
#   inflating: crop_512_r1_conv_dataset/images/1690_0011.png
#   inflating: crop_512_r1_conv_dataset/images/26664_0005.png
#   inflating: crop_512_r1_conv_dataset/images/28791_0004.png
#   inflating: crop_512_r1_conv_dataset/images/9453_0001.png
#   inflating: crop_512_r1_conv_dataset/images/23009_0004.png
#   inflating: crop_512_r1_conv_dataset/images/11497_0015.png
#   inflating: crop_512_r1_conv_dataset/images/23094_0000.png
#   inflating: crop_512_r1_conv_dataset/images/25472_0010.png
#   inflating: crop_512_r1_conv_dataset/images/17143_0005.png
#   inflating: crop_512_r1_conv_dataset/images/27781_0013.png
#   inflating: crop_512_r1_conv_dataset/images/24222_0012.png
#   inflating: crop_512_r1_conv_dataset/images/1690_0002.png
#   inflating: crop_512_r1_conv_dataset/images/22718_0003.png
#   inflating: crop_512_r1_conv_dataset/images/8343_0011.png
#   inflating: crop_512_r1_conv_dataset/images/25472_0000.png
#   inflating: crop_512_r1_conv_dataset/images/9769_0012.png
#   inflating: crop_512_r1_conv_dataset/images/10992_0005.png
#   inflating: crop_512_r1_conv_dataset/images/21195_0008.png
#   inflating: crop_512_r1_conv_dataset/images/24194_0012.png
#   inflating: crop_512_r1_conv_dataset/images/2344_0004.png
#   inflating: crop_512_r1_conv_dataset/images/15860_0015.png
#   inflating: crop_512_r1_conv_dataset/images/8227_0015.png
#   inflating: crop_512_r1_conv_dataset/images/13189_0012.png
#   inflating: crop_512_r1_conv_dataset/images/20478_0013.png
#   inflating: crop_512_r1_conv_dataset/images/24097_0010.png
#   inflating: crop_512_r1_conv_dataset/images/26319_0008.png
#   inflating: crop_512_r1_conv_dataset/images/8231_0004.png
#   inflating: crop_512_r1_conv_dataset/images/5317_0007.png
#   inflating: crop_512_r1_conv_dataset/images/4062_0008.png
#   inflating: crop_512_r1_conv_dataset/images/12476_0011.png
#   inflating: crop_512_r1_conv_dataset/images/29424_0012.png
#   inflating: crop_512_r1_conv_dataset/images/21086_0007.png
#   inflating: crop_512_r1_conv_dataset/images/2174_0003.png
#   inflating: crop_512_r1_conv_dataset/images/928_0006.png
#   inflating: crop_512_r1_conv_dataset/images/30194_0014.png
#   inflating: crop_512_r1_conv_dataset/images/6120_0003.png
#   inflating: crop_512_r1_conv_dataset/images/30876_0012.png
#   inflating: crop_512_r1_conv_dataset/images/22995_0006.png
#   inflating: crop_512_r1_conv_dataset/images/32231_0010.png
#   inflating: crop_512_r1_conv_dataset/images/4561_0007.png
#   inflating: crop_512_r1_conv_dataset/images/9517_0013.png
#   inflating: crop_512_r1_conv_dataset/images/660_0003.png
#   inflating: crop_512_r1_conv_dataset/images/17828_0007.png
#   inflating: crop_512_r1_conv_dataset/images/1878_0013.png
#   inflating: crop_512_r1_conv_dataset/images/22035_0001.png
#   inflating: crop_512_r1_conv_dataset/images/29213_0012.png
#   inflating: crop_512_r1_conv_dataset/images/5583_0009.png
#   inflating: crop_512_r1_conv_dataset/images/8638_0010.png
#   inflating: crop_512_r1_conv_dataset/images/20247_0000.png
#   inflating: crop_512_r1_conv_dataset/images/19048_0004.png
#   inflating: crop_512_r1_conv_dataset/images/13942_0015.png
#   inflating: crop_512_r1_conv_dataset/images/23665_0005.png
#   inflating: crop_512_r1_conv_dataset/images/27587_0001.png
#   inflating: crop_512_r1_conv_dataset/images/9437_0013.png
#   inflating: crop_512_r1_conv_dataset/images/15192_0010.png
#   inflating: crop_512_r1_conv_dataset/images/31958_0007.png
#   inflating: crop_512_r1_conv_dataset/images/1690_0012.png
#   inflating: crop_512_r1_conv_dataset/images/16609_0012.png
#   inflating: crop_512_r1_conv_dataset/images/24522_0012.png
#   inflating: crop_512_r1_conv_dataset/images/6611_0013.png
#   inflating: crop_512_r1_conv_dataset/images/3409_0006.png
#   inflating: crop_512_r1_conv_dataset/images/31727_0003.png
#   inflating: crop_512_r1_conv_dataset/images/28045_0008.png
#   inflating: crop_512_r1_conv_dataset/images/16564_0010.png
#   inflating: crop_512_r1_conv_dataset/images/9791_0000.png
#   inflating: crop_512_r1_conv_dataset/images/22133_0014.png
#   inflating: crop_512_r1_conv_dataset/images/10610_0005.png
#   inflating: crop_512_r1_conv_dataset/images/22035_0005.png
#   inflating: crop_512_r1_conv_dataset/images/10610_0008.png
#   inflating: crop_512_r1_conv_dataset/images/9453_0015.png
#   inflating: crop_512_r1_conv_dataset/images/14183_0012.png
#   inflating: crop_512_r1_conv_dataset/images/7902_0015.png
#   inflating: crop_512_r1_conv_dataset/images/18121_0015.png
#   inflating: crop_512_r1_conv_dataset/images/22016_0015.png
#   inflating: crop_512_r1_conv_dataset/images/6722_0014.png
#   inflating: crop_512_r1_conv_dataset/images/16362_0012.png
#   inflating: crop_512_r1_conv_dataset/images/6120_0007.png
#   inflating: crop_512_r1_conv_dataset/images/28622_0015.png
#   inflating: crop_512_r1_conv_dataset/images/17143_0014.png
#   inflating: crop_512_r1_conv_dataset/images/21195_0009.png
#   inflating: crop_512_r1_conv_dataset/images/32325_0001.png
#   inflating: crop_512_r1_conv_dataset/images/7569_0000.png
#   inflating: crop_512_r1_conv_dataset/images/24100_0001.png
#   inflating: crop_512_r1_conv_dataset/images/24100_0010.png
#   inflating: crop_512_r1_conv_dataset/images/32412_0015.png
#   inflating: crop_512_r1_conv_dataset/images/26174_0006.png
#   inflating: crop_512_r1_conv_dataset/images/6722_0005.png
#   inflating: crop_512_r1_conv_dataset/images/21501_0009.png
#   inflating: crop_512_r1_conv_dataset/images/4066_0007.png
#   inflating: crop_512_r1_conv_dataset/images/2174_0009.png
#   inflating: crop_512_r1_conv_dataset/images/12483_0002.png
#   inflating: crop_512_r1_conv_dataset/images/11448_0005.png
#   inflating: crop_512_r1_conv_dataset/images/2874_0009.png
#   inflating: crop_512_r1_conv_dataset/images/19569_0006.png
#   inflating: crop_512_r1_conv_dataset/images/10971_0013.png
#   inflating: crop_512_r1_conv_dataset/images/13483_0013.png
#   inflating: crop_512_r1_conv_dataset/images/28052_0014.png
#   inflating: crop_512_r1_conv_dataset/images/8752_0000.png
#   inflating: crop_512_r1_conv_dataset/images/20428_0004.png
#   inflating: crop_512_r1_conv_dataset/images/17828_0010.png
#   inflating: crop_512_r1_conv_dataset/images/30424_0003.png
#   inflating: crop_512_r1_conv_dataset/images/20247_0014.png
#   inflating: crop_512_r1_conv_dataset/images/2668_0012.png
#   inflating: crop_512_r1_conv_dataset/images/22236_0004.png
#   inflating: crop_512_r1_conv_dataset/images/26780_0009.png
#   inflating: crop_512_r1_conv_dataset/images/30474_0008.png
#   inflating: crop_512_r1_conv_dataset/images/686_0012.png
#   inflating: crop_512_r1_conv_dataset/images/15551_0002.png
#   inflating: crop_512_r1_conv_dataset/images/28622_0011.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0009.png
#   inflating: crop_512_r1_conv_dataset/images/13396_0000.png
#   inflating: crop_512_r1_conv_dataset/images/12784_0002.png
#   inflating: crop_512_r1_conv_dataset/images/29180_0009.png
#   inflating: crop_512_r1_conv_dataset/images/24097_0013.png
#   inflating: crop_512_r1_conv_dataset/images/3303_0010.png
#   inflating: crop_512_r1_conv_dataset/images/20520_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4062_0002.png
#   inflating: crop_512_r1_conv_dataset/images/8402_0002.png
#   inflating: crop_512_r1_conv_dataset/images/24522_0005.png
#   inflating: crop_512_r1_conv_dataset/images/14407_0014.png
#   inflating: crop_512_r1_conv_dataset/images/19360_0003.png
#   inflating: crop_512_r1_conv_dataset/images/30201_0003.png
#   inflating: crop_512_r1_conv_dataset/images/1220_0011.png
#   inflating: crop_512_r1_conv_dataset/images/29238_0013.png
#   inflating: crop_512_r1_conv_dataset/images/20440_0005.png
#   inflating: crop_512_r1_conv_dataset/images/15499_0001.png
#   inflating: crop_512_r1_conv_dataset/images/5583_0014.png
#   inflating: crop_512_r1_conv_dataset/images/23760_0006.png
#   inflating: crop_512_r1_conv_dataset/images/21812_0009.png
#   inflating: crop_512_r1_conv_dataset/images/62_0001.png
#   inflating: crop_512_r1_conv_dataset/images/2424_0007.png
#   inflating: crop_512_r1_conv_dataset/images/30201_0001.png
#   inflating: crop_512_r1_conv_dataset/images/29296_0002.png
#   inflating: crop_512_r1_conv_dataset/images/18121_0007.png
#   inflating: crop_512_r1_conv_dataset/images/1157_0003.png
#   inflating: crop_512_r1_conv_dataset/images/15787_0015.png
#   inflating: crop_512_r1_conv_dataset/images/20955_0007.png
#   inflating: crop_512_r1_conv_dataset/images/29424_0015.png
#   inflating: crop_512_r1_conv_dataset/images/27781_0012.png
#   inflating: crop_512_r1_conv_dataset/images/15860_0012.png
#   inflating: crop_512_r1_conv_dataset/images/6611_0004.png
#   inflating: crop_512_r1_conv_dataset/images/23760_0015.png
#   inflating: crop_512_r1_conv_dataset/images/22133_0005.png
#   inflating: crop_512_r1_conv_dataset/images/1690_0007.png
#   inflating: crop_512_r1_conv_dataset/images/4802_0015.png
#   inflating: crop_512_r1_conv_dataset/images/6121_0004.png
#   inflating: crop_512_r1_conv_dataset/images/3083_0000.png
#   inflating: crop_512_r1_conv_dataset/images/12471_0010.png
#   inflating: crop_512_r1_conv_dataset/images/12174_0009.png
#   inflating: crop_512_r1_conv_dataset/images/1123_0013.png
#   inflating: crop_512_r1_conv_dataset/images/24782_0002.png
#   inflating: crop_512_r1_conv_dataset/images/6318_0010.png
#   inflating: crop_512_r1_conv_dataset/images/25689_0006.png
#   inflating: crop_512_r1_conv_dataset/images/30224_0009.png
#   inflating: crop_512_r1_conv_dataset/images/6318_0013.png
#   inflating: crop_512_r1_conv_dataset/images/30474_0013.png
#   inflating: crop_512_r1_conv_dataset/images/15067_0012.png
#   inflating: crop_512_r1_conv_dataset/images/23665_0013.png
#   inflating: crop_512_r1_conv_dataset/images/19997_0003.png
#   inflating: crop_512_r1_conv_dataset/images/31958_0006.png
#   inflating: crop_512_r1_conv_dataset/images/22133_0008.png
#   inflating: crop_512_r1_conv_dataset/images/11064_0006.png
#   inflating: crop_512_r1_conv_dataset/images/2079_0002.png
#   inflating: crop_512_r1_conv_dataset/images/28963_0001.png
#   inflating: crop_512_r1_conv_dataset/images/28436_0003.png
#   inflating: crop_512_r1_conv_dataset/images/4777_0001.png
#   inflating: crop_512_r1_conv_dataset/images/9453_0002.png
#   inflating: crop_512_r1_conv_dataset/images/164_0010.png
#   inflating: crop_512_r1_conv_dataset/images/26319_0006.png
#   inflating: crop_512_r1_conv_dataset/images/20302_0004.png
#   inflating: crop_512_r1_conv_dataset/images/21321_0015.png
#   inflating: crop_512_r1_conv_dataset/images/29223_0002.png
#   inflating: crop_512_r1_conv_dataset/images/11662_0009.png
#   inflating: crop_512_r1_conv_dataset/images/16659_0007.png
#   inflating: crop_512_r1_conv_dataset/images/19179_0004.png
#   inflating: crop_512_r1_conv_dataset/images/676_0010.png
#   inflating: crop_512_r1_conv_dataset/images/27350_0001.png
#   inflating: crop_512_r1_conv_dataset/images/20831_0012.png
#   inflating: crop_512_r1_conv_dataset/images/23828_0006.png
#   inflating: crop_512_r1_conv_dataset/images/30080_0003.png
#   inflating: crop_512_r1_conv_dataset/images/2424_0015.png
#   inflating: crop_512_r1_conv_dataset/images/8638_0007.png
#   inflating: crop_512_r1_conv_dataset/images/29213_0002.png
#   inflating: crop_512_r1_conv_dataset/images/16214_0011.png
#   inflating: crop_512_r1_conv_dataset/images/28748_0012.png
#   inflating: crop_512_r1_conv_dataset/images/10892_0005.png
#   inflating: crop_512_r1_conv_dataset/images/4561_0014.png
#   inflating: crop_512_r1_conv_dataset/images/4658_0011.png
#   inflating: crop_512_r1_conv_dataset/images/3083_0009.png
#   inflating: crop_512_r1_conv_dataset/images/21086_0002.png
#   inflating: crop_512_r1_conv_dataset/images/3959_0007.png
#   inflating: crop_512_r1_conv_dataset/images/18445_0001.png
#   inflating: crop_512_r1_conv_dataset/images/28262_0000.png
#   inflating: crop_512_r1_conv_dataset/images/12174_0004.png
#   inflating: crop_512_r1_conv_dataset/images/32527_0003.png
#   inflating: crop_512_r1_conv_dataset/images/28963_0010.png
#   inflating: crop_512_r1_conv_dataset/images/7359_0002.png
#   inflating: crop_512_r1_conv_dataset/images/27803_0010.png
#   inflating: crop_512_r1_conv_dataset/images/20428_0015.png
#   inflating: crop_512_r1_conv_dataset/images/24782_0013.png
#   inflating: crop_512_r1_conv_dataset/images/2793_0009.png
#   inflating: crop_512_r1_conv_dataset/images/30080_0009.png
#   inflating: crop_512_r1_conv_dataset/images/32151_0010.png
#   inflating: crop_512_r1_conv_dataset/images/4944_0007.png
#   inflating: crop_512_r1_conv_dataset/images/7397_0011.png
#   inflating: crop_512_r1_conv_dataset/images/21155_0007.png
#   inflating: crop_512_r1_conv_dataset/images/10611_0008.png
#   inflating: crop_512_r1_conv_dataset/images/13942_0005.png
#   inflating: crop_512_r1_conv_dataset/images/928_0002.png
#   inflating: crop_512_r1_conv_dataset/images/3409_0010.png
#   inflating: crop_512_r1_conv_dataset/images/6318_0004.png
#   inflating: crop_512_r1_conv_dataset/images/16214_0000.png
#   inflating: crop_512_r1_conv_dataset/images/30294_0008.png
#   inflating: crop_512_r1_conv_dataset/images/164_0000.png
#   inflating: crop_512_r1_conv_dataset/images/28963_0000.png
#   inflating: crop_512_r1_conv_dataset/images/29690_0007.png
#   inflating: crop_512_r1_conv_dataset/images/12452_0013.png
#   inflating: crop_512_r1_conv_dataset/images/31675_0006.png
#   inflating: crop_512_r1_conv_dataset/images/23665_0014.png
#   inflating: crop_512_r1_conv_dataset/images/25516_0005.png
#   inflating: crop_512_r1_conv_dataset/images/28318_0014.png
#   inflating: crop_512_r1_conv_dataset/images/8116_0015.png
#   inflating: crop_512_r1_conv_dataset/images/28126_0007.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0000.png
#   inflating: crop_512_r1_conv_dataset/images/1690_0005.png
#   inflating: crop_512_r1_conv_dataset/images/8343_0001.png
#   inflating: crop_512_r1_conv_dataset/images/29307_0015.png
#   inflating: crop_512_r1_conv_dataset/images/23959_0008.png
#   inflating: crop_512_r1_conv_dataset/images/19179_0014.png
#   inflating: crop_512_r1_conv_dataset/images/25298_0007.png
#   inflating: crop_512_r1_conv_dataset/images/12244_0014.png
#   inflating: crop_512_r1_conv_dataset/images/6121_0005.png
#   inflating: crop_512_r1_conv_dataset/images/8502_0013.png
#   inflating: crop_512_r1_conv_dataset/images/15732_0007.png
#   inflating: crop_512_r1_conv_dataset/images/24269_0000.png
#   inflating: crop_512_r1_conv_dataset/images/8402_0003.png
#   inflating: crop_512_r1_conv_dataset/images/2793_0008.png
#   inflating: crop_512_r1_conv_dataset/images/15192_0011.png
#   inflating: crop_512_r1_conv_dataset/images/17187_0011.png
#   inflating: crop_512_r1_conv_dataset/images/5287_0006.png
#   inflating: crop_512_r1_conv_dataset/images/27468_0009.png
#   inflating: crop_512_r1_conv_dataset/images/1157_0012.png
#   inflating: crop_512_r1_conv_dataset/images/24100_0002.png
#   inflating: crop_512_r1_conv_dataset/images/8227_0014.png
#   inflating: crop_512_r1_conv_dataset/images/23880_0010.png
#   inflating: crop_512_r1_conv_dataset/images/17455_0003.png
#   inflating: crop_512_r1_conv_dataset/images/24782_0009.png
#   inflating: crop_512_r1_conv_dataset/images/30414_0006.png
#   inflating: crop_512_r1_conv_dataset/images/7569_0004.png
#   inflating: crop_512_r1_conv_dataset/images/14388_0010.png
#   inflating: crop_512_r1_conv_dataset/images/15842_0009.png
#   inflating: crop_512_r1_conv_dataset/images/29424_0014.png
#   inflating: crop_512_r1_conv_dataset/images/26480_0004.png
#   inflating: crop_512_r1_conv_dataset/images/17455_0014.png
#   inflating: crop_512_r1_conv_dataset/images/30414_0000.png
#   inflating: crop_512_r1_conv_dataset/images/9445_0000.png
#   inflating: crop_512_r1_conv_dataset/images/2943_0006.png
#   inflating: crop_512_r1_conv_dataset/images/28318_0008.png
#   inflating: crop_512_r1_conv_dataset/images/31139_0007.png
#   inflating: crop_512_r1_conv_dataset/images/18401_0011.png
#   inflating: crop_512_r1_conv_dataset/images/28429_0015.png
#   inflating: crop_512_r1_conv_dataset/images/28045_0010.png
#   inflating: crop_512_r1_conv_dataset/images/24833_0015.png
#   inflating: crop_512_r1_conv_dataset/images/8502_0009.png
#   inflating: crop_512_r1_conv_dataset/images/1184_0006.png
#   inflating: crop_512_r1_conv_dataset/images/9407_0009.png
#   inflating: crop_512_r1_conv_dataset/images/22741_0008.png
#   inflating: crop_512_r1_conv_dataset/images/4301_0011.png
#   inflating: crop_512_r1_conv_dataset/images/16163_0015.png
#   inflating: crop_512_r1_conv_dataset/images/4066_0006.png
#   inflating: crop_512_r1_conv_dataset/images/28940_0004.png
#   inflating: crop_512_r1_conv_dataset/images/4301_0007.png
#   inflating: crop_512_r1_conv_dataset/images/21086_0001.png
#   inflating: crop_512_r1_conv_dataset/images/1168_0009.png
#   inflating: crop_512_r1_conv_dataset/images/435_0014.png
#   inflating: crop_512_r1_conv_dataset/images/15842_0000.png
#   inflating: crop_512_r1_conv_dataset/images/11448_0010.png
#   inflating: crop_512_r1_conv_dataset/images/127_0010.png
#   inflating: crop_512_r1_conv_dataset/images/19507_0001.png
#   inflating: crop_512_r1_conv_dataset/images/10651_0010.png
#   inflating: crop_512_r1_conv_dataset/images/4776_0010.png
#   inflating: crop_512_r1_conv_dataset/images/2079_0010.png
#   inflating: crop_512_r1_conv_dataset/images/32009_0012.png
#   inflating: crop_512_r1_conv_dataset/images/5777_0009.png
#   inflating: crop_512_r1_conv_dataset/images/12233_0009.png
#   inflating: crop_512_r1_conv_dataset/images/5832_0009.png
#   inflating: crop_512_r1_conv_dataset/images/30581_0001.png
#   inflating: crop_512_r1_conv_dataset/images/1157_0015.png
#   inflating: crop_512_r1_conv_dataset/images/30394_0012.png
#   inflating: crop_512_r1_conv_dataset/images/2424_0013.png
#   inflating: crop_512_r1_conv_dataset/images/28940_0013.png
#   inflating: crop_512_r1_conv_dataset/images/31898_0002.png
#   inflating: crop_512_r1_conv_dataset/images/5317_0005.png
#   inflating: crop_512_r1_conv_dataset/images/22236_0009.png
#   inflating: crop_512_r1_conv_dataset/images/12174_0008.png
#   inflating: crop_512_r1_conv_dataset/images/11629_0015.png
#   inflating: crop_512_r1_conv_dataset/images/7359_0004.png
#   inflating: crop_512_r1_conv_dataset/images/31958_0010.png
#   inflating: crop_512_r1_conv_dataset/images/22995_0014.png
#   inflating: crop_512_r1_conv_dataset/images/28963_0007.png
#   inflating: crop_512_r1_conv_dataset/images/5583_0005.png
#   inflating: crop_512_r1_conv_dataset/images/1878_0006.png
#   inflating: crop_512_r1_conv_dataset/images/23961_0012.png
#   inflating: crop_512_r1_conv_dataset/images/9445_0010.png
#   inflating: crop_512_r1_conv_dataset/images/1229_0007.png
#   inflating: crop_512_r1_conv_dataset/images/21129_0001.png
#   inflating: crop_512_r1_conv_dataset/images/27616_0002.png
#   inflating: crop_512_r1_conv_dataset/images/21812_0003.png
#   inflating: crop_512_r1_conv_dataset/images/27616_0005.png
#   inflating: crop_512_r1_conv_dataset/images/29223_0011.png
#   inflating: crop_512_r1_conv_dataset/images/16728_0003.png
#   inflating: crop_512_r1_conv_dataset/images/6730_0003.png
#   inflating: crop_512_r1_conv_dataset/images/31571_0001.png
#   inflating: crop_512_r1_conv_dataset/images/12466_0002.png
#   inflating: crop_512_r1_conv_dataset/images/31675_0013.png
#   inflating: crop_512_r1_conv_dataset/images/737_0012.png
#   inflating: crop_512_r1_conv_dataset/images/10044_0011.png
#   inflating: crop_512_r1_conv_dataset/images/21155_0000.png
#   inflating: crop_512_r1_conv_dataset/images/16890_0014.png
#   inflating: crop_512_r1_conv_dataset/images/28189_0009.png
#   inflating: crop_512_r1_conv_dataset/images/9450_0014.png
#   inflating: crop_512_r1_conv_dataset/images/29307_0008.png
#   inflating: crop_512_r1_conv_dataset/images/8402_0007.png
#   inflating: crop_512_r1_conv_dataset/images/16216_0003.png
#   inflating: crop_512_r1_conv_dataset/images/29223_0009.png
#   inflating: crop_512_r1_conv_dataset/images/10971_0008.png
#   inflating: crop_512_r1_conv_dataset/images/31139_0009.png
#   inflating: crop_512_r1_conv_dataset/images/144_0007.png
#   inflating: crop_512_r1_conv_dataset/images/28052_0008.png
#   inflating: crop_512_r1_conv_dataset/images/30474_0000.png
#   inflating: crop_512_r1_conv_dataset/images/8116_0007.png
#   inflating: crop_512_r1_conv_dataset/images/30876_0010.png
#   inflating: crop_512_r1_conv_dataset/images/5102_0008.png
#   inflating: crop_512_r1_conv_dataset/images/30080_0005.png
#   inflating: crop_512_r1_conv_dataset/images/30765_0002.png
#   inflating: crop_512_r1_conv_dataset/images/24222_0009.png
#   inflating: crop_512_r1_conv_dataset/images/4944_0008.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0007.png
#   inflating: crop_512_r1_conv_dataset/images/18792_0002.png
#   inflating: crop_512_r1_conv_dataset/images/6390_0000.png
#   inflating: crop_512_r1_conv_dataset/images/26982_0012.png
#   inflating: crop_512_r1_conv_dataset/images/6121_0000.png
#   inflating: crop_512_r1_conv_dataset/images/12476_0004.png
#   inflating: crop_512_r1_conv_dataset/images/23252_0011.png
#   inflating: crop_512_r1_conv_dataset/images/28262_0015.png
#   inflating: crop_512_r1_conv_dataset/images/435_0011.png
#   inflating: crop_512_r1_conv_dataset/images/10992_0008.png
#   inflating: crop_512_r1_conv_dataset/images/28045_0003.png
#   inflating: crop_512_r1_conv_dataset/images/23009_0010.png
#   inflating: crop_512_r1_conv_dataset/images/31727_0008.png
#   inflating: crop_512_r1_conv_dataset/images/21358_0006.png
#   inflating: crop_512_r1_conv_dataset/images/19179_0015.png
#   inflating: crop_512_r1_conv_dataset/images/10610_0010.png
#   inflating: crop_512_r1_conv_dataset/images/31733_0000.png
#   inflating: crop_512_r1_conv_dataset/images/24269_0006.png
#   inflating: crop_512_r1_conv_dataset/images/164_0007.png
#   inflating: crop_512_r1_conv_dataset/images/26174_0000.png
#   inflating: crop_512_r1_conv_dataset/images/32009_0004.png
#   inflating: crop_512_r1_conv_dataset/images/31958_0011.png
#   inflating: crop_512_r1_conv_dataset/images/28748_0000.png
#   inflating: crop_512_r1_conv_dataset/images/12244_0006.png
#   inflating: crop_512_r1_conv_dataset/images/28823_0007.png
#   inflating: crop_512_r1_conv_dataset/images/19179_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4265_0010.png
#   inflating: crop_512_r1_conv_dataset/images/9777_0014.png
#   inflating: crop_512_r1_conv_dataset/images/29424_0004.png
#   inflating: crop_512_r1_conv_dataset/images/30876_0007.png
#   inflating: crop_512_r1_conv_dataset/images/6611_0007.png
#   inflating: crop_512_r1_conv_dataset/images/23760_0013.png
#   inflating: crop_512_r1_conv_dataset/images/17126_0009.png
#   inflating: crop_512_r1_conv_dataset/images/8638_0004.png
#   inflating: crop_512_r1_conv_dataset/images/16362_0015.png
#   inflating: crop_512_r1_conv_dataset/images/15067_0008.png
#   inflating: crop_512_r1_conv_dataset/images/30394_0007.png
#   inflating: crop_512_r1_conv_dataset/images/14388_0009.png
#   inflating: crop_512_r1_conv_dataset/images/25689_0010.png
#   inflating: crop_512_r1_conv_dataset/images/6120_0014.png
#   inflating: crop_512_r1_conv_dataset/images/30201_0006.png
#   inflating: crop_512_r1_conv_dataset/images/15067_0006.png
#   inflating: crop_512_r1_conv_dataset/images/23760_0009.png
#   inflating: crop_512_r1_conv_dataset/images/24833_0009.png
#   inflating: crop_512_r1_conv_dataset/images/28189_0007.png
#   inflating: crop_512_r1_conv_dataset/images/15005_0000.png
#   inflating: crop_512_r1_conv_dataset/images/1220_0009.png
#   inflating: crop_512_r1_conv_dataset/images/22236_0008.png
#   inflating: crop_512_r1_conv_dataset/images/29809_0006.png
#   inflating: crop_512_r1_conv_dataset/images/8388_0008.png
#   inflating: crop_512_r1_conv_dataset/images/21195_0011.png
#   inflating: crop_512_r1_conv_dataset/images/12827_0004.png
#   inflating: crop_512_r1_conv_dataset/images/11629_0008.png
#   inflating: crop_512_r1_conv_dataset/images/4265_0014.png
#   inflating: crop_512_r1_conv_dataset/images/23051_0000.png
#   inflating: crop_512_r1_conv_dataset/images/928_0011.png
#   inflating: crop_512_r1_conv_dataset/images/27128_0011.png
#   inflating: crop_512_r1_conv_dataset/images/19997_0006.png
#   inflating: crop_512_r1_conv_dataset/images/12174_0012.png
#   inflating: crop_512_r1_conv_dataset/images/2943_0014.png
#   inflating: crop_512_r1_conv_dataset/images/14396_0007.png
#   inflating: crop_512_r1_conv_dataset/images/1157_0007.png
#   inflating: crop_512_r1_conv_dataset/images/12244_0007.png
#   inflating: crop_512_r1_conv_dataset/images/31799_0006.png
#   inflating: crop_512_r1_conv_dataset/images/15732_0003.png
#   inflating: crop_512_r1_conv_dataset/images/28126_0009.png
#   inflating: crop_512_r1_conv_dataset/images/16890_0012.png
#   inflating: crop_512_r1_conv_dataset/images/5287_0000.png
#   inflating: crop_512_r1_conv_dataset/images/2424_0011.png
#   inflating: crop_512_r1_conv_dataset/images/26319_0003.png
#   inflating: crop_512_r1_conv_dataset/images/27879_0000.png
#   inflating: crop_512_r1_conv_dataset/images/21039_0010.png
#   inflating: crop_512_r1_conv_dataset/images/1500_0014.png
#   inflating: crop_512_r1_conv_dataset/images/30876_0013.png
#   inflating: crop_512_r1_conv_dataset/images/7169_0004.png
#   inflating: crop_512_r1_conv_dataset/images/31799_0007.png
#   inflating: crop_512_r1_conv_dataset/images/23828_0009.png
#   inflating: crop_512_r1_conv_dataset/images/15732_0000.png
#   inflating: crop_512_r1_conv_dataset/images/8638_0012.png
#   inflating: crop_512_r1_conv_dataset/images/19507_0005.png
#   inflating: crop_512_r1_conv_dataset/images/14407_0010.png
#   inflating: crop_512_r1_conv_dataset/images/30581_0005.png
#   inflating: crop_512_r1_conv_dataset/images/30765_0000.png
#   inflating: crop_512_r1_conv_dataset/images/16711_0006.png
#   inflating: crop_512_r1_conv_dataset/images/2500_0002.png
#   inflating: crop_512_r1_conv_dataset/images/6730_0007.png
#   inflating: crop_512_r1_conv_dataset/images/25516_0008.png
#   inflating: crop_512_r1_conv_dataset/images/21812_0000.png
#   inflating: crop_512_r1_conv_dataset/images/5785_0008.png
#   inflating: crop_512_r1_conv_dataset/images/2279_0011.png
#   inflating: crop_512_r1_conv_dataset/images/23961_0011.png
#   inflating: crop_512_r1_conv_dataset/images/19377_0010.png
#   inflating: crop_512_r1_conv_dataset/images/17143_0013.png
#   inflating: crop_512_r1_conv_dataset/images/1731_0007.png
#   inflating: crop_512_r1_conv_dataset/images/19048_0000.png
#   inflating: crop_512_r1_conv_dataset/images/25620_0015.png
#   inflating: crop_512_r1_conv_dataset/images/5099_0009.png
#   inflating: crop_512_r1_conv_dataset/images/28823_0009.png
#   inflating: crop_512_r1_conv_dataset/images/28429_0001.png
#   inflating: crop_512_r1_conv_dataset/images/8151_0005.png
#   inflating: crop_512_r1_conv_dataset/images/13483_0014.png
#   inflating: crop_512_r1_conv_dataset/images/1878_0012.png
#   inflating: crop_512_r1_conv_dataset/images/30194_0010.png
#   inflating: crop_512_r1_conv_dataset/images/16711_0000.png
#   inflating: crop_512_r1_conv_dataset/images/22718_0006.png
#   inflating: crop_512_r1_conv_dataset/images/28318_0004.png
#   inflating: crop_512_r1_conv_dataset/images/13942_0008.png
#   inflating: crop_512_r1_conv_dataset/images/26319_0001.png
#   inflating: crop_512_r1_conv_dataset/images/6794_0009.png
#   inflating: crop_512_r1_conv_dataset/images/29307_0011.png
#   inflating: crop_512_r1_conv_dataset/images/6390_0015.png
#   inflating: crop_512_r1_conv_dataset/images/22236_0005.png
#   inflating: crop_512_r1_conv_dataset/images/26780_0007.png
#   inflating: crop_512_r1_conv_dataset/images/21155_0005.png
#   inflating: crop_512_r1_conv_dataset/images/18445_0014.png
#   inflating: crop_512_r1_conv_dataset/images/2793_0011.png
#   inflating: crop_512_r1_conv_dataset/images/10992_0010.png
#   inflating: crop_512_r1_conv_dataset/images/9904_0006.png
#   inflating: crop_512_r1_conv_dataset/images/13189_0006.png
#   inflating: crop_512_r1_conv_dataset/images/1731_0005.png
#   inflating: crop_512_r1_conv_dataset/images/14674_0001.png
#   inflating: crop_512_r1_conv_dataset/images/351_0005.png
#   inflating: crop_512_r1_conv_dataset/images/30394_0005.png
#   inflating: crop_512_r1_conv_dataset/images/8876_0010.png
#   inflating: crop_512_r1_conv_dataset/images/16609_0013.png
#   inflating: crop_512_r1_conv_dataset/images/28189_0000.png
#   inflating: crop_512_r1_conv_dataset/images/10666_0014.png
#   inflating: crop_512_r1_conv_dataset/images/5932_0006.png
#   inflating: crop_512_r1_conv_dataset/images/22310_0013.png
#   inflating: crop_512_r1_conv_dataset/images/27232_0003.png
#   inflating: crop_512_r1_conv_dataset/images/7970_0003.png
#   inflating: crop_512_r1_conv_dataset/images/28748_0007.png
#   inflating: crop_512_r1_conv_dataset/images/16362_0014.png
#   inflating: crop_512_r1_conv_dataset/images/21086_0004.png
#   inflating: crop_512_r1_conv_dataset/images/16216_0009.png
#   inflating: crop_512_r1_conv_dataset/images/25620_0004.png
#   inflating: crop_512_r1_conv_dataset/images/9231_0005.png
#   inflating: crop_512_r1_conv_dataset/images/27298_0015.png
#   inflating: crop_512_r1_conv_dataset/images/203_0008.png
#   inflating: crop_512_r1_conv_dataset/images/3054_0013.png
#   inflating: crop_512_r1_conv_dataset/images/4802_0005.png
#   inflating: crop_512_r1_conv_dataset/images/13507_0006.png
#   inflating: crop_512_r1_conv_dataset/images/29809_0012.png
#   inflating: crop_512_r1_conv_dataset/images/28748_0014.png
#   inflating: crop_512_r1_conv_dataset/images/3409_0003.png
#   inflating: crop_512_r1_conv_dataset/images/9450_0005.png
#   inflating: crop_512_r1_conv_dataset/images/5832_0011.png
#   inflating: crop_512_r1_conv_dataset/images/21195_0004.png
#   inflating: crop_512_r1_conv_dataset/images/22035_0000.png
#   inflating: crop_512_r1_conv_dataset/images/62_0008.png
#   inflating: crop_512_r1_conv_dataset/images/8222_0001.png
#   inflating: crop_512_r1_conv_dataset/images/5099_0006.png
#   inflating: crop_512_r1_conv_dataset/images/8876_0011.png
#   inflating: crop_512_r1_conv_dataset/images/17143_0003.png
#   inflating: crop_512_r1_conv_dataset/images/23640_0007.png
#   inflating: crop_512_r1_conv_dataset/images/4777_0007.png
#   inflating: crop_512_r1_conv_dataset/images/11497_0009.png
#   inflating: crop_512_r1_conv_dataset/images/6021_0000.png
#   inflating: crop_512_r1_conv_dataset/images/20520_0005.png
#   inflating: crop_512_r1_conv_dataset/images/15787_0014.png
#   inflating: crop_512_r1_conv_dataset/images/32325_0007.png
#   inflating: crop_512_r1_conv_dataset/images/23828_0014.png
#   inflating: crop_512_r1_conv_dataset/images/10044_0013.png
#   inflating: crop_512_r1_conv_dataset/images/16711_0001.png
#   inflating: crop_512_r1_conv_dataset/images/23959_0002.png
#   inflating: crop_512_r1_conv_dataset/images/9231_0001.png
#   inflating: crop_512_r1_conv_dataset/images/2079_0012.png
#   inflating: crop_512_r1_conv_dataset/images/2500_0010.png
#   inflating: crop_512_r1_conv_dataset/images/12483_0009.png
#   inflating: crop_512_r1_conv_dataset/images/12483_0011.png
#   inflating: crop_512_r1_conv_dataset/images/15551_0007.png
#   inflating: crop_512_r1_conv_dataset/images/19569_0015.png
#   inflating: crop_512_r1_conv_dataset/images/435_0010.png
#   inflating: crop_512_r1_conv_dataset/images/21501_0013.png
#   inflating: crop_512_r1_conv_dataset/images/435_0004.png
#   inflating: crop_512_r1_conv_dataset/images/25641_0007.png
#   inflating: crop_512_r1_conv_dataset/images/4802_0013.png
#   inflating: crop_512_r1_conv_dataset/images/7706_0009.png
#   inflating: crop_512_r1_conv_dataset/images/4301_0010.png
#   inflating: crop_512_r1_conv_dataset/images/16659_0014.png
#   inflating: crop_512_r1_conv_dataset/images/26886_0013.png
#   inflating: crop_512_r1_conv_dataset/images/15842_0010.png
#   inflating: crop_512_r1_conv_dataset/images/8638_0001.png
#   inflating: crop_512_r1_conv_dataset/images/24522_0011.png
#   inflating: crop_512_r1_conv_dataset/images/14388_0004.png
#   inflating: crop_512_r1_conv_dataset/images/9407_0010.png
#   inflating: crop_512_r1_conv_dataset/images/32231_0000.png
#   inflating: crop_512_r1_conv_dataset/images/31733_0009.png
#   inflating: crop_512_r1_conv_dataset/images/2793_0000.png
#   inflating: crop_512_r1_conv_dataset/images/21195_0001.png
#   inflating: crop_512_r1_conv_dataset/images/8222_0012.png
#   inflating: crop_512_r1_conv_dataset/images/19048_0014.png
#   inflating: crop_512_r1_conv_dataset/images/30080_0000.png
#   inflating: crop_512_r1_conv_dataset/images/1157_0009.png
#   inflating: crop_512_r1_conv_dataset/images/1878_0007.png
#   inflating: crop_512_r1_conv_dataset/images/9407_0001.png
#   inflating: crop_512_r1_conv_dataset/images/1229_0012.png
#   inflating: crop_512_r1_conv_dataset/images/6021_0015.png
#   inflating: crop_512_r1_conv_dataset/images/22544_0013.png
#   inflating: crop_512_r1_conv_dataset/images/15860_0010.png
#   inflating: crop_512_r1_conv_dataset/images/10892_0006.png
#   inflating: crop_512_r1_conv_dataset/images/28622_0006.png
#   inflating: crop_512_r1_conv_dataset/images/30414_0008.png
#   inflating: crop_512_r1_conv_dataset/images/24782_0001.png
#   inflating: crop_512_r1_conv_dataset/images/13396_0003.png
#   inflating: crop_512_r1_conv_dataset/images/928_0007.png
#   inflating: crop_512_r1_conv_dataset/images/30581_0010.png
#   inflating: crop_512_r1_conv_dataset/images/29296_0005.png
#   inflating: crop_512_r1_conv_dataset/images/13507_0001.png
#   inflating: crop_512_r1_conv_dataset/images/20247_0008.png
#   inflating: crop_512_r1_conv_dataset/images/203_0007.png
#   inflating: crop_512_r1_conv_dataset/images/16214_0004.png
#   inflating: crop_512_r1_conv_dataset/images/23094_0012.png
#   inflating: crop_512_r1_conv_dataset/images/22310_0006.png
#   inflating: crop_512_r1_conv_dataset/images/7397_0003.png
#   inflating: crop_512_r1_conv_dataset/images/18426_0010.png
#   inflating: crop_512_r1_conv_dataset/images/12026_0008.png
#   inflating: crop_512_r1_conv_dataset/images/9791_0010.png
#   inflating: crop_512_r1_conv_dataset/images/676_0008.png
#   inflating: crop_512_r1_conv_dataset/images/20563_0009.png
#   inflating: crop_512_r1_conv_dataset/images/3054_0015.png
#   inflating: crop_512_r1_conv_dataset/images/11064_0002.png
#   inflating: crop_512_r1_conv_dataset/images/28262_0013.png
#   inflating: crop_512_r1_conv_dataset/images/30355_0003.png
#   inflating: crop_512_r1_conv_dataset/images/9407_0005.png
#   inflating: crop_512_r1_conv_dataset/images/20563_0000.png
#   inflating: crop_512_r1_conv_dataset/images/22953_0011.png
#   inflating: crop_512_r1_conv_dataset/images/10992_0009.png
#   inflating: crop_512_r1_conv_dataset/images/8842_0006.png
#   inflating: crop_512_r1_conv_dataset/images/7169_0011.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0015.png
#   inflating: crop_512_r1_conv_dataset/images/10703_0002.png
#   inflating: crop_512_r1_conv_dataset/images/27468_0006.png
#   inflating: crop_512_r1_conv_dataset/images/8227_0009.png
#   inflating: crop_512_r1_conv_dataset/images/12476_0006.png
#   inflating: crop_512_r1_conv_dataset/images/14674_0009.png
#   inflating: crop_512_r1_conv_dataset/images/6390_0002.png
#   inflating: crop_512_r1_conv_dataset/images/8343_0014.png
#   inflating: crop_512_r1_conv_dataset/images/30424_0013.png
#   inflating: crop_512_r1_conv_dataset/images/14388_0000.png
#   inflating: crop_512_r1_conv_dataset/images/12466_0000.png
#   inflating: crop_512_r1_conv_dataset/images/5099_0002.png
#   inflating: crop_512_r1_conv_dataset/images/23959_0009.png
#   inflating: crop_512_r1_conv_dataset/images/10912_0014.png
#   inflating: crop_512_r1_conv_dataset/images/17422_0005.png
#   inflating: crop_512_r1_conv_dataset/images/6611_0008.png
#   inflating: crop_512_r1_conv_dataset/images/5785_0004.png
#   inflating: crop_512_r1_conv_dataset/images/27803_0005.png
#   inflating: crop_512_r1_conv_dataset/images/32231_0004.png
#   inflating: crop_512_r1_conv_dataset/images/737_0009.png
#   inflating: crop_512_r1_conv_dataset/images/15551_0015.png
#   inflating: crop_512_r1_conv_dataset/images/1123_0002.png
#   inflating: crop_512_r1_conv_dataset/images/27340_0002.png
#   inflating: crop_512_r1_conv_dataset/images/30250_0007.png
#   inflating: crop_512_r1_conv_dataset/images/27781_0006.png
#   inflating: crop_512_r1_conv_dataset/images/25945_0012.png
#   inflating: crop_512_r1_conv_dataset/images/127_0014.png
#   inflating: crop_512_r1_conv_dataset/images/12026_0007.png
#   inflating: crop_512_r1_conv_dataset/images/32412_0013.png
#   inflating: crop_512_r1_conv_dataset/images/23880_0013.png
#   inflating: crop_512_r1_conv_dataset/images/18401_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4658_0010.png
#   inflating: crop_512_r1_conv_dataset/images/21195_0000.png
#   inflating: crop_512_r1_conv_dataset/images/19084_0012.png
#   inflating: crop_512_r1_conv_dataset/images/16163_0000.png
#   inflating: crop_512_r1_conv_dataset/images/5932_0004.png
#   inflating: crop_512_r1_conv_dataset/images/21812_0004.png
#   inflating: crop_512_r1_conv_dataset/images/15499_0003.png
#   inflating: crop_512_r1_conv_dataset/images/4412_0011.png
#   inflating: crop_512_r1_conv_dataset/images/5086_0013.png
#   inflating: crop_512_r1_conv_dataset/images/737_0000.png
#   inflating: crop_512_r1_conv_dataset/images/9769_0010.png
#   inflating: crop_512_r1_conv_dataset/images/5102_0012.png
#   inflating: crop_512_r1_conv_dataset/images/7970_0001.png
#   inflating: crop_512_r1_conv_dataset/images/18426_0008.png
#   inflating: crop_512_r1_conv_dataset/images/32527_0012.png
#   inflating: crop_512_r1_conv_dataset/images/3054_0009.png
#   inflating: crop_512_r1_conv_dataset/images/19179_0002.png
#   inflating: crop_512_r1_conv_dataset/images/20440_0007.png
#   inflating: crop_512_r1_conv_dataset/images/20302_0012.png
#   inflating: crop_512_r1_conv_dataset/images/27616_0008.png
#   inflating: crop_512_r1_conv_dataset/images/14674_0011.png
#   inflating: crop_512_r1_conv_dataset/images/13483_0000.png
#   inflating: crop_512_r1_conv_dataset/images/5932_0014.png
#   inflating: crop_512_r1_conv_dataset/images/20478_0004.png
#   inflating: crop_512_r1_conv_dataset/images/16711_0003.png
#   inflating: crop_512_r1_conv_dataset/images/25430_0000.png
#   inflating: crop_512_r1_conv_dataset/images/6794_0012.png
#   inflating: crop_512_r1_conv_dataset/images/6021_0009.png
#   inflating: crop_512_r1_conv_dataset/images/4066_0009.png
#   inflating: crop_512_r1_conv_dataset/images/25689_0007.png
#   inflating: crop_512_r1_conv_dataset/images/31406_0008.png
#   inflating: crop_512_r1_conv_dataset/images/21501_0015.png
# ...
#   inflating: crop_512_r1_conv_dataset/images/203_0004.png
#   inflating: crop_512_r1_conv_dataset/images/4412_0009.png
#   inflating: crop_512_r1_conv_dataset/images/8151_0011.png
#   inflating: crop_512_r1_conv_dataset/images/15732_0010.png
#   inflating: crop_512_r1_conv_dataset/images/11064_0004.png
#   inflating: crop_512_r1_conv_dataset/images/1168_0010.png
#   inflating: crop_512_r1_conv_dataset/images/8450_0000.png
#   inflating: crop_512_r1_conv_dataset/images/23051_0009.png
#   inflating: crop_512_r1_conv_dataset/images/8842_0013.png
#   inflating: crop_512_r1_conv_dataset/images/20955_0013.png
#   inflating: crop_512_r1_conv_dataset/images/30424_0000.png
#   inflating: crop_512_r1_conv_dataset/images/29213_0003.png
#   inflating: crop_512_r1_conv_dataset/images/18422_0014.png
#   inflating: crop_512_r1_conv_dataset/images/17143_0001.png
#   inflating: crop_512_r1_conv_dataset/images/8116_0004.png
#   inflating: crop_512_r1_conv_dataset/images/18401_0002.png
#   inflating: crop_512_r1_conv_dataset/images/29296_0007.png
#   inflating: crop_512_r1_conv_dataset/images/20831_0006.png
#   inflating: crop_512_r1_conv_dataset/images/17126_0001.png
#   inflating: crop_512_r1_conv_dataset/images/8502_0014.png
#   inflating: crop_512_r1_conv_dataset/images/21812_0010.png
#   inflating: crop_512_r1_conv_dataset/images/10992_0003.png
#   inflating: crop_512_r1_conv_dataset/images/13942_0002.png
#   inflating: crop_512_r1_conv_dataset/images/29213_0015.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0012.png
#   inflating: crop_512_r1_conv_dataset/images/10611_0007.png
#   inflating: crop_512_r1_conv_dataset/images/30500_0000.png
#   inflating: crop_512_r1_conv_dataset/images/22995_0004.png
#   inflating: crop_512_r1_conv_dataset/images/27879_0004.png
#   inflating: crop_512_r1_conv_dataset/images/16609_0009.png
#   inflating: crop_512_r1_conv_dataset/images/30500_0010.png
#   inflating: crop_512_r1_conv_dataset/images/18422_0006.png
#   inflating: crop_512_r1_conv_dataset/images/20794_0003.png
#   inflating: crop_512_r1_conv_dataset/images/7169_0000.png
#   inflating: crop_512_r1_conv_dataset/images/13396_0013.png
#   inflating: crop_512_r1_conv_dataset/images/19084_0002.png
#   inflating: crop_512_r1_conv_dataset/images/14396_0005.png
#   inflating: crop_512_r1_conv_dataset/images/351_0006.png
#   inflating: crop_512_r1_conv_dataset/images/1184_0008.png
#   inflating: crop_512_r1_conv_dataset/images/5086_0005.png
#   inflating: crop_512_r1_conv_dataset/images/22953_0015.png
#   inflating: crop_512_r1_conv_dataset/images/6794_0010.png
#   inflating: crop_512_r1_conv_dataset/images/28657_0010.png
#   inflating: crop_512_r1_conv_dataset/images/1123_0010.png
#   inflating: crop_512_r1_conv_dataset/images/9358_0015.png
#   inflating: crop_512_r1_conv_dataset/images/10892_0000.png
#   inflating: crop_512_r1_conv_dataset/images/19997_0015.png
#   inflating: crop_512_r1_conv_dataset/images/9777_0013.png
#   inflating: crop_512_r1_conv_dataset/images/24961_0012.png
#   inflating: crop_512_r1_conv_dataset/images/16362_0004.png
#   inflating: crop_512_r1_conv_dataset/images/17187_0002.png
#   inflating: crop_512_r1_conv_dataset/images/14407_0011.png
#   inflating: crop_512_r1_conv_dataset/images/27232_0013.png
#   inflating: crop_512_r1_conv_dataset/images/2447_0015.png
#   inflating: crop_512_r1_conv_dataset/images/30194_0000.png
#   inflating: crop_512_r1_conv_dataset/images/4944_0015.png
#   inflating: crop_512_r1_conv_dataset/images/23961_0009.png
#   inflating: crop_512_r1_conv_dataset/images/3303_0009.png
#   inflating: crop_512_r1_conv_dataset/images/26780_0001.png
#   inflating: crop_512_r1_conv_dataset/images/21039_0013.png
#   inflating: crop_512_r1_conv_dataset/images/12476_0009.png
#   inflating: crop_512_r1_conv_dataset/images/26664_0014.png
#   inflating: crop_512_r1_conv_dataset/images/22236_0013.png
#   inflating: crop_512_r1_conv_dataset/images/8402_0012.png
#   inflating: crop_512_r1_conv_dataset/images/15124_0010.png
#   inflating: crop_512_r1_conv_dataset/images/9904_0008.png
#   inflating: crop_512_r1_conv_dataset/images/10971_0015.png
#   inflating: crop_512_r1_conv_dataset/images/62_0014.png
#   inflating: crop_512_r1_conv_dataset/images/27128_0014.png
#   inflating: crop_512_r1_conv_dataset/images/8450_0015.png
#   inflating: crop_512_r1_conv_dataset/images/3959_0004.png
#   inflating: crop_512_r1_conv_dataset/images/28436_0001.png
#   inflating: crop_512_r1_conv_dataset/images/30194_0002.png
#   inflating: crop_512_r1_conv_dataset/images/1184_0014.png
#   inflating: crop_512_r1_conv_dataset/images/4777_0015.png
#   inflating: crop_512_r1_conv_dataset/images/21501_0000.png
#   inflating: crop_512_r1_conv_dataset/images/8842_0010.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0001.png
#   inflating: crop_512_r1_conv_dataset/images/16149_0005.png
#   inflating: crop_512_r1_conv_dataset/images/20478_0014.png
#   inflating: crop_512_r1_conv_dataset/images/14756_0001.png
#   inflating: crop_512_r1_conv_dataset/images/31799_0005.png
#   inflating: crop_512_r1_conv_dataset/images/28429_0006.png
#   inflating: crop_512_r1_conv_dataset/images/686_0013.png
#   inflating: crop_512_r1_conv_dataset/images/8343_0015.png
#   inflating: crop_512_r1_conv_dataset/images/11645_0011.png
#   inflating: crop_512_r1_conv_dataset/images/19533_0008.png
#   inflating: crop_512_r1_conv_dataset/images/6318_0007.png
#   inflating: crop_512_r1_conv_dataset/images/5102_0002.png
#   inflating: crop_512_r1_conv_dataset/images/16149_0013.png
#   inflating: crop_512_r1_conv_dataset/images/25430_0007.png
#   inflating: crop_512_r1_conv_dataset/images/17828_0009.png
#   inflating: crop_512_r1_conv_dataset/images/25945_0007.png
#   inflating: crop_512_r1_conv_dataset/images/20563_0005.png
#   inflating: crop_512_r1_conv_dataset/images/20440_0001.png
#   inflating: crop_512_r1_conv_dataset/images/24097_0012.png
#   inflating: crop_512_r1_conv_dataset/images/8151_0000.png
#   inflating: crop_512_r1_conv_dataset/images/11629_0011.png
#   inflating: crop_512_r1_conv_dataset/images/31290_0011.png
#   inflating: crop_512_r1_conv_dataset/images/12476_0010.png
#   inflating: crop_512_r1_conv_dataset/images/26982_0014.png
#   inflating: crop_512_r1_conv_dataset/images/5995_0011.png
#   inflating: crop_512_r1_conv_dataset/images/23665_0011.png
#   inflating: crop_512_r1_conv_dataset/images/4265_0002.png
#   inflating: crop_512_r1_conv_dataset/images/5317_0008.png
#   inflating: crop_512_r1_conv_dataset/images/29180_0011.png
#   inflating: crop_512_r1_conv_dataset/images/9777_0003.png
#   inflating: crop_512_r1_conv_dataset/images/686_0008.png
#   inflating: crop_512_r1_conv_dataset/images/22953_0005.png
#   inflating: crop_512_r1_conv_dataset/images/24222_0011.png
#   inflating: crop_512_r1_conv_dataset/images/28823_0003.png
#   inflating: crop_512_r1_conv_dataset/images/23243_0002.png
#   inflating: crop_512_r1_conv_dataset/images/29143_0002.png
#   inflating: crop_512_r1_conv_dataset/images/4777_0009.png
#   inflating: crop_512_r1_conv_dataset/images/4944_0004.png
#   inflating: crop_512_r1_conv_dataset/images/23828_0011.png
#   inflating: crop_512_r1_conv_dataset/images/25641_0013.png
#   inflating: crop_512_r1_conv_dataset/images/28748_0003.png
#   inflating: crop_512_r1_conv_dataset/images/19048_0005.png
#   inflating: crop_512_r1_conv_dataset/images/1184_0000.png
#   inflating: crop_512_r1_conv_dataset/images/2447_0010.png
#   inflating: crop_512_r1_conv_dataset/images/32009_0001.png
#   inflating: crop_512_r1_conv_dataset/images/30581_0006.png
#   inflating: crop_512_r1_conv_dataset/images/3959_0013.png
#   inflating: crop_512_r1_conv_dataset/images/164_0008.png
#   inflating: crop_512_r1_conv_dataset/images/19533_0012.png
#   inflating: crop_512_r1_conv_dataset/images/9517_0009.png
#   inflating: crop_512_r1_conv_dataset/images/23640_0008.png
#   inflating: crop_512_r1_conv_dataset/images/8894_0004.png
#   inflating: crop_512_r1_conv_dataset/images/127_0008.png
#   inflating: crop_512_r1_conv_dataset/images/31958_0009.png
#   inflating: crop_512_r1_conv_dataset/images/5317_0009.png
#   inflating: crop_512_r1_conv_dataset/images/11448_0008.png
#   inflating: crop_512_r1_conv_dataset/images/6120_0001.png
#   inflating: crop_512_r1_conv_dataset/images/8231_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4265_0003.png
#   inflating: crop_512_r1_conv_dataset/images/9517_0003.png
#   inflating: crop_512_r1_conv_dataset/images/28748_0013.png
#   inflating: crop_512_r1_conv_dataset/images/6794_0000.png
#   inflating: crop_512_r1_conv_dataset/images/28126_0011.png
#   inflating: crop_512_r1_conv_dataset/images/27468_0010.png
#   inflating: crop_512_r1_conv_dataset/images/14388_0008.png
#   inflating: crop_512_r1_conv_dataset/images/8450_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4301_0006.png
#   inflating: crop_512_r1_conv_dataset/images/3083_0012.png
#   inflating: crop_512_r1_conv_dataset/images/23094_0004.png
#   inflating: crop_512_r1_conv_dataset/images/30201_0011.png
#   inflating: crop_512_r1_conv_dataset/images/4777_0003.png
#   inflating: crop_512_r1_conv_dataset/images/13942_0000.png
#   inflating: crop_512_r1_conv_dataset/images/1690_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4639_0008.png
#   inflating: crop_512_r1_conv_dataset/images/18449_0009.png
#   inflating: crop_512_r1_conv_dataset/images/18401_0010.png
#   inflating: crop_512_r1_conv_dataset/images/2668_0006.png
#   inflating: crop_512_r1_conv_dataset/images/31727_0009.png
#   inflating: crop_512_r1_conv_dataset/images/11645_0002.png
#   inflating: crop_512_r1_conv_dataset/images/10611_0014.png
#   inflating: crop_512_r1_conv_dataset/images/20302_0001.png
#   inflating: crop_512_r1_conv_dataset/images/1220_0003.png
#   inflating: crop_512_r1_conv_dataset/images/21155_0001.png
#   inflating: crop_512_r1_conv_dataset/images/31698_0003.png
#   inflating: crop_512_r1_conv_dataset/images/12233_0000.png
#   inflating: crop_512_r1_conv_dataset/images/3054_0001.png
#   inflating: crop_512_r1_conv_dataset/images/435_0003.png
#   inflating: crop_512_r1_conv_dataset/images/6730_0011.png
#   inflating: crop_512_r1_conv_dataset/images/31698_0002.png
#   inflating: crop_512_r1_conv_dataset/images/24961_0001.png
#   inflating: crop_512_r1_conv_dataset/images/23828_0001.png
#   inflating: crop_512_r1_conv_dataset/images/31727_0005.png
#   inflating: crop_512_r1_conv_dataset/images/11064_0003.png
#   inflating: crop_512_r1_conv_dataset/images/11890_0015.png
#   inflating: crop_512_r1_conv_dataset/images/3409_0007.png
#   inflating: crop_512_r1_conv_dataset/images/9387_0004.png
#   inflating: crop_512_r1_conv_dataset/images/16216_0012.png
#   inflating: crop_512_r1_conv_dataset/images/1955_0010.png
#   inflating: crop_512_r1_conv_dataset/images/31571_0007.png
#   inflating: crop_512_r1_conv_dataset/images/4066_0000.png
#   inflating: crop_512_r1_conv_dataset/images/3409_0013.png
#   inflating: crop_512_r1_conv_dataset/images/12026_0013.png
#   inflating: crop_512_r1_conv_dataset/images/11064_0013.png
#   inflating: crop_512_r1_conv_dataset/images/29223_0001.png
#   inflating: crop_512_r1_conv_dataset/images/4265_0011.png
#   inflating: crop_512_r1_conv_dataset/images/28823_0002.png
#   inflating: crop_512_r1_conv_dataset/images/16659_0009.png
#   inflating: crop_512_r1_conv_dataset/images/11629_0010.png
#   inflating: crop_512_r1_conv_dataset/images/28262_0005.png
#   inflating: crop_512_r1_conv_dataset/images/20247_0013.png
#   inflating: crop_512_r1_conv_dataset/images/30250_0005.png
#   inflating: crop_512_r1_conv_dataset/images/9450_0011.png
#   inflating: crop_512_r1_conv_dataset/images/14756_0004.png
#   inflating: crop_512_r1_conv_dataset/images/6807_0007.png
#   inflating: crop_512_r1_conv_dataset/images/2279_0015.png
#   inflating: crop_512_r1_conv_dataset/images/3303_0001.png
#   inflating: crop_512_r1_conv_dataset/images/29610_0013.png
#   inflating: crop_512_r1_conv_dataset/images/29809_0009.png
#   inflating: crop_512_r1_conv_dataset/images/15551_0000.png
#   inflating: crop_512_r1_conv_dataset/images/20428_0009.png
#   inflating: crop_512_r1_conv_dataset/images/23640_0015.png
#   inflating: crop_512_r1_conv_dataset/images/21358_0009.png
#   inflating: crop_512_r1_conv_dataset/images/15551_0008.png
#   inflating: crop_512_r1_conv_dataset/images/21129_0006.png
#   inflating: crop_512_r1_conv_dataset/images/12483_0008.png
#   inflating: crop_512_r1_conv_dataset/images/8752_0008.png
#   inflating: crop_512_r1_conv_dataset/images/3054_0000.png
#   inflating: crop_512_r1_conv_dataset/images/1157_0008.png
#   inflating: crop_512_r1_conv_dataset/images/6807_0003.png
#   inflating: crop_512_r1_conv_dataset/images/4404_0010.png
#   inflating: crop_512_r1_conv_dataset/images/15124_0009.png
#   inflating: crop_512_r1_conv_dataset/images/5552_0001.png
#   inflating: crop_512_r1_conv_dataset/images/30394_0006.png
#   inflating: crop_512_r1_conv_dataset/images/24833_0012.png
#   inflating: crop_512_r1_conv_dataset/images/30500_0007.png
#   inflating: crop_512_r1_conv_dataset/images/12784_0004.png
#   inflating: crop_512_r1_conv_dataset/images/27861_0003.png
#   inflating: crop_512_r1_conv_dataset/images/23880_0001.png
#   inflating: crop_512_r1_conv_dataset/images/30250_0004.png
#   inflating: crop_512_r1_conv_dataset/images/30876_0011.png
#   inflating: crop_512_r1_conv_dataset/images/8227_0013.png
#   inflating: crop_512_r1_conv_dataset/images/8151_0014.png
#   inflating: crop_512_r1_conv_dataset/images/28429_0007.png
#   inflating: crop_512_r1_conv_dataset/images/16216_0004.png
#   inflating: crop_512_r1_conv_dataset/images/23665_0012.png
#   inflating: crop_512_r1_conv_dataset/images/13189_0009.png
#   inflating: crop_512_r1_conv_dataset/images/928_0005.png
#   inflating: crop_512_r1_conv_dataset/images/2943_0010.png
#   inflating: crop_512_r1_conv_dataset/images/13189_0010.png
#   inflating: crop_512_r1_conv_dataset/images/28436_0012.png
#   inflating: crop_512_r1_conv_dataset/images/14407_0003.png
#   inflating: crop_512_r1_conv_dataset/images/18900_0002.png
#   inflating: crop_512_r1_conv_dataset/images/19997_0002.png
#   inflating: crop_512_r1_conv_dataset/images/7970_0015.png
#   inflating: crop_512_r1_conv_dataset/images/29610_0005.png
#   inflating: crop_512_r1_conv_dataset/images/28318_0003.png
#   inflating: crop_512_r1_conv_dataset/images/10666_0009.png
#   inflating: crop_512_r1_conv_dataset/images/14407_0005.png
#   inflating: crop_512_r1_conv_dataset/images/8876_0012.png
#   inflating: crop_512_r1_conv_dataset/images/26319_0000.png
#   inflating: crop_512_r1_conv_dataset/images/20563_0004.png
#   inflating: crop_512_r1_conv_dataset/images/5102_0003.png
#   inflating: crop_512_r1_conv_dataset/images/8388_0006.png
#   inflating: crop_512_r1_conv_dataset/images/14407_0013.png
#   inflating: crop_512_r1_conv_dataset/images/27587_0015.png
#   inflating: crop_512_r1_conv_dataset/images/9769_0003.png
#   inflating: crop_512_r1_conv_dataset/images/1850_0003.png
#   inflating: crop_512_r1_conv_dataset/images/8231_0012.png
#   inflating: crop_512_r1_conv_dataset/images/29296_0011.png
#   inflating: crop_512_r1_conv_dataset/images/25620_0011.png
#   inflating: crop_512_r1_conv_dataset/images/29223_0012.png
#   inflating: crop_512_r1_conv_dataset/images/12476_0015.png
#   inflating: crop_512_r1_conv_dataset/images/32741_0005.png
#   inflating: crop_512_r1_conv_dataset/images/10666_0006.png
#   inflating: crop_512_r1_conv_dataset/images/16564_0000.png
#   inflating: crop_512_r1_conv_dataset/images/20794_0015.png
#   inflating: crop_512_r1_conv_dataset/images/10992_0007.png
#   inflating: crop_512_r1_conv_dataset/images/22133_0000.png
#   inflating: crop_512_r1_conv_dataset/images/21021_0004.png
#   inflating: crop_512_r1_conv_dataset/images/21086_0012.png
#   inflating: crop_512_r1_conv_dataset/images/6611_0015.png
#   inflating: crop_512_r1_conv_dataset/images/22133_0010.png

# %%
# train csv
# !gdown 1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# To: /content/train.csv
# 100% 16.4M/16.4M [00:00<00:00, 206MB/s]

# %%
# b0 ~ b7
# !gdown 1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# !unzip ./encoder.zip -d ./encoder
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# To: /content/encoder.zip
# 100% 720M/720M [00:02<00:00, 265MB/s]
# Archive:  ./encoder.zip
#   inflating: ./encoder/efficientnet-b0-08094119.pth
#   inflating: ./encoder/efficientnet-b1-dbc7070a.pth
#   inflating: ./encoder/efficientnet-b2-27687264.pth
#   inflating: ./encoder/efficientnet-b3-c8376fa2.pth
#   inflating: ./encoder/efficientnet-b4-e116e8b3.pth
#   inflating: ./encoder/efficientnet-b5-586e6cc6.pth
#   inflating: ./encoder/efficientnet-b6-c76e70fd.pth
#   inflating: ./encoder/efficientnet-b7-dcc49843.pth

# %% [markdown]
# # Import

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision.all import *
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import os
import cv2
import gc
import random
from albumentations import *
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from lovasz import lovasz_hinge
import rasterio
from rasterio.windows import Window
from tqdm.notebook import tqdm

from PIL import Image
import tifffile as tiff

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Parameter & Etc..

# %%
dataset_name = 'effib4_conv_2048crop_512_r1_binary_dataset'
head_epochs = 5
full_epochs = 50
lr_max = 0.5e-2
lr_slice = slice(2e-4,2e-3)
bs = 4
nfolds = 4
fold = 0
SEED = 2020
TRAIN = '/content/crop_512_r1_conv_dataset/images'
MASKS = '/content/crop_512_r1_conv_dataset/masks'
LABELS = './train.csv'
NUM_WORKERS = 4
mean = np.array([0.74458427, 0.70185819, 0.73192461])
std = np.array([0.16912043, 0.19226691, 0.1886624])

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    #the following line gives ~10% speedup
    #but may lead to some stochasticity in the results 
    torch.backends.cudnn.benchmark = True
    
seed_everything(SEED)

# %% [markdown]
# # Data preprocessing

# %%
# # https://www.kaggle.com/iafoss/256x256-images
# mean = np.array([0.65459856,0.48386562,0.69428385])
# std = np.array([0.15167958,0.23584107,0.13146145])


# https://www.kaggle.com/datasets/thedevastator/hubmap-2022-256x256
def img2tensor(img,dtype:np.dtype=np.float32):
    if img.ndim==2 : img = np.expand_dims(img,2)
    img = np.transpose(img,(2,0,1))
    return torch.from_numpy(img.astype(dtype, copy=False))



class HuBMAPDataset(Dataset):
    def __init__(self, fold=fold, train=True, tfms=None):
        ids = pd.read_csv(LABELS).id.astype(str).values
        kf = KFold(n_splits=nfolds,random_state=SEED,shuffle=True)
        ids = set(ids[list(kf.split(ids))[fold][0 if train else 1]])
        self.fnames = [fname for fname in os.listdir(TRAIN) if fname.split('_')[0] in ids]
        self.train = train
        self.tfms = tfms
        
    def __len__(self):
        return len(self.fnames)
    
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.cvtColor(cv2.imread(os.path.join(TRAIN,fname)), cv2.COLOR_BGR2RGB)
        mask = cv2.imread(os.path.join(MASKS,fname),cv2.IMREAD_GRAYSCALE)
        if self.tfms is not None:
            augmented = self.tfms(image=img,mask=mask)
            img,mask = augmented['image'],augmented['mask']
        return img2tensor((img/255.0 - mean)/std),img2tensor(mask)
    


# version 1 0.65 version
def get_aug(p=1.0):
    return Compose([
        HorizontalFlip(p=0.5),
        VerticalFlip(),
        # GridDropout(ratio=0.4),
        RandomRotate90(p=1),
        #Morphology
        ShiftScaleRotate(shift_limit=0, scale_limit=(-0.2,0.2), rotate_limit=(-30,30), 
                         interpolation=1, border_mode=0, value=(0,0,0), p=0.5),
        GaussNoise(var_limit=(0,50.0), mean=0, p=0.5),
        GaussianBlur(blur_limit=(3,7), p=0.5),
        #Color
        RandomBrightnessContrast(brightness_limit=0.35, contrast_limit=0.5, 
                                 brightness_by_max=True,p=0.5),
        HueSaturationValue(hue_shift_limit=30, sat_shift_limit=30, 
                           val_shift_limit=0, p=0.5),
        OneOf([
            OpticalDistortion(p=0.3),
            GridDistortion(p=.1),
            IAAPiecewiseAffine(p=0.3),
        ], p=0.3),
    ], p=p)

# %%
#example of train images with masks
ds = HuBMAPDataset()
dl = DataLoader(ds,batch_size=8,shuffle=False,num_workers=NUM_WORKERS)
imgs,masks = next(iter(dl))

plt.figure(figsize=(16,16))
for i,(img,mask) in enumerate(zip(imgs,masks)):
    img = ((img.permute(1,2,0)*std + mean)*255.0).numpy().astype(np.uint8)
    plt.subplot(8,8,i+1)
    plt.imshow(img,vmin=0,vmax=255)
    plt.imshow(mask.squeeze().numpy(), alpha=0.2)
    plt.axis('off')
    plt.subplots_adjust(wspace=None, hspace=None)
    
del ds,dl,imgs,masks

# %% [markdown]
# # Model - EfficientUnet

# %%
class FPN(nn.Module):
    def __init__(self, input_channels:list, output_channels:list):
        super().__init__()
        self.convs = nn.ModuleList(
            [nn.Sequential(nn.Conv2d(in_ch, out_ch*2, kernel_size=3, padding=1),
             nn.ReLU(inplace=True), nn.BatchNorm2d(out_ch*2),
             nn.Conv2d(out_ch*2, out_ch, kernel_size=3, padding=1))
            for in_ch, out_ch in zip(input_channels, output_channels)])
        
    def forward(self, xs:list, last_layer):
        hcs = [F.interpolate(c(x),scale_factor=2**(len(self.convs)-i),mode='bilinear') 
               for i,(c,x) in enumerate(zip(self.convs, xs))]
        hcs.append(last_layer)
        return torch.cat(hcs, dim=1)

class UnetBlock(Module):
    def __init__(self, up_in_c:int, x_in_c:int, nf:int=None, blur:bool=False,
                 self_attention:bool=False, **kwargs):
        super().__init__()
        self.shuf = PixelShuffle_ICNR(up_in_c, up_in_c//2, blur=blur, **kwargs)
        self.bn = nn.BatchNorm2d(x_in_c)
        ni = up_in_c//2 + x_in_c
        nf = nf if nf is not None else max(up_in_c//2,32)
        self.conv1 = ConvLayer(ni, nf, norm_type=None, **kwargs)
        self.conv2 = ConvLayer(nf, nf, norm_type=None,
            xtra=SelfAttention(nf) if self_attention else None, **kwargs)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, up_in:Tensor, left_in:Tensor) -> Tensor:
        s = left_in
        up_out = self.shuf(up_in)
        cat_x = self.relu(torch.cat([up_out, self.bn(s)], dim=1))
        return self.conv2(self.conv1(cat_x))
        
class _ASPPModule(nn.Module):
    def __init__(self, inplanes, planes, kernel_size, padding, dilation, groups=1):
        super().__init__()
        self.atrous_conv = nn.Conv2d(inplanes, planes, kernel_size=kernel_size,
                stride=1, padding=padding, dilation=dilation, bias=False, groups=groups)
        self.bn = nn.BatchNorm2d(planes)
        self.relu = nn.ReLU()

        self._init_weight()

    def forward(self, x):
        x = self.atrous_conv(x)
        x = self.bn(x)

        return self.relu(x)

    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

class ASPP(nn.Module):
    def __init__(self, inplanes=512, mid_c=256, dilations=[6, 12, 18, 24], out_c=None):
        super().__init__()
        self.aspps = [_ASPPModule(inplanes, mid_c, 1, padding=0, dilation=1)] + \
            [_ASPPModule(inplanes, mid_c, 3, padding=d, dilation=d,groups=4) for d in dilations]
        self.aspps = nn.ModuleList(self.aspps)
        self.global_pool = nn.Sequential(nn.AdaptiveMaxPool2d((1, 1)),
                        nn.Conv2d(inplanes, mid_c, 1, stride=1, bias=False),
                        nn.BatchNorm2d(mid_c), nn.ReLU())
        out_c = out_c if out_c is not None else mid_c
        self.out_conv = nn.Sequential(nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False),
                                    nn.BatchNorm2d(out_c), nn.ReLU(inplace=True))
        self.conv1 = nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False)
        self._init_weight()

    def forward(self, x):
        x0 = self.global_pool(x)
        xs = [aspp(x) for aspp in self.aspps]
        x0 = F.interpolate(x0, size=xs[0].size()[2:], mode='bilinear', align_corners=True)
        x = torch.cat([x0] + xs, dim=1)
        return self.out_conv(x)
    
    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
pretrained_root = './encoder/'
efficient_net_encoders = {
    "efficientnet-b0": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (3, 5, 9, 16),
        "weight_path": pretrained_root + "efficientnet-b0-08094119.pth"
    },
    "efficientnet-b1": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b1-dbc7070a.pth"
    },
    "efficientnet-b2": {
        "out_channels": (3, 32, 24, 48, 120, 352),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b2-27687264.pth"
    },
    "efficientnet-b3": {
        "out_channels": (3, 40, 32, 48, 136, 384),
        "stage_idxs": (5, 8, 18, 26),
        "weight_path": pretrained_root + "efficientnet-b3-c8376fa2.pth"
    },
    "efficientnet-b4": {
        "out_channels": (3, 48, 32, 56, 160, 448),
        "stage_idxs": (6, 10, 22, 32),
        "weight_path": pretrained_root + "efficientnet-b4-e116e8b3.pth"
    },
    "efficientnet-b5": {
        "out_channels": (3, 48, 40, 64, 176, 512),
        "stage_idxs": (8, 13, 27, 39),
        "weight_path": pretrained_root + "efficientnet-b5-586e6cc6.pth"
    },
    "efficientnet-b6": {
        "out_channels": (3, 56, 40, 72, 200, 576),
        "stage_idxs": (9, 15, 31, 45),
        "weight_path": pretrained_root + "efficientnet-b6-c76e70fd.pth"
    },
    "efficientnet-b7": {
        "out_channels": (3, 64, 48, 80, 224, 640),
        "stage_idxs": (11, 18, 38, 55),
        "weight_path": pretrained_root + "efficientnet-b7-dcc49843.pth"
    }
}

# %%
import sys
# sys.path.insert(0, '../input/efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master')

from efficientnet_pytorch import EfficientNet
from efficientnet_pytorch.utils import url_map, url_map_advprop, get_model_params


class EfficientNetEncoder(EfficientNet):
    def __init__(self, stage_idxs, out_channels, model_name, depth=5):

        blocks_args, global_params = get_model_params(model_name, override_params=None)
        super().__init__(blocks_args, global_params)
        
        cfg = efficient_net_encoders[model_name]

        self._stage_idxs = stage_idxs
        self._out_channels = out_channels
        self._depth = depth
        self._in_channels = 3

        del self._fc
        self.load_state_dict(torch.load(cfg['weight_path']))

    def get_stages(self):
        return [
            nn.Identity(),
            nn.Sequential(self._conv_stem, self._bn0, self._swish),
            self._blocks[:self._stage_idxs[0]],
            self._blocks[self._stage_idxs[0]:self._stage_idxs[1]],
            self._blocks[self._stage_idxs[1]:self._stage_idxs[2]],
            self._blocks[self._stage_idxs[2]:],
        ]

    def forward(self, x):
        stages = self.get_stages()

        block_number = 0.
        drop_connect_rate = self._global_params.drop_connect_rate

        features = []
        for i in range(self._depth + 1):

            # Identity and Sequential stages
            if i < 2:
                x = stages[i](x)

            # Block stages need drop_connect rate
            else:
                for module in stages[i]:
                    drop_connect = drop_connect_rate * block_number / len(self._blocks)
                    block_number += 1.
                    x = module(x, drop_connect)

            features.append(x)

        return features

    def load_state_dict(self, state_dict, **kwargs):
        state_dict.pop("_fc.bias")
        state_dict.pop("_fc.weight")
        super().load_state_dict(state_dict, **kwargs)  
        

class EffUnet(nn.Module):
    def __init__(self, model_name, stride=1):
        super().__init__()
        
        cfg = efficient_net_encoders[model_name]
        stage_idxs = cfg['stage_idxs']
        out_channels = cfg['out_channels']
        
        self.encoder = EfficientNetEncoder(stage_idxs, out_channels, model_name)

        #aspp with customized dilatations
        self.aspp = ASPP(out_channels[-1], 256, out_c=384, 
                         dilations=[stride*1, stride*2, stride*3, stride*4])
        # self.drop_aspp = nn.Dropout2d(0.5)
        #decoder
        self.dec4 = UnetBlock(384, out_channels[-2], 256)
        self.dec3 = UnetBlock(256, out_channels[-3], 128)
        self.dec2 = UnetBlock(128, out_channels[-4], 64)
        self.dec1 = UnetBlock(64, out_channels[-5], 32)
        self.fpn = FPN([384, 256, 128, 64], [16]*4)
        # self.drop = nn.Dropout2d(0.1)
        self.final_conv = ConvLayer(32+16*4, 1, ks=1, norm_type=None, act_cls=None)
        
    def forward(self, x):
        enc0, enc1, enc2, enc3, enc4 = self.encoder(x)[-5:]
        enc5 = self.aspp(enc4)
        # dec3 = self.dec4(self.drop_aspp(enc5), enc3)
        dec3 = self.dec4(enc5, enc3)
        dec2 = self.dec3(dec3,enc2)
        dec1 = self.dec2(dec2,enc1)
        dec0 = self.dec1(dec1,enc0)
        x = self.fpn([enc5, dec3, dec2, dec1], dec0)
        # x = self.final_conv(self.drop(x))
        x = self.final_conv(x)
        x = F.interpolate(x,scale_factor=2,mode='bilinear')
        return x
    
#split the model to encoder and decoder for fast.ai
split_layers = lambda m: [
                list(m.encoder.parameters()),
                list(m.aspp.parameters())+list(m.dec4.parameters())+
                list(m.dec3.parameters())+list(m.dec2.parameters())+
                list(m.dec1.parameters())+list(m.fpn.parameters())+
                list(m.final_conv.parameters())
            ]

# %% [markdown]
# # Loss & Metrics

# %%
def symmetric_lovasz(outputs, targets):
    return 0.5*(lovasz_hinge(outputs, targets) + lovasz_hinge(-outputs, 1.0 - targets))

# %%
class Dice_soft(Metric):
    def __init__(self, axis=1): 
        self.axis = axis 
    def reset(self): self.inter,self.union = 0,0
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        self.inter += (pred*targ).float().sum().item()
        self.union += (pred+targ).float().sum().item()
    @property
    def value(self): return 2.0 * self.inter/self.union if self.union > 0 else None
    
# dice with automatic threshold selection
class Dice_th(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.05), axis=1): 
        self.axis = axis
        self.ths = ths
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 
                2.0*self.inter/self.union, torch.zeros_like(self.union))
        return dices.max()

# %% [markdown]
# # Model evaluation

# %%
#iterator like wrapper that returns predicted and gt masks
class Model_pred:
    def __init__(self, model, dl, tta:bool=True, half:bool=False):
        self.model = model
        self.dl = dl
        self.tta = tta
        self.half = half
        
    def __iter__(self):
        self.model.eval()
        name_list = self.dl.dataset.fnames
        count=0
        with torch.no_grad():
            for x,y in iter(self.dl):
                x = x.cuda()
                if self.half: x = x.half()
                p = self.model(x)
                py = torch.sigmoid(p).detach()
                if self.tta:
                    #x,y,xy flips as TTA
                    flips = [[-1],[-2],[-2,-1]]
                    for f in flips:
                        p = self.model(torch.flip(x,f))
                        p = torch.flip(p,f)
                        py += torch.sigmoid(p).detach()
                    py /= (1+len(flips))
                if y is not None and len(y.shape)==4 and py.shape != y.shape:
                    py = F.upsample(py, size=(y.shape[-2],y.shape[-1]), mode="bilinear")
                py = py.permute(0,2,3,1).float().cpu()
                batch_size = len(py)
                for i in range(batch_size):
                    taget = y[i].detach().cpu() if y is not None else None
                    yield py[i],taget,name_list[count]
                    count += 1
                    
    def __len__(self):
        return len(self.dl.dataset)
    
class Dice_th_pred(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.01), axis=1): 
        self.axis = axis
        self.ths = ths
        self.reset()
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self,p,t):
        pred,targ = flatten_check(p, t)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 2.0*self.inter/self.union, 
                            torch.zeros_like(self.union))
        return dices
    
def save_img(data,name,out):
    data = data.float().cpu().numpy()
    img = cv2.imencode('.png',(data*255).astype(np.uint8))[1]
    out.writestr(name, img)

# %% [markdown]
# # Train

# %%
# ## callbacks - early stopping, save model
# cbs=[EarlyStoppingCallback(monitor='valid_loss', min_delta=0, patience=5),
#      SaveModelCallback(monitor='dice_th',comp=np.greater)]

# %%
dice = Dice_th_pred(np.arange(0.2,0.7,0.01))
for fold in range(1):
    # ds_t = HuBMAPDataset(fold=fold, train=True, tfms=get_aug())
    ds_t = HuBMAPDataset(fold=fold, train=True)
    ds_v = HuBMAPDataset(fold=fold, train=False)
    data = ImageDataLoaders.from_dsets(ds_t,ds_v,bs=bs,
                num_workers=NUM_WORKERS,pin_memory=True).cuda()
    model = EffUnet('efficientnet-b4').cuda()
    learn = Learner(data, model, loss_func=symmetric_lovasz,
                metrics=[Dice_soft(),Dice_th()], 
                splitter=split_layers,
                cbs=WandbCallback())
    # .to_fp16(clip=0.5)
    
    #start with training the head
    learn.freeze_to(-1) #doesn't work
    for param in learn.opt.param_groups[0]['params']:
        param.requires_grad = False
    learn.fit_one_cycle(head_epochs, lr_max=lr_max)

    #continue training full model
    learn.unfreeze()
    learn.fit_one_cycle(full_epochs, lr_max=lr_slice,
        cbs=SaveModelCallback(monitor='valid_loss',comp=np.less))
        # cbs=SaveModelCallback(monitor='dice_th',comp=np.greater))
    torch.save(learn.model.state_dict(),f'model_{fold}.pth')
    
    #model evaluation on val and saving the masks
    mp = Model_pred(learn.model,learn.dls.loaders[1])
    with zipfile.ZipFile('val_masks_tta.zip', 'a') as out:
        for p in progress_bar(mp):
            dice.accumulate(p[0],p[1])
            save_img(p[0],p[2],out)
    gc.collect()
# Out:
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'HuBMAPDataset' object has no attribute 'items'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.498613</td>
#       <td>1.592522</td>
#       <td>0.306010</td>
#       <td>0.564273</td>
#       <td>02:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.423371</td>
#       <td>1.456641</td>
#       <td>0.471340</td>
#       <td>0.626407</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.391788</td>
#       <td>1.347529</td>
#       <td>0.557594</td>
#       <td>0.699700</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.265959</td>
#       <td>1.246427</td>
#       <td>0.588216</td>
#       <td>0.739521</td>
#       <td>02:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.183034</td>
#       <td>1.251452</td>
#       <td>0.607764</td>
#       <td>0.735208</td>
#       <td>02:40</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.211034</td>
#       <td>1.188089</td>
#       <td>0.636559</td>
#       <td>0.756949</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.068002</td>
#       <td>1.141815</td>
#       <td>0.667350</td>
#       <td>0.774065</td>
#       <td>07:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.105470</td>
#       <td>1.091107</td>
#       <td>0.687854</td>
#       <td>0.792805</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.972058</td>
#       <td>1.061573</td>
#       <td>0.719338</td>
#       <td>0.799868</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.898642</td>
#       <td>0.995937</td>
#       <td>0.759354</td>
#       <td>0.826959</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.909126</td>
#       <td>1.106758</td>
#       <td>0.746749</td>
#       <td>0.803386</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.876325</td>
#       <td>1.019574</td>
#       <td>0.764907</td>
#       <td>0.825368</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.773020</td>
#       <td>0.934027</td>
#       <td>0.781028</td>
#       <td>0.844154</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.735275</td>
#       <td>1.019720</td>
#       <td>0.796640</td>
#       <td>0.834099</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.761698</td>
#       <td>0.948832</td>
#       <td>0.786808</td>
#       <td>0.850577</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.712035</td>
#       <td>1.108862</td>
#       <td>0.784000</td>
#       <td>0.836919</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.615865</td>
#       <td>0.968144</td>
#       <td>0.795492</td>
#       <td>0.841314</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.578896</td>
#       <td>1.065217</td>
#       <td>0.815056</td>
#       <td>0.853098</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.649654</td>
#       <td>1.140636</td>
#       <td>0.804233</td>
#       <td>0.856453</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.503192</td>
#       <td>1.102325</td>
#       <td>0.779431</td>
#       <td>0.800417</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.429928</td>
#       <td>1.149426</td>
#       <td>0.807398</td>
#       <td>0.827514</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.447350</td>
#       <td>1.017117</td>
#       <td>0.839831</td>
#       <td>0.864700</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.432389</td>
#       <td>1.019059</td>
#       <td>0.809177</td>
#       <td>0.853993</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.459255</td>
#       <td>1.036137</td>
#       <td>0.832985</td>
#       <td>0.857175</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.347638</td>
#       <td>1.163898</td>
#       <td>0.827141</td>
#       <td>0.845580</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.367481</td>
#       <td>1.130218</td>
#       <td>0.834243</td>
#       <td>0.853570</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.365285</td>
#       <td>1.145152</td>
#       <td>0.831499</td>
#       <td>0.852204</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.362873</td>
#       <td>1.117486</td>
#       <td>0.828998</td>
#       <td>0.866301</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.309341</td>
#       <td>1.322921</td>
#       <td>0.823810</td>
#       <td>0.855148</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.266239</td>
#       <td>1.180712</td>
#       <td>0.848222</td>
#       <td>0.865728</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.282189</td>
#       <td>1.141873</td>
#       <td>0.846179</td>
#       <td>0.860153</td>
#       <td>07:48</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.283085</td>
#       <td>1.274562</td>
#       <td>0.823155</td>
#       <td>0.854432</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.252388</td>
#       <td>1.180526</td>
#       <td>0.852385</td>
#       <td>0.867453</td>
#       <td>07:48</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.251520</td>
#       <td>1.264277</td>
#       <td>0.856664</td>
#       <td>0.866562</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.198578</td>
#       <td>1.251605</td>
#       <td>0.855238</td>
#       <td>0.866138</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.234724</td>
#       <td>1.357148</td>
#       <td>0.847715</td>
#       <td>0.855127</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.234493</td>
#       <td>1.309944</td>
#       <td>0.848811</td>
#       <td>0.866473</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.190804</td>
#       <td>1.272484</td>
#       <td>0.855208</td>
#       <td>0.864520</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.198750</td>
#       <td>1.290109</td>
#       <td>0.861113</td>
#       <td>0.869727</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.189229</td>
#       <td>1.322722</td>
#       <td>0.862271</td>
#       <td>0.871198</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.183802</td>
#       <td>1.233709</td>
#       <td>0.851923</td>
#       <td>0.865983</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.158561</td>
#       <td>1.325932</td>
#       <td>0.863853</td>
#       <td>0.870317</td>
#       <td>07:47</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.154436</td>
#       <td>1.397864</td>
#       <td>0.862770</td>
#       <td>0.871161</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.149636</td>
#       <td>1.401144</td>
#       <td>0.866302</td>
#       <td>0.872123</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.133823</td>
#       <td>1.425198</td>
#       <td>0.859939</td>
#       <td>0.870034</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.152889</td>
#       <td>1.453640</td>
#       <td>0.864742</td>
#       <td>0.870173</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.134031</td>
#       <td>1.461753</td>
#       <td>0.866896</td>
#       <td>0.872213</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.115353</td>
#       <td>1.522813</td>
#       <td>0.864031</td>
#       <td>0.870245</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.124601</td>
#       <td>1.475731</td>
#       <td>0.866998</td>
#       <td>0.871741</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.111872</td>
#       <td>1.532664</td>
#       <td>0.861008</td>
#       <td>0.870252</td>
#       <td>07:46</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.120469</td>
#       <td>1.490037</td>
#       <td>0.865250</td>
#       <td>0.870823</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.122398</td>
#       <td>1.547342</td>
#       <td>0.866191</td>
#       <td>0.871015</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.100744</td>
#       <td>1.581521</td>
#       <td>0.863904</td>
#       <td>0.870718</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.111064</td>
#       <td>1.572545</td>
#       <td>0.863845</td>
#       <td>0.870459</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.115684</td>
#       <td>1.503132</td>
#       <td>0.864481</td>
#       <td>0.871318</td>
#       <td>07:44</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.18808913230896.
# Better model found at epoch 1 with valid_loss value: 1.1418147087097168.
# Better model found at epoch 2 with valid_loss value: 1.0911073684692383.
# Better model found at epoch 3 with valid_loss value: 1.0615730285644531.
# Better model found at epoch 4 with valid_loss value: 0.995936930179596.
# Better model found at epoch 7 with valid_loss value: 0.9340265393257141.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1404' class='' max='1404' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1404/1404 03:09&lt;00:00]
#     </div>

# %%
dices = dice.value
noise_ths = dice.ths
best_dice = dices.max()
best_thr = noise_ths[dices.argmax()]
plt.figure(figsize=(8,4))
plt.plot(noise_ths, dices, color='blue')
plt.vlines(x=best_thr, ymin=dices.min(), ymax=dices.max(), colors='black')
d = dices.max() - dices.min()
plt.text(noise_ths[-1]-0.1, best_dice-0.1*d, f'DICE = {best_dice:.3f}', fontsize=12);
plt.text(noise_ths[-1]-0.1, best_dice-0.2*d, f'TH = {best_thr:.3f}', fontsize=12);
plt.show()

# %%
dataset_name = 'effib4_conv_2048crop_512_r1_binary_dataset'

# %%
# !mkdir {dataset_name}
# !mv ./model_0.pth ./{dataset_name}
# !mv ./model_1.pth ./{dataset_name}
# !mv ./model_2.pth ./{dataset_name}
# !mv ./model_3.pth ./{dataset_name}
# Out:
# mv: cannot stat './model_0.pth': No such file or directory

# %%
# !zip /content/drive/MyDrive/data/kaggle/main_test/{dataset_name}.zip -r ./{dataset_name}
# Out:
#   adding: effib4_conv_2048crop_512_r1_binary_dataset/ (stored 0%)
