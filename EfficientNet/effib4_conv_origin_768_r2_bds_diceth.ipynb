# %% [markdown]
# <a href="https://colab.research.google.com/github/heokwon/i-seg-you/blob/main/fast_ai_starter_efficientnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Thu Sep  8 23:36:25 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Download

# %%
# !pip install rasterio efficientnet_pytorch wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 6.9 MB/s
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Collecting wandb
#   Downloading wandb-0.13.3-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 65.9 MB/s
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (22.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio) (57.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2022.6.15)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.12.1+cu113)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 71.7 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 71.2 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 90.3 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 75.6 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 88.9 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 90.8 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 76.5 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 66.6 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 72.9 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 65.6 MB/s
# Building wheels for collected packages: efficientnet-pytorch, pathtools
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=4493f5228dd6b758585f8b4ac1be1656ff826b2e95484b1322d3bd751bac4e3b
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=6c1e1e1f5a03ea2b485a7d54ef0c2dd93528d349f309fc1e471e11e97ccd6d12
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built efficientnet-pytorch pathtools
# Installing collected packages: smmap, gitdb, snuggs, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, cligj, click-plugins, affine, wandb, rasterio, efficientnet-pytorch
# Successfully installed GitPython-3.1.27 affine-2.3.1 click-plugins-1.1.1 cligj-0.7.2 docker-pycreds-0.4.0 efficientnet-pytorch-0.7.1 gitdb-4.0.9 pathtools-0.1.2 rasterio-1.2.10 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 snuggs-1.4.7 wandb-0.13.3

# %%
# !git clone https://github.com/albumentations-team/albumentations.git
# Out:
# Cloning into 'albumentations'...
# remote: Enumerating objects: 5186, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 5186 (delta 145), reused 127 (delta 84), pack-reused 4960
# Receiving objects: 100% (5186/5186), 99.74 MiB | 21.94 MiB/s, done.
# Resolving deltas: 100% (3573/3573), done.

# %% [markdown]
# # Wandb login

# %%
import os

os.environ["WANDB_NOTEBOOK_NAME"] = "effib4_conv_origin_768_r2_bds_diceth.ipynb"

# %%
import wandb
wandb.login()
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find effib4_conv_origin_768_r2_bds_diceth.ipynb.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Project Name

# %%
from fastai.callback.wandb import *

# start logging a wandb run
wandb.init(project='HuBMAP + HPA - Hacking the Human Body => Main_testing')
wandb.run.name = 'effib4_conv_origin_768_r2_bds_diceth_test7'
# Out:
# wandb: Currently logged in as: jcjang. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>/content/wandb/run-20220908_233712-3fhvr2mr</code>
# Syncing run <strong><a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing/runs/3fhvr2mr" target="_blank">grateful-totem-17</a></strong> to <a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# # Load Dataset

# %%
import zipfile

zip_path = '/content/drive/MyDrive/Colab Notebooks/alpaco/Team_1. CODEnter [ Save Form : Name_FileName_Date ]/3. 공모전/참고/Dataset/Converting/Main_dataset/conv_origin_768_r2_binary_dataset.zip'
fantasy_zip = zipfile.ZipFile(zip_path)
fantasy_zip.extractall('/content')

fantasy_zip.close()

# %%
# !gdown 1TR148ijIX14wQd1gqbwlH22aNsDKs7VN
# !unzip /content/conv_origin_768_r2_binary_dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TR148ijIX14wQd1gqbwlH22aNsDKs7VN
# To: /content/conv_origin_768_r2_binary_dataset.zip
# 100% 1.42G/1.42G [00:07<00:00, 185MB/s]
# Archive:  /content/conv_origin_768_r2_binary_dataset.zip
#    creating: conv_768_r2_dataset/
#    creating: conv_768_r2_dataset/masks/
#   inflating: conv_768_r2_dataset/masks/21021_0003.png
#   inflating: conv_768_r2_dataset/masks/24522_0002.png
#   inflating: conv_768_r2_dataset/masks/3083_0003.png
#   inflating: conv_768_r2_dataset/masks/22133_0003.png
#   inflating: conv_768_r2_dataset/masks/8638_0003.png
#   inflating: conv_768_r2_dataset/masks/9791_0001.png
#   inflating: conv_768_r2_dataset/masks/23243_0000.png
#   inflating: conv_768_r2_dataset/masks/19533_0000.png
#   inflating: conv_768_r2_dataset/masks/28657_0003.png
#   inflating: conv_768_r2_dataset/masks/31698_0002.png
#   inflating: conv_768_r2_dataset/masks/27340_0001.png
#   inflating: conv_768_r2_dataset/masks/8842_0000.png
#   inflating: conv_768_r2_dataset/masks/18777_0000.png
#   inflating: conv_768_r2_dataset/masks/23961_0003.png
#   inflating: conv_768_r2_dataset/masks/28429_0001.png
#   inflating: conv_768_r2_dataset/masks/11662_0002.png
#   inflating: conv_768_r2_dataset/masks/30581_0001.png
#   inflating: conv_768_r2_dataset/masks/25945_0002.png
#   inflating: conv_768_r2_dataset/masks/10666_0000.png
#   inflating: conv_768_r2_dataset/masks/22236_0002.png
#   inflating: conv_768_r2_dataset/masks/27298_0001.png
#   inflating: conv_768_r2_dataset/masks/30765_0003.png
#   inflating: conv_768_r2_dataset/masks/12471_0003.png
#   inflating: conv_768_r2_dataset/masks/7169_0003.png
#   inflating: conv_768_r2_dataset/masks/10611_0003.png
#   inflating: conv_768_r2_dataset/masks/32741_0001.png
#   inflating: conv_768_r2_dataset/masks/19048_0002.png
#   inflating: conv_768_r2_dataset/masks/24097_0001.png
#   inflating: conv_768_r2_dataset/masks/737_0003.png
#   inflating: conv_768_r2_dataset/masks/17455_0000.png
#   inflating: conv_768_r2_dataset/masks/9407_0002.png
#   inflating: conv_768_r2_dataset/masks/10971_0002.png
#   inflating: conv_768_r2_dataset/masks/8876_0002.png
#   inflating: conv_768_r2_dataset/masks/5099_0000.png
#   inflating: conv_768_r2_dataset/masks/22035_0002.png
#   inflating: conv_768_r2_dataset/masks/2668_0001.png
#   inflating: conv_768_r2_dataset/masks/27340_0000.png
#   inflating: conv_768_r2_dataset/masks/26664_0000.png
#   inflating: conv_768_r2_dataset/masks/19179_0000.png
#   inflating: conv_768_r2_dataset/masks/6730_0002.png
#   inflating: conv_768_r2_dataset/masks/9387_0000.png
#   inflating: conv_768_r2_dataset/masks/24222_0000.png
#   inflating: conv_768_r2_dataset/masks/30414_0002.png
#   inflating: conv_768_r2_dataset/masks/8450_0003.png
#   inflating: conv_768_r2_dataset/masks/14407_0000.png
#   inflating: conv_768_r2_dataset/masks/5995_0002.png
#   inflating: conv_768_r2_dataset/masks/13483_0003.png
#   inflating: conv_768_r2_dataset/masks/21021_0000.png
#   inflating: conv_768_r2_dataset/masks/20440_0003.png
#   inflating: conv_768_r2_dataset/masks/24222_0002.png
#   inflating: conv_768_r2_dataset/masks/1850_0002.png
#   inflating: conv_768_r2_dataset/masks/10274_0003.png
#   inflating: conv_768_r2_dataset/masks/27350_0001.png
#   inflating: conv_768_r2_dataset/masks/28622_0001.png
#   inflating: conv_768_r2_dataset/masks/22310_0000.png
#   inflating: conv_768_r2_dataset/masks/30294_0001.png
#   inflating: conv_768_r2_dataset/masks/27861_0001.png
#   inflating: conv_768_r2_dataset/masks/15706_0002.png
#   inflating: conv_768_r2_dataset/masks/6794_0002.png
#   inflating: conv_768_r2_dataset/masks/12476_0000.png
#   inflating: conv_768_r2_dataset/masks/31958_0000.png
#   inflating: conv_768_r2_dataset/masks/27471_0000.png
#   inflating: conv_768_r2_dataset/masks/2793_0000.png
#   inflating: conv_768_r2_dataset/masks/11645_0003.png
#   inflating: conv_768_r2_dataset/masks/22133_0001.png
#   inflating: conv_768_r2_dataset/masks/24241_0001.png
#   inflating: conv_768_r2_dataset/masks/4404_0003.png
#   inflating: conv_768_r2_dataset/masks/928_0001.png
#   inflating: conv_768_r2_dataset/masks/1878_0001.png
#   inflating: conv_768_r2_dataset/masks/30765_0002.png
#   inflating: conv_768_r2_dataset/masks/25516_0002.png
#   inflating: conv_768_r2_dataset/masks/22953_0001.png
#   inflating: conv_768_r2_dataset/masks/31406_0003.png
#   inflating: conv_768_r2_dataset/masks/20428_0000.png
#   inflating: conv_768_r2_dataset/masks/676_0002.png
#   inflating: conv_768_r2_dataset/masks/7970_0000.png
#   inflating: conv_768_r2_dataset/masks/31290_0000.png
#   inflating: conv_768_r2_dataset/masks/24194_0001.png
#   inflating: conv_768_r2_dataset/masks/26886_0000.png
#   inflating: conv_768_r2_dataset/masks/4776_0001.png
#   inflating: conv_768_r2_dataset/masks/9769_0000.png
#   inflating: conv_768_r2_dataset/masks/23252_0003.png
#   inflating: conv_768_r2_dataset/masks/62_0003.png
#   inflating: conv_768_r2_dataset/masks/24833_0000.png
#   inflating: conv_768_r2_dataset/masks/16659_0003.png
#   inflating: conv_768_r2_dataset/masks/5832_0001.png
#   inflating: conv_768_r2_dataset/masks/1500_0001.png
#   inflating: conv_768_r2_dataset/masks/29180_0002.png
#   inflating: conv_768_r2_dataset/masks/2279_0000.png
#   inflating: conv_768_r2_dataset/masks/4301_0001.png
#   inflating: conv_768_r2_dataset/masks/29238_0001.png
#   inflating: conv_768_r2_dataset/masks/32325_0000.png
#   inflating: conv_768_r2_dataset/masks/8222_0003.png
#   inflating: conv_768_r2_dataset/masks/20520_0002.png
#   inflating: conv_768_r2_dataset/masks/14396_0002.png
#   inflating: conv_768_r2_dataset/masks/15551_0001.png
#   inflating: conv_768_r2_dataset/masks/27298_0002.png
#   inflating: conv_768_r2_dataset/masks/16362_0002.png
#   inflating: conv_768_r2_dataset/masks/10703_0002.png
#   inflating: conv_768_r2_dataset/masks/25620_0000.png
#   inflating: conv_768_r2_dataset/masks/15860_0001.png
#   inflating: conv_768_r2_dataset/masks/22995_0001.png
#   inflating: conv_768_r2_dataset/masks/19377_0000.png
#   inflating: conv_768_r2_dataset/masks/32412_0001.png
#   inflating: conv_768_r2_dataset/masks/19507_0001.png
#   inflating: conv_768_r2_dataset/masks/25516_0000.png
#   inflating: conv_768_r2_dataset/masks/20520_0000.png
#   inflating: conv_768_r2_dataset/masks/5552_0002.png
#   inflating: conv_768_r2_dataset/masks/19377_0001.png
#   inflating: conv_768_r2_dataset/masks/5086_0000.png
#   inflating: conv_768_r2_dataset/masks/31799_0000.png
#   inflating: conv_768_r2_dataset/masks/14407_0002.png
#   inflating: conv_768_r2_dataset/masks/10892_0003.png
#   inflating: conv_768_r2_dataset/masks/3054_0000.png
#   inflating: conv_768_r2_dataset/masks/164_0000.png
#   inflating: conv_768_r2_dataset/masks/2344_0001.png
#   inflating: conv_768_r2_dataset/masks/21112_0000.png
#   inflating: conv_768_r2_dataset/masks/1955_0001.png
#   inflating: conv_768_r2_dataset/masks/25689_0000.png
#   inflating: conv_768_r2_dataset/masks/32151_0001.png
#   inflating: conv_768_r2_dataset/masks/15124_0001.png
#   inflating: conv_768_r2_dataset/masks/19533_0003.png
#   inflating: conv_768_r2_dataset/masks/27587_0000.png
#   inflating: conv_768_r2_dataset/masks/20955_0001.png
#   inflating: conv_768_r2_dataset/masks/16362_0001.png
#   inflating: conv_768_r2_dataset/masks/11497_0003.png
#   inflating: conv_768_r2_dataset/masks/16149_0002.png
#   inflating: conv_768_r2_dataset/masks/27861_0002.png
#   inflating: conv_768_r2_dataset/masks/32412_0000.png
#   inflating: conv_768_r2_dataset/masks/31709_0001.png
#   inflating: conv_768_r2_dataset/masks/30224_0003.png
#   inflating: conv_768_r2_dataset/masks/21501_0002.png
#   inflating: conv_768_r2_dataset/masks/17828_0001.png
#   inflating: conv_768_r2_dataset/masks/31727_0003.png
#   inflating: conv_768_r2_dataset/masks/5583_0000.png
#   inflating: conv_768_r2_dataset/masks/16216_0002.png
#   inflating: conv_768_r2_dataset/masks/6021_0003.png
#   inflating: conv_768_r2_dataset/masks/8116_0001.png
#   inflating: conv_768_r2_dataset/masks/22953_0002.png
#   inflating: conv_768_r2_dataset/masks/28436_0001.png
#   inflating: conv_768_r2_dataset/masks/15192_0001.png
#   inflating: conv_768_r2_dataset/masks/1184_0002.png
#   inflating: conv_768_r2_dataset/masks/3303_0001.png
#   inflating: conv_768_r2_dataset/masks/28748_0000.png
#   inflating: conv_768_r2_dataset/masks/32741_0002.png
#   inflating: conv_768_r2_dataset/masks/5995_0000.png
#   inflating: conv_768_r2_dataset/masks/17455_0002.png
#   inflating: conv_768_r2_dataset/masks/23959_0001.png
#   inflating: conv_768_r2_dataset/masks/9437_0003.png
#   inflating: conv_768_r2_dataset/masks/15005_0001.png
#   inflating: conv_768_r2_dataset/masks/4066_0000.png
#   inflating: conv_768_r2_dataset/masks/15732_0003.png
#   inflating: conv_768_r2_dataset/masks/8894_0001.png
#   inflating: conv_768_r2_dataset/masks/8116_0003.png
#   inflating: conv_768_r2_dataset/masks/15192_0003.png
#   inflating: conv_768_r2_dataset/masks/21195_0003.png
#   inflating: conv_768_r2_dataset/masks/62_0002.png
#   inflating: conv_768_r2_dataset/masks/127_0002.png
#   inflating: conv_768_r2_dataset/masks/29307_0000.png
#   inflating: conv_768_r2_dataset/masks/6807_0000.png
#   inflating: conv_768_r2_dataset/masks/8151_0003.png
#   inflating: conv_768_r2_dataset/masks/16728_0001.png
#   inflating: conv_768_r2_dataset/masks/2424_0000.png
#   inflating: conv_768_r2_dataset/masks/144_0003.png
#   inflating: conv_768_r2_dataset/masks/23009_0003.png
#   inflating: conv_768_r2_dataset/masks/19533_0001.png
#   inflating: conv_768_r2_dataset/masks/1229_0003.png
#   inflating: conv_768_r2_dataset/masks/4776_0003.png
#   inflating: conv_768_r2_dataset/masks/5932_0003.png
#   inflating: conv_768_r2_dataset/masks/13507_0002.png
#   inflating: conv_768_r2_dataset/masks/12233_0002.png
#   inflating: conv_768_r2_dataset/masks/24522_0003.png
#   inflating: conv_768_r2_dataset/masks/3057_0003.png
#   inflating: conv_768_r2_dataset/masks/25516_0001.png
#   inflating: conv_768_r2_dataset/masks/12827_0002.png
#   inflating: conv_768_r2_dataset/masks/2500_0001.png
#   inflating: conv_768_r2_dataset/masks/1157_0003.png
#   inflating: conv_768_r2_dataset/masks/30224_0002.png
#   inflating: conv_768_r2_dataset/masks/3409_0003.png
#   inflating: conv_768_r2_dataset/masks/27803_0000.png
#   inflating: conv_768_r2_dataset/masks/17187_0002.png
#   inflating: conv_768_r2_dataset/masks/30876_0000.png
#   inflating: conv_768_r2_dataset/masks/16728_0003.png
#   inflating: conv_768_r2_dataset/masks/29223_0003.png
#   inflating: conv_768_r2_dataset/masks/13396_0002.png
#   inflating: conv_768_r2_dataset/masks/6390_0001.png
#   inflating: conv_768_r2_dataset/masks/5777_0003.png
#   inflating: conv_768_r2_dataset/masks/2079_0001.png
#   inflating: conv_768_r2_dataset/masks/1168_0001.png
#   inflating: conv_768_r2_dataset/masks/8752_0002.png
#   inflating: conv_768_r2_dataset/masks/31139_0002.png
#   inflating: conv_768_r2_dataset/masks/9791_0000.png
#   inflating: conv_768_r2_dataset/masks/22035_0000.png
#   inflating: conv_768_r2_dataset/masks/16214_0001.png
#   inflating: conv_768_r2_dataset/masks/23009_0002.png
#   inflating: conv_768_r2_dataset/masks/17828_0000.png
#   inflating: conv_768_r2_dataset/masks/27616_0000.png
#   inflating: conv_768_r2_dataset/masks/30355_0000.png
#   inflating: conv_768_r2_dataset/masks/31290_0003.png
#   inflating: conv_768_r2_dataset/masks/25298_0000.png
#   inflating: conv_768_r2_dataset/masks/2793_0001.png
#   inflating: conv_768_r2_dataset/masks/29690_0003.png
#   inflating: conv_768_r2_dataset/masks/22133_0000.png
#   inflating: conv_768_r2_dataset/masks/12233_0003.png
#   inflating: conv_768_r2_dataset/masks/9453_0000.png
#   inflating: conv_768_r2_dataset/masks/28126_0003.png
#   inflating: conv_768_r2_dataset/masks/21021_0002.png
#   inflating: conv_768_r2_dataset/masks/10392_0000.png
#   inflating: conv_768_r2_dataset/masks/8402_0000.png
#   inflating: conv_768_r2_dataset/masks/31406_0000.png
#   inflating: conv_768_r2_dataset/masks/17126_0001.png
#   inflating: conv_768_r2_dataset/masks/27468_0003.png
#   inflating: conv_768_r2_dataset/masks/27861_0003.png
#   inflating: conv_768_r2_dataset/masks/5099_0002.png
#   inflating: conv_768_r2_dataset/masks/18401_0000.png
#   inflating: conv_768_r2_dataset/masks/31675_0000.png
#   inflating: conv_768_r2_dataset/masks/16711_0001.png
#   inflating: conv_768_r2_dataset/masks/16216_0003.png
#   inflating: conv_768_r2_dataset/masks/19360_0000.png
#   inflating: conv_768_r2_dataset/masks/23880_0003.png
#   inflating: conv_768_r2_dataset/masks/25689_0001.png
#   inflating: conv_768_r2_dataset/masks/27128_0002.png
#   inflating: conv_768_r2_dataset/masks/29690_0001.png
#   inflating: conv_768_r2_dataset/masks/20955_0002.png
#   inflating: conv_768_r2_dataset/masks/8894_0002.png
#   inflating: conv_768_r2_dataset/masks/21812_0000.png
#   inflating: conv_768_r2_dataset/masks/15787_0003.png
#   inflating: conv_768_r2_dataset/masks/12452_0002.png
#   inflating: conv_768_r2_dataset/masks/19179_0002.png
#   inflating: conv_768_r2_dataset/masks/32527_0002.png
#   inflating: conv_768_r2_dataset/masks/29820_0000.png
#   inflating: conv_768_r2_dataset/masks/9450_0002.png
#   inflating: conv_768_r2_dataset/masks/12471_0002.png
#   inflating: conv_768_r2_dataset/masks/1878_0000.png
#   inflating: conv_768_r2_dataset/masks/30080_0001.png
#   inflating: conv_768_r2_dataset/masks/21501_0000.png
#   inflating: conv_768_r2_dataset/masks/15706_0001.png
#   inflating: conv_768_r2_dataset/masks/27350_0000.png
#   inflating: conv_768_r2_dataset/masks/3959_0002.png
#   inflating: conv_768_r2_dataset/masks/19569_0002.png
#   inflating: conv_768_r2_dataset/masks/27781_0003.png
#   inflating: conv_768_r2_dataset/masks/27861_0000.png
#   inflating: conv_768_r2_dataset/masks/28045_0002.png
#   inflating: conv_768_r2_dataset/masks/30500_0000.png
#   inflating: conv_768_r2_dataset/masks/31290_0002.png
#   inflating: conv_768_r2_dataset/masks/7569_0001.png
#   inflating: conv_768_r2_dataset/masks/12827_0003.png
#   inflating: conv_768_r2_dataset/masks/22995_0002.png
#   inflating: conv_768_r2_dataset/masks/8638_0002.png
#   inflating: conv_768_r2_dataset/masks/11890_0001.png
#   inflating: conv_768_r2_dataset/masks/6722_0000.png
#   inflating: conv_768_r2_dataset/masks/24833_0001.png
#   inflating: conv_768_r2_dataset/masks/23880_0002.png
#   inflating: conv_768_r2_dataset/masks/24194_0000.png
#   inflating: conv_768_r2_dataset/masks/23640_0003.png
#   inflating: conv_768_r2_dataset/masks/23665_0001.png
#   inflating: conv_768_r2_dataset/masks/2668_0002.png
#   inflating: conv_768_r2_dataset/masks/19048_0001.png
#   inflating: conv_768_r2_dataset/masks/32231_0002.png
#   inflating: conv_768_r2_dataset/masks/13507_0000.png
#   inflating: conv_768_r2_dataset/masks/20440_0002.png
#   inflating: conv_768_r2_dataset/masks/676_0003.png
#   inflating: conv_768_r2_dataset/masks/27350_0002.png
#   inflating: conv_768_r2_dataset/masks/12476_0003.png
#   inflating: conv_768_r2_dataset/masks/1229_0000.png
#   inflating: conv_768_r2_dataset/masks/3303_0003.png
#   inflating: conv_768_r2_dataset/masks/23094_0003.png
#   inflating: conv_768_r2_dataset/masks/15860_0002.png
#   inflating: conv_768_r2_dataset/masks/3057_0002.png
#   inflating: conv_768_r2_dataset/masks/27879_0001.png
#   inflating: conv_768_r2_dataset/masks/27128_0000.png
#   inflating: conv_768_r2_dataset/masks/12476_0001.png
#   inflating: conv_768_r2_dataset/masks/29809_0000.png
#   inflating: conv_768_r2_dataset/masks/30355_0002.png
#   inflating: conv_768_r2_dataset/masks/11064_0002.png
#   inflating: conv_768_r2_dataset/masks/8227_0002.png
#   inflating: conv_768_r2_dataset/masks/1184_0001.png
#   inflating: conv_768_r2_dataset/masks/17126_0000.png
#   inflating: conv_768_r2_dataset/masks/164_0003.png
#   inflating: conv_768_r2_dataset/masks/23252_0002.png
#   inflating: conv_768_r2_dataset/masks/5932_0001.png
#   inflating: conv_768_r2_dataset/masks/21155_0001.png
#   inflating: conv_768_r2_dataset/masks/30500_0002.png
#   inflating: conv_768_r2_dataset/masks/20794_0001.png
#   inflating: conv_768_r2_dataset/masks/2447_0003.png
#   inflating: conv_768_r2_dataset/masks/13034_0002.png
#   inflating: conv_768_r2_dataset/masks/29143_0002.png
#   inflating: conv_768_r2_dataset/masks/20302_0000.png
#   inflating: conv_768_r2_dataset/masks/5932_0002.png
#   inflating: conv_768_r2_dataset/masks/351_0000.png
#   inflating: conv_768_r2_dataset/masks/4944_0000.png
#   inflating: conv_768_r2_dataset/masks/5785_0000.png
#   inflating: conv_768_r2_dataset/masks/2279_0001.png
#   inflating: conv_768_r2_dataset/masks/30084_0002.png
#   inflating: conv_768_r2_dataset/masks/10611_0002.png
#   inflating: conv_768_r2_dataset/masks/31898_0000.png
#   inflating: conv_768_r2_dataset/masks/28657_0001.png
#   inflating: conv_768_r2_dataset/masks/8842_0002.png
#   inflating: conv_768_r2_dataset/masks/11448_0001.png
#   inflating: conv_768_r2_dataset/masks/660_0001.png
#   inflating: conv_768_r2_dataset/masks/8231_0003.png
#   inflating: conv_768_r2_dataset/masks/1878_0003.png
#   inflating: conv_768_r2_dataset/masks/21129_0001.png
#   inflating: conv_768_r2_dataset/masks/32126_0001.png
#   inflating: conv_768_r2_dataset/masks/18449_0003.png
#   inflating: conv_768_r2_dataset/masks/17126_0002.png
#   inflating: conv_768_r2_dataset/masks/25472_0003.png
#   inflating: conv_768_r2_dataset/masks/2668_0003.png
#   inflating: conv_768_r2_dataset/masks/16362_0000.png
#   inflating: conv_768_r2_dataset/masks/30355_0003.png
#   inflating: conv_768_r2_dataset/masks/10703_0000.png
#   inflating: conv_768_r2_dataset/masks/28318_0003.png
#   inflating: conv_768_r2_dataset/masks/12784_0000.png
#   inflating: conv_768_r2_dataset/masks/21039_0003.png
#   inflating: conv_768_r2_dataset/masks/9769_0003.png
#   inflating: conv_768_r2_dataset/masks/6390_0003.png
#   inflating: conv_768_r2_dataset/masks/164_0002.png
#   inflating: conv_768_r2_dataset/masks/4404_0001.png
#   inflating: conv_768_r2_dataset/masks/15860_0000.png
#   inflating: conv_768_r2_dataset/masks/32231_0001.png
#   inflating: conv_768_r2_dataset/masks/7169_0000.png
#   inflating: conv_768_r2_dataset/masks/28318_0001.png
#   inflating: conv_768_r2_dataset/masks/2874_0000.png
#   inflating: conv_768_r2_dataset/masks/24097_0000.png
#   inflating: conv_768_r2_dataset/masks/30424_0001.png
#   inflating: conv_768_r2_dataset/masks/13260_0000.png
#   inflating: conv_768_r2_dataset/masks/29143_0000.png
#   inflating: conv_768_r2_dataset/masks/10971_0003.png
#   inflating: conv_768_r2_dataset/masks/8752_0000.png
#   inflating: conv_768_r2_dataset/masks/31698_0001.png
#   inflating: conv_768_r2_dataset/masks/11645_0000.png
#   inflating: conv_768_r2_dataset/masks/2874_0002.png
#   inflating: conv_768_r2_dataset/masks/30201_0000.png
#   inflating: conv_768_r2_dataset/masks/17422_0001.png
#   inflating: conv_768_r2_dataset/masks/22059_0003.png
#   inflating: conv_768_r2_dataset/masks/1690_0000.png
#   inflating: conv_768_r2_dataset/masks/7397_0001.png
#   inflating: conv_768_r2_dataset/masks/10992_0001.png
#   inflating: conv_768_r2_dataset/masks/24100_0001.png
#   inflating: conv_768_r2_dataset/masks/2943_0003.png
#   inflating: conv_768_r2_dataset/masks/12174_0000.png
#   inflating: conv_768_r2_dataset/masks/12471_0000.png
#   inflating: conv_768_r2_dataset/masks/22133_0002.png
#   inflating: conv_768_r2_dataset/masks/1168_0003.png
#   inflating: conv_768_r2_dataset/masks/16564_0001.png
#   inflating: conv_768_r2_dataset/masks/32325_0002.png
#   inflating: conv_768_r2_dataset/masks/4066_0003.png
#   inflating: conv_768_r2_dataset/masks/2424_0001.png
#   inflating: conv_768_r2_dataset/masks/1184_0003.png
#   inflating: conv_768_r2_dataset/masks/29820_0001.png
#   inflating: conv_768_r2_dataset/masks/27879_0002.png
#   inflating: conv_768_r2_dataset/masks/23094_0001.png
#   inflating: conv_768_r2_dataset/masks/5317_0001.png
#   inflating: conv_768_r2_dataset/masks/20794_0002.png
#   inflating: conv_768_r2_dataset/masks/8343_0003.png
#   inflating: conv_768_r2_dataset/masks/18445_0003.png
#   inflating: conv_768_r2_dataset/masks/2943_0000.png
#   inflating: conv_768_r2_dataset/masks/29424_0001.png
#   inflating: conv_768_r2_dataset/masks/6794_0001.png
#   inflating: conv_768_r2_dataset/masks/28748_0003.png
#   inflating: conv_768_r2_dataset/masks/12483_0003.png
#   inflating: conv_768_r2_dataset/masks/19048_0000.png
#   inflating: conv_768_r2_dataset/masks/4265_0001.png
#   inflating: conv_768_r2_dataset/masks/15329_0001.png
#   inflating: conv_768_r2_dataset/masks/17455_0003.png
#   inflating: conv_768_r2_dataset/masks/26319_0001.png
#   inflating: conv_768_r2_dataset/masks/12483_0000.png
#   inflating: conv_768_r2_dataset/masks/4639_0000.png
#   inflating: conv_768_r2_dataset/masks/30876_0003.png
#   inflating: conv_768_r2_dataset/masks/4404_0002.png
#   inflating: conv_768_r2_dataset/masks/28823_0002.png
#   inflating: conv_768_r2_dataset/masks/27587_0003.png
#   inflating: conv_768_r2_dataset/masks/10703_0003.png
#   inflating: conv_768_r2_dataset/masks/23828_0000.png
#   inflating: conv_768_r2_dataset/masks/4777_0000.png
#   inflating: conv_768_r2_dataset/masks/10912_0003.png
#   inflating: conv_768_r2_dataset/masks/28262_0000.png
#   inflating: conv_768_r2_dataset/masks/32527_0001.png
#   inflating: conv_768_r2_dataset/masks/17143_0001.png
#   inflating: conv_768_r2_dataset/masks/20794_0000.png
#   inflating: conv_768_r2_dataset/masks/14407_0001.png
#   inflating: conv_768_r2_dataset/masks/1731_0000.png
#   inflating: conv_768_r2_dataset/masks/18449_0000.png
#   inflating: conv_768_r2_dataset/masks/31733_0000.png
#   inflating: conv_768_r2_dataset/masks/6318_0002.png
#   inflating: conv_768_r2_dataset/masks/4944_0003.png
#   inflating: conv_768_r2_dataset/masks/3054_0002.png
#   inflating: conv_768_r2_dataset/masks/1123_0003.png
#   inflating: conv_768_r2_dataset/masks/18445_0000.png
#   inflating: conv_768_r2_dataset/masks/15499_0001.png
#   inflating: conv_768_r2_dataset/masks/18777_0003.png
#   inflating: conv_768_r2_dataset/masks/30424_0002.png
#   inflating: conv_768_r2_dataset/masks/2079_0003.png
#   inflating: conv_768_r2_dataset/masks/29820_0002.png
#   inflating: conv_768_r2_dataset/masks/12244_0001.png
#   inflating: conv_768_r2_dataset/masks/4062_0002.png
#   inflating: conv_768_r2_dataset/masks/23640_0002.png
#   inflating: conv_768_r2_dataset/masks/9407_0003.png
#   inflating: conv_768_r2_dataset/masks/25430_0003.png
#   inflating: conv_768_r2_dataset/masks/8151_0001.png
#   inflating: conv_768_r2_dataset/masks/30876_0002.png
#   inflating: conv_768_r2_dataset/masks/62_0000.png
#   inflating: conv_768_r2_dataset/masks/14183_0002.png
#   inflating: conv_768_r2_dataset/masks/14183_0000.png
#   inflating: conv_768_r2_dataset/masks/30084_0001.png
#   inflating: conv_768_r2_dataset/masks/23009_0000.png
#   inflating: conv_768_r2_dataset/masks/23760_0000.png
#   inflating: conv_768_r2_dataset/masks/2500_0002.png
#   inflating: conv_768_r2_dataset/masks/15005_0002.png
#   inflating: conv_768_r2_dataset/masks/30424_0003.png
#   inflating: conv_768_r2_dataset/masks/27128_0001.png
#   inflating: conv_768_r2_dataset/masks/30194_0000.png
#   inflating: conv_768_r2_dataset/masks/10892_0002.png
#   inflating: conv_768_r2_dataset/masks/4062_0001.png
#   inflating: conv_768_r2_dataset/masks/24269_0000.png
#   inflating: conv_768_r2_dataset/masks/9445_0001.png
#   inflating: conv_768_r2_dataset/masks/13189_0001.png
#   inflating: conv_768_r2_dataset/masks/29809_0001.png
#   inflating: conv_768_r2_dataset/masks/11497_0000.png
#   inflating: conv_768_r2_dataset/masks/17828_0002.png
#   inflating: conv_768_r2_dataset/masks/8876_0003.png
#   inflating: conv_768_r2_dataset/masks/9437_0001.png
#   inflating: conv_768_r2_dataset/masks/12174_0002.png
#   inflating: conv_768_r2_dataset/masks/4639_0002.png
#   inflating: conv_768_r2_dataset/masks/2447_0000.png
#   inflating: conv_768_r2_dataset/masks/15124_0000.png
#   inflating: conv_768_r2_dataset/masks/928_0002.png
#   inflating: conv_768_r2_dataset/masks/21129_0000.png
#   inflating: conv_768_r2_dataset/masks/9777_0003.png
#   inflating: conv_768_r2_dataset/masks/737_0002.png
#   inflating: conv_768_r2_dataset/masks/12483_0001.png
#   inflating: conv_768_r2_dataset/masks/4561_0002.png
#   inflating: conv_768_r2_dataset/masks/16564_0002.png
#   inflating: conv_768_r2_dataset/masks/25620_0002.png
#   inflating: conv_768_r2_dataset/masks/4802_0003.png
#   inflating: conv_768_r2_dataset/masks/18401_0003.png
#   inflating: conv_768_r2_dataset/masks/18121_0002.png
#   inflating: conv_768_r2_dataset/masks/28045_0003.png
#   inflating: conv_768_r2_dataset/masks/11064_0003.png
#   inflating: conv_768_r2_dataset/masks/24782_0003.png
#   inflating: conv_768_r2_dataset/masks/24961_0001.png
#   inflating: conv_768_r2_dataset/masks/26174_0002.png
#   inflating: conv_768_r2_dataset/masks/23760_0003.png
#   inflating: conv_768_r2_dataset/masks/5099_0001.png
#   inflating: conv_768_r2_dataset/masks/9777_0000.png
#   inflating: conv_768_r2_dataset/masks/15067_0002.png
#   inflating: conv_768_r2_dataset/masks/2079_0000.png
#   inflating: conv_768_r2_dataset/masks/27879_0000.png
#   inflating: conv_768_r2_dataset/masks/12244_0002.png
#   inflating: conv_768_r2_dataset/masks/31958_0001.png
#   inflating: conv_768_r2_dataset/masks/8894_0000.png
#   inflating: conv_768_r2_dataset/masks/10274_0002.png
#   inflating: conv_768_r2_dataset/masks/7397_0003.png
#   inflating: conv_768_r2_dataset/masks/30581_0003.png
#   inflating: conv_768_r2_dataset/masks/27232_0000.png
#   inflating: conv_768_r2_dataset/masks/27616_0001.png
#   inflating: conv_768_r2_dataset/masks/15842_0001.png
#   inflating: conv_768_r2_dataset/masks/18121_0000.png
#   inflating: conv_768_r2_dataset/masks/21812_0002.png
#   inflating: conv_768_r2_dataset/masks/11064_0001.png
#   inflating: conv_768_r2_dataset/masks/32151_0003.png
#   inflating: conv_768_r2_dataset/masks/31733_0003.png
#   inflating: conv_768_r2_dataset/masks/16659_0002.png
#   inflating: conv_768_r2_dataset/masks/24097_0003.png
#   inflating: conv_768_r2_dataset/masks/9358_0001.png
#   inflating: conv_768_r2_dataset/masks/32325_0003.png
#   inflating: conv_768_r2_dataset/masks/29223_0001.png
#   inflating: conv_768_r2_dataset/masks/5287_0003.png
#   inflating: conv_768_r2_dataset/masks/26480_0000.png
#   inflating: conv_768_r2_dataset/masks/7569_0000.png
#   inflating: conv_768_r2_dataset/masks/30765_0000.png
#   inflating: conv_768_r2_dataset/masks/12174_0003.png
#   inflating: conv_768_r2_dataset/masks/10971_0000.png
#   inflating: conv_768_r2_dataset/masks/23051_0000.png
#   inflating: conv_768_r2_dataset/masks/30250_0001.png
#   inflating: conv_768_r2_dataset/masks/4265_0000.png
#   inflating: conv_768_r2_dataset/masks/3083_0002.png
#   inflating: conv_768_r2_dataset/masks/19084_0003.png
#   inflating: conv_768_r2_dataset/masks/9387_0003.png
#   inflating: conv_768_r2_dataset/masks/18792_0002.png
#   inflating: conv_768_r2_dataset/masks/18792_0000.png
#   inflating: conv_768_r2_dataset/masks/7397_0002.png
#   inflating: conv_768_r2_dataset/masks/28748_0001.png
#   inflating: conv_768_r2_dataset/masks/4802_0001.png
#   inflating: conv_768_r2_dataset/masks/30414_0003.png
#   inflating: conv_768_r2_dataset/masks/32741_0000.png
#   inflating: conv_768_r2_dataset/masks/6120_0003.png
#   inflating: conv_768_r2_dataset/masks/32325_0001.png
#   inflating: conv_768_r2_dataset/masks/29296_0001.png
#   inflating: conv_768_r2_dataset/masks/5287_0000.png
#   inflating: conv_768_r2_dataset/masks/30474_0000.png
#   inflating: conv_768_r2_dataset/masks/31571_0002.png
#   inflating: conv_768_r2_dataset/masks/16149_0001.png
#   inflating: conv_768_r2_dataset/masks/3303_0000.png
#   inflating: conv_768_r2_dataset/masks/9450_0003.png
#   inflating: conv_768_r2_dataset/masks/8116_0002.png
#   inflating: conv_768_r2_dataset/masks/17828_0003.png
#   inflating: conv_768_r2_dataset/masks/24100_0003.png
#   inflating: conv_768_r2_dataset/masks/4412_0001.png
#   inflating: conv_768_r2_dataset/masks/660_0000.png
#   inflating: conv_768_r2_dataset/masks/1157_0000.png
#   inflating: conv_768_r2_dataset/masks/29180_0000.png
#   inflating: conv_768_r2_dataset/masks/22544_0003.png
#   inflating: conv_768_r2_dataset/masks/9387_0002.png
#   inflating: conv_768_r2_dataset/masks/18792_0001.png
#   inflating: conv_768_r2_dataset/masks/9517_0000.png
#   inflating: conv_768_r2_dataset/masks/11629_0001.png
#   inflating: conv_768_r2_dataset/masks/19360_0001.png
#   inflating: conv_768_r2_dataset/masks/13396_0003.png
#   inflating: conv_768_r2_dataset/masks/8222_0001.png
#   inflating: conv_768_r2_dataset/masks/27468_0000.png
#   inflating: conv_768_r2_dataset/masks/19997_0001.png
#   inflating: conv_768_r2_dataset/masks/4301_0003.png
#   inflating: conv_768_r2_dataset/masks/8842_0001.png
#   inflating: conv_768_r2_dataset/masks/21129_0003.png
#   inflating: conv_768_r2_dataset/masks/22236_0003.png
#   inflating: conv_768_r2_dataset/masks/676_0000.png
#   inflating: conv_768_r2_dataset/masks/14396_0000.png
#   inflating: conv_768_r2_dataset/masks/9470_0001.png
#   inflating: conv_768_r2_dataset/masks/29424_0000.png
#   inflating: conv_768_r2_dataset/masks/28748_0002.png
#   inflating: conv_768_r2_dataset/masks/20478_0000.png
#   inflating: conv_768_r2_dataset/masks/2079_0002.png
#   inflating: conv_768_r2_dataset/masks/23880_0000.png
#   inflating: conv_768_r2_dataset/masks/20428_0001.png
#   inflating: conv_768_r2_dataset/masks/12483_0002.png
#   inflating: conv_768_r2_dataset/masks/26982_0003.png
#   inflating: conv_768_r2_dataset/masks/15787_0001.png
#   inflating: conv_768_r2_dataset/masks/9407_0000.png
#   inflating: conv_768_r2_dataset/masks/29238_0002.png
#   inflating: conv_768_r2_dataset/masks/21812_0001.png
#   inflating: conv_768_r2_dataset/masks/6611_0001.png
#   inflating: conv_768_r2_dataset/masks/27803_0001.png
#   inflating: conv_768_r2_dataset/masks/22718_0002.png
#   inflating: conv_768_r2_dataset/masks/11662_0000.png
#   inflating: conv_768_r2_dataset/masks/13507_0003.png
#   inflating: conv_768_r2_dataset/masks/14756_0003.png
#   inflating: conv_768_r2_dataset/masks/31675_0002.png
#   inflating: conv_768_r2_dataset/masks/5086_0003.png
#   inflating: conv_768_r2_dataset/masks/22741_0001.png
#   inflating: conv_768_r2_dataset/masks/22016_0001.png
#   inflating: conv_768_r2_dataset/masks/435_0002.png
#   inflating: conv_768_r2_dataset/masks/20478_0001.png
#   inflating: conv_768_r2_dataset/masks/20955_0003.png
#   inflating: conv_768_r2_dataset/masks/23640_0001.png
#   inflating: conv_768_r2_dataset/masks/7706_0001.png
#   inflating: conv_768_r2_dataset/masks/16711_0003.png
#   inflating: conv_768_r2_dataset/masks/26480_0002.png
#   inflating: conv_768_r2_dataset/masks/1690_0003.png
#   inflating: conv_768_r2_dataset/masks/24194_0002.png
#   inflating: conv_768_r2_dataset/masks/15732_0000.png
#   inflating: conv_768_r2_dataset/masks/16728_0002.png
#   inflating: conv_768_r2_dataset/masks/20563_0003.png
#   inflating: conv_768_r2_dataset/masks/14388_0003.png
#   inflating: conv_768_r2_dataset/masks/27298_0003.png
#   inflating: conv_768_r2_dataset/masks/7169_0002.png
#   inflating: conv_768_r2_dataset/masks/11629_0002.png
#   inflating: conv_768_r2_dataset/masks/17187_0000.png
#   inflating: conv_768_r2_dataset/masks/16609_0001.png
#   inflating: conv_768_r2_dataset/masks/8450_0000.png
#   inflating: conv_768_r2_dataset/masks/18777_0001.png
#   inflating: conv_768_r2_dataset/masks/737_0001.png
#   inflating: conv_768_r2_dataset/masks/24222_0003.png
#   inflating: conv_768_r2_dataset/masks/18422_0001.png
#   inflating: conv_768_r2_dataset/masks/19997_0000.png
#   inflating: conv_768_r2_dataset/masks/10488_0003.png
#   inflating: conv_768_r2_dataset/masks/25945_0001.png
#   inflating: conv_768_r2_dataset/masks/30581_0000.png
#   inflating: conv_768_r2_dataset/masks/2174_0002.png
#   inflating: conv_768_r2_dataset/masks/6390_0000.png
#   inflating: conv_768_r2_dataset/masks/23051_0002.png
#   inflating: conv_768_r2_dataset/masks/29307_0001.png
#   inflating: conv_768_r2_dataset/masks/29213_0003.png
#   inflating: conv_768_r2_dataset/masks/10044_0000.png
#   inflating: conv_768_r2_dataset/masks/9517_0001.png
#   inflating: conv_768_r2_dataset/masks/4561_0001.png
#   inflating: conv_768_r2_dataset/masks/3409_0000.png
#   inflating: conv_768_r2_dataset/masks/9445_0000.png
#   inflating: conv_768_r2_dataset/masks/24522_0001.png
#   inflating: conv_768_r2_dataset/masks/19507_0002.png
#   inflating: conv_768_r2_dataset/masks/6807_0001.png
#   inflating: conv_768_r2_dataset/masks/5099_0003.png
#   inflating: conv_768_r2_dataset/masks/20302_0002.png
#   inflating: conv_768_r2_dataset/masks/28052_0002.png
#   inflating: conv_768_r2_dataset/masks/16362_0003.png
#   inflating: conv_768_r2_dataset/masks/6722_0003.png
#   inflating: conv_768_r2_dataset/masks/30414_0001.png
#   inflating: conv_768_r2_dataset/masks/15005_0003.png
#   inflating: conv_768_r2_dataset/masks/15124_0003.png
#   inflating: conv_768_r2_dataset/masks/16163_0002.png
#   inflating: conv_768_r2_dataset/masks/31800_0001.png
#   inflating: conv_768_r2_dataset/masks/8638_0001.png
#   inflating: conv_768_r2_dataset/masks/8231_0000.png
#   inflating: conv_768_r2_dataset/masks/20520_0001.png
#   inflating: conv_768_r2_dataset/masks/29610_0002.png
#   inflating: conv_768_r2_dataset/masks/9358_0000.png
#   inflating: conv_768_r2_dataset/masks/8151_0000.png
#   inflating: conv_768_r2_dataset/masks/5777_0002.png
#   inflating: conv_768_r2_dataset/masks/25641_0000.png
#   inflating: conv_768_r2_dataset/masks/10274_0000.png
#   inflating: conv_768_r2_dataset/masks/5552_0000.png
#   inflating: conv_768_r2_dataset/masks/9358_0002.png
#   inflating: conv_768_r2_dataset/masks/20478_0002.png
#   inflating: conv_768_r2_dataset/masks/8502_0000.png
#   inflating: conv_768_r2_dataset/masks/23051_0001.png
#   inflating: conv_768_r2_dataset/masks/13942_0002.png
#   inflating: conv_768_r2_dataset/masks/676_0001.png
#   inflating: conv_768_r2_dataset/masks/20302_0001.png
#   inflating: conv_768_r2_dataset/masks/9231_0002.png
#   inflating: conv_768_r2_dataset/masks/24269_0003.png
#   inflating: conv_768_r2_dataset/masks/30084_0003.png
#   inflating: conv_768_r2_dataset/masks/18792_0003.png
#   inflating: conv_768_r2_dataset/masks/30294_0000.png
#   inflating: conv_768_r2_dataset/masks/9358_0003.png
#   inflating: conv_768_r2_dataset/masks/18422_0000.png
#   inflating: conv_768_r2_dataset/masks/14674_0000.png
#   inflating: conv_768_r2_dataset/masks/8227_0003.png
#   inflating: conv_768_r2_dataset/masks/10611_0001.png
#   inflating: conv_768_r2_dataset/masks/7569_0003.png
#   inflating: conv_768_r2_dataset/masks/3057_0001.png
#   inflating: conv_768_r2_dataset/masks/32009_0000.png
#   inflating: conv_768_r2_dataset/masks/24100_0000.png
#   inflating: conv_768_r2_dataset/masks/26101_0002.png
#   inflating: conv_768_r2_dataset/masks/12827_0001.png
#   inflating: conv_768_r2_dataset/masks/29296_0002.png
#   inflating: conv_768_r2_dataset/masks/18426_0001.png
#   inflating: conv_768_r2_dataset/masks/15787_0002.png
#   inflating: conv_768_r2_dataset/masks/29424_0003.png
#   inflating: conv_768_r2_dataset/masks/27803_0002.png
#   inflating: conv_768_r2_dataset/masks/164_0001.png
#   inflating: conv_768_r2_dataset/masks/27468_0001.png
#   inflating: conv_768_r2_dataset/masks/28262_0002.png
#   inflating: conv_768_r2_dataset/masks/21195_0002.png
#   inflating: conv_768_r2_dataset/masks/28436_0000.png
#   inflating: conv_768_r2_dataset/masks/31898_0002.png
#   inflating: conv_768_r2_dataset/masks/17187_0003.png
#   inflating: conv_768_r2_dataset/masks/19569_0001.png
#   inflating: conv_768_r2_dataset/masks/14674_0002.png
#   inflating: conv_768_r2_dataset/masks/15499_0002.png
#   inflating: conv_768_r2_dataset/masks/2696_0001.png
#   inflating: conv_768_r2_dataset/masks/30394_0001.png
#   inflating: conv_768_r2_dataset/masks/30500_0003.png
#   inflating: conv_768_r2_dataset/masks/23665_0003.png
#   inflating: conv_768_r2_dataset/masks/25641_0003.png
#   inflating: conv_768_r2_dataset/masks/21086_0002.png
#   inflating: conv_768_r2_dataset/masks/9470_0002.png
#   inflating: conv_768_r2_dataset/masks/25689_0002.png
#   inflating: conv_768_r2_dataset/masks/24269_0002.png
#   inflating: conv_768_r2_dataset/masks/5785_0002.png
#   inflating: conv_768_r2_dataset/masks/30355_0001.png
#   inflating: conv_768_r2_dataset/masks/1500_0000.png
#   inflating: conv_768_r2_dataset/masks/8876_0000.png
#   inflating: conv_768_r2_dataset/masks/10392_0003.png
#   inflating: conv_768_r2_dataset/masks/3054_0001.png
#   inflating: conv_768_r2_dataset/masks/22236_0001.png
#   inflating: conv_768_r2_dataset/masks/20247_0000.png
#   inflating: conv_768_r2_dataset/masks/27468_0002.png
#   inflating: conv_768_r2_dataset/masks/14407_0003.png
#   inflating: conv_768_r2_dataset/masks/2279_0003.png
#   inflating: conv_768_r2_dataset/masks/8388_0001.png
#   inflating: conv_768_r2_dataset/masks/29213_0000.png
#   inflating: conv_768_r2_dataset/masks/9517_0003.png
#   inflating: conv_768_r2_dataset/masks/26319_0003.png
#   inflating: conv_768_r2_dataset/masks/5583_0002.png
#   inflating: conv_768_r2_dataset/masks/16163_0003.png
#   inflating: conv_768_r2_dataset/masks/31799_0002.png
#   inflating: conv_768_r2_dataset/masks/20428_0002.png
#   inflating: conv_768_r2_dataset/masks/6120_0001.png
#   inflating: conv_768_r2_dataset/masks/9453_0002.png
#   inflating: conv_768_r2_dataset/masks/21358_0001.png
#   inflating: conv_768_r2_dataset/masks/27471_0002.png
#   inflating: conv_768_r2_dataset/masks/18422_0002.png
#   inflating: conv_768_r2_dataset/masks/20563_0002.png
#   inflating: conv_768_r2_dataset/masks/2174_0003.png
#   inflating: conv_768_r2_dataset/masks/27232_0002.png
#   inflating: conv_768_r2_dataset/masks/21039_0000.png
#   inflating: conv_768_r2_dataset/masks/16216_0001.png
#   inflating: conv_768_r2_dataset/masks/29143_0001.png
#   inflating: conv_768_r2_dataset/masks/23959_0003.png
#   inflating: conv_768_r2_dataset/masks/1220_0001.png
#   inflating: conv_768_r2_dataset/masks/21195_0001.png
#   inflating: conv_768_r2_dataset/masks/5086_0001.png
#   inflating: conv_768_r2_dataset/masks/29690_0000.png
#   inflating: conv_768_r2_dataset/masks/16890_0002.png
#   inflating: conv_768_r2_dataset/masks/31709_0002.png
#   inflating: conv_768_r2_dataset/masks/30080_0000.png
#   inflating: conv_768_r2_dataset/masks/31290_0001.png
#   inflating: conv_768_r2_dataset/masks/23009_0001.png
#   inflating: conv_768_r2_dataset/masks/27340_0003.png
#   inflating: conv_768_r2_dataset/masks/20428_0003.png
#   inflating: conv_768_r2_dataset/masks/25945_0003.png
#   inflating: conv_768_r2_dataset/masks/2500_0000.png
#   inflating: conv_768_r2_dataset/masks/4802_0002.png
#   inflating: conv_768_r2_dataset/masks/13483_0000.png
#   inflating: conv_768_r2_dataset/masks/21039_0001.png
#   inflating: conv_768_r2_dataset/masks/3054_0003.png
#   inflating: conv_768_r2_dataset/masks/15067_0001.png
#   inflating: conv_768_r2_dataset/masks/24522_0000.png
#   inflating: conv_768_r2_dataset/masks/10666_0001.png
#   inflating: conv_768_r2_dataset/masks/28940_0002.png
#   inflating: conv_768_r2_dataset/masks/31799_0001.png
#   inflating: conv_768_r2_dataset/masks/30194_0003.png
#   inflating: conv_768_r2_dataset/masks/8450_0002.png
#   inflating: conv_768_r2_dataset/masks/32231_0003.png
#   inflating: conv_768_r2_dataset/masks/9453_0001.png
#   inflating: conv_768_r2_dataset/masks/13942_0001.png
#   inflating: conv_768_r2_dataset/masks/12466_0001.png
#   inflating: conv_768_r2_dataset/masks/16659_0000.png
#   inflating: conv_768_r2_dataset/masks/22016_0002.png
#   inflating: conv_768_r2_dataset/masks/26886_0001.png
#   inflating: conv_768_r2_dataset/masks/22995_0003.png
#   inflating: conv_768_r2_dataset/masks/11497_0001.png
#   inflating: conv_768_r2_dataset/masks/9445_0002.png
#   inflating: conv_768_r2_dataset/masks/24833_0003.png
#   inflating: conv_768_r2_dataset/masks/30080_0003.png
#   inflating: conv_768_r2_dataset/masks/15329_0002.png
#   inflating: conv_768_r2_dataset/masks/7902_0003.png
#   inflating: conv_768_r2_dataset/masks/28429_0002.png
#   inflating: conv_768_r2_dataset/masks/5102_0000.png
#   inflating: conv_768_r2_dataset/masks/18121_0001.png
#   inflating: conv_768_r2_dataset/masks/4412_0003.png
#   inflating: conv_768_r2_dataset/masks/1731_0002.png
#   inflating: conv_768_r2_dataset/masks/27232_0001.png
#   inflating: conv_768_r2_dataset/masks/1229_0001.png
#   inflating: conv_768_r2_dataset/masks/10610_0000.png
#   inflating: conv_768_r2_dataset/masks/17143_0003.png
#   inflating: conv_768_r2_dataset/masks/23640_0000.png
#   inflating: conv_768_r2_dataset/masks/29820_0003.png
#   inflating: conv_768_r2_dataset/masks/29213_0002.png
#   inflating: conv_768_r2_dataset/masks/7359_0003.png
#   inflating: conv_768_r2_dataset/masks/30194_0001.png
#   inflating: conv_768_r2_dataset/masks/26101_0001.png
#   inflating: conv_768_r2_dataset/masks/13507_0001.png
#   inflating: conv_768_r2_dataset/masks/15842_0003.png
#   inflating: conv_768_r2_dataset/masks/28436_0002.png
#   inflating: conv_768_r2_dataset/masks/26780_0003.png
#   inflating: conv_768_r2_dataset/masks/3959_0003.png
#   inflating: conv_768_r2_dataset/masks/28262_0003.png
#   inflating: conv_768_r2_dataset/masks/16711_0002.png
#   inflating: conv_768_r2_dataset/masks/9904_0003.png
#   inflating: conv_768_r2_dataset/masks/6121_0000.png
#   inflating: conv_768_r2_dataset/masks/15732_0002.png
#   inflating: conv_768_r2_dataset/masks/27781_0002.png
#   inflating: conv_768_r2_dataset/masks/9231_0003.png
#   inflating: conv_768_r2_dataset/masks/20247_0001.png
#   inflating: conv_768_r2_dataset/masks/16890_0003.png
#   inflating: conv_768_r2_dataset/masks/25298_0003.png
#   inflating: conv_768_r2_dataset/masks/2424_0002.png
#   inflating: conv_768_r2_dataset/masks/10651_0002.png
#   inflating: conv_768_r2_dataset/masks/351_0003.png
#   inflating: conv_768_r2_dataset/masks/26886_0002.png
#   inflating: conv_768_r2_dataset/masks/22953_0003.png
#   inflating: conv_768_r2_dataset/masks/4412_0000.png
#   inflating: conv_768_r2_dataset/masks/24222_0001.png
#   inflating: conv_768_r2_dataset/masks/11890_0002.png
#   inflating: conv_768_r2_dataset/masks/32412_0003.png
#   inflating: conv_768_r2_dataset/masks/28262_0001.png
#   inflating: conv_768_r2_dataset/masks/2424_0003.png
#   inflating: conv_768_r2_dataset/masks/8752_0003.png
#   inflating: conv_768_r2_dataset/masks/9470_0003.png
#   inflating: conv_768_r2_dataset/masks/10666_0002.png
#   inflating: conv_768_r2_dataset/masks/14756_0001.png
#   inflating: conv_768_r2_dataset/masks/1850_0001.png
#   inflating: conv_768_r2_dataset/masks/3083_0001.png
#   inflating: conv_768_r2_dataset/masks/1157_0001.png
#   inflating: conv_768_r2_dataset/masks/30224_0000.png
#   inflating: conv_768_r2_dataset/masks/11662_0001.png
#   inflating: conv_768_r2_dataset/masks/10611_0000.png
#   inflating: conv_768_r2_dataset/masks/23665_0002.png
#   inflating: conv_768_r2_dataset/masks/31733_0001.png
#   inflating: conv_768_r2_dataset/masks/22016_0003.png
#   inflating: conv_768_r2_dataset/masks/30474_0002.png
#   inflating: conv_768_r2_dataset/masks/19533_0002.png
#   inflating: conv_768_r2_dataset/masks/4658_0001.png
#   inflating: conv_768_r2_dataset/masks/21086_0000.png
#   inflating: conv_768_r2_dataset/masks/8231_0001.png
#   inflating: conv_768_r2_dataset/masks/15787_0000.png
#   inflating: conv_768_r2_dataset/masks/11629_0000.png
#   inflating: conv_768_r2_dataset/masks/21112_0001.png
#   inflating: conv_768_r2_dataset/masks/31571_0003.png
#   inflating: conv_768_r2_dataset/masks/28622_0000.png
#   inflating: conv_768_r2_dataset/masks/29307_0003.png
#   inflating: conv_768_r2_dataset/masks/28189_0000.png
#   inflating: conv_768_r2_dataset/masks/1731_0001.png
#   inflating: conv_768_r2_dataset/masks/9769_0001.png
#   inflating: conv_768_r2_dataset/masks/10044_0002.png
#   inflating: conv_768_r2_dataset/masks/30474_0001.png
#   inflating: conv_768_r2_dataset/masks/31675_0003.png
#   inflating: conv_768_r2_dataset/masks/26174_0000.png
#   inflating: conv_768_r2_dataset/masks/6807_0002.png
#   inflating: conv_768_r2_dataset/masks/435_0003.png
#   inflating: conv_768_r2_dataset/masks/4639_0003.png
#   inflating: conv_768_r2_dataset/masks/11064_0000.png
#   inflating: conv_768_r2_dataset/masks/10651_0001.png
#   inflating: conv_768_r2_dataset/masks/32527_0003.png
#   inflating: conv_768_r2_dataset/masks/29238_0003.png
#   inflating: conv_768_r2_dataset/masks/1168_0000.png
#   inflating: conv_768_r2_dataset/masks/30394_0002.png
#   inflating: conv_768_r2_dataset/masks/9517_0002.png
#   inflating: conv_768_r2_dataset/masks/2793_0002.png
#   inflating: conv_768_r2_dataset/masks/6794_0003.png
#   inflating: conv_768_r2_dataset/masks/25641_0002.png
#   inflating: conv_768_r2_dataset/masks/28963_0000.png
#   inflating: conv_768_r2_dataset/masks/18445_0002.png
#   inflating: conv_768_r2_dataset/masks/24269_0001.png
#   inflating: conv_768_r2_dataset/masks/8402_0003.png
#   inflating: conv_768_r2_dataset/masks/31571_0001.png
#   inflating: conv_768_r2_dataset/masks/7902_0002.png
#   inflating: conv_768_r2_dataset/masks/21129_0002.png
#   inflating: conv_768_r2_dataset/masks/1731_0003.png
#   inflating: conv_768_r2_dataset/masks/17143_0000.png
#   inflating: conv_768_r2_dataset/masks/351_0001.png
#   inflating: conv_768_r2_dataset/masks/6318_0000.png
#   inflating: conv_768_r2_dataset/masks/19507_0003.png
#   inflating: conv_768_r2_dataset/masks/22718_0001.png
#   inflating: conv_768_r2_dataset/masks/31733_0002.png
#   inflating: conv_768_r2_dataset/masks/4062_0003.png
#   inflating: conv_768_r2_dataset/masks/2943_0002.png
#   inflating: conv_768_r2_dataset/masks/26174_0003.png
#   inflating: conv_768_r2_dataset/masks/4561_0003.png
#   inflating: conv_768_r2_dataset/masks/28189_0003.png
#   inflating: conv_768_r2_dataset/masks/8231_0002.png
#   inflating: conv_768_r2_dataset/masks/13942_0003.png
#   inflating: conv_768_r2_dataset/masks/6021_0002.png
#   inflating: conv_768_r2_dataset/masks/21812_0003.png
#   inflating: conv_768_r2_dataset/masks/25298_0002.png
#   inflating: conv_768_r2_dataset/masks/28045_0000.png
#   inflating: conv_768_r2_dataset/masks/30250_0002.png
#   inflating: conv_768_r2_dataset/masks/18777_0002.png
#   inflating: conv_768_r2_dataset/masks/15860_0003.png
#   inflating: conv_768_r2_dataset/masks/2696_0003.png
#   inflating: conv_768_r2_dataset/masks/13483_0001.png
#   inflating: conv_768_r2_dataset/masks/9407_0001.png
#   inflating: conv_768_r2_dataset/masks/10610_0001.png
#   inflating: conv_768_r2_dataset/masks/25620_0001.png
#   inflating: conv_768_r2_dataset/masks/1850_0000.png
#   inflating: conv_768_r2_dataset/masks/21321_0002.png
#   inflating: conv_768_r2_dataset/masks/14183_0003.png
#   inflating: conv_768_r2_dataset/masks/27298_0000.png
#   inflating: conv_768_r2_dataset/masks/5785_0003.png
#   inflating: conv_768_r2_dataset/masks/28429_0003.png
#   inflating: conv_768_r2_dataset/masks/15124_0002.png
#   inflating: conv_768_r2_dataset/masks/10912_0002.png
#   inflating: conv_768_r2_dataset/masks/16149_0003.png
#   inflating: conv_768_r2_dataset/masks/23760_0001.png
#   inflating: conv_768_r2_dataset/masks/3959_0001.png
#   inflating: conv_768_r2_dataset/masks/13942_0000.png
#   inflating: conv_768_r2_dataset/masks/25620_0003.png
#   inflating: conv_768_r2_dataset/masks/15192_0000.png
#   inflating: conv_768_r2_dataset/masks/32126_0002.png
#   inflating: conv_768_r2_dataset/masks/25298_0001.png
#   inflating: conv_768_r2_dataset/masks/27471_0003.png
#   inflating: conv_768_r2_dataset/masks/6730_0000.png
#   inflating: conv_768_r2_dataset/masks/14183_0001.png
#   inflating: conv_768_r2_dataset/masks/737_0000.png
#   inflating: conv_768_r2_dataset/masks/6121_0003.png
#   inflating: conv_768_r2_dataset/masks/23243_0002.png
# ...
#   inflating: conv_768_r2_dataset/images/16609_0002.png
#   inflating: conv_768_r2_dataset/images/19569_0003.png
#   inflating: conv_768_r2_dataset/images/928_0000.png
#   inflating: conv_768_r2_dataset/images/1220_0003.png
#   inflating: conv_768_r2_dataset/images/10044_0001.png
#   inflating: conv_768_r2_dataset/images/23252_0000.png
#   inflating: conv_768_r2_dataset/images/5317_0002.png
#   inflating: conv_768_r2_dataset/images/15732_0001.png
#   inflating: conv_768_r2_dataset/images/8402_0001.png
#   inflating: conv_768_r2_dataset/images/31406_0002.png
#   inflating: conv_768_r2_dataset/images/19569_0000.png
#   inflating: conv_768_r2_dataset/images/15551_0003.png
#   inflating: conv_768_r2_dataset/images/26780_0001.png
#   inflating: conv_768_r2_dataset/images/31727_0002.png
#   inflating: conv_768_r2_dataset/images/12026_0000.png
#   inflating: conv_768_r2_dataset/images/5832_0003.png
#   inflating: conv_768_r2_dataset/images/26319_0000.png
#   inflating: conv_768_r2_dataset/images/3303_0002.png
#   inflating: conv_768_r2_dataset/images/12452_0003.png
#   inflating: conv_768_r2_dataset/images/17455_0001.png
#   inflating: conv_768_r2_dataset/images/4561_0000.png
#   inflating: conv_768_r2_dataset/images/435_0000.png
#   inflating: conv_768_r2_dataset/images/10992_0000.png
#   inflating: conv_768_r2_dataset/images/3959_0000.png
#   inflating: conv_768_r2_dataset/images/29296_0003.png
#   inflating: conv_768_r2_dataset/images/9791_0003.png
#   inflating: conv_768_r2_dataset/images/13189_0002.png
#   inflating: conv_768_r2_dataset/images/6611_0000.png
#   inflating: conv_768_r2_dataset/images/8450_0001.png
#   inflating: conv_768_r2_dataset/images/26480_0003.png
#   inflating: conv_768_r2_dataset/images/10651_0003.png
#   inflating: conv_768_r2_dataset/images/28791_0000.png
#   inflating: conv_768_r2_dataset/images/4776_0000.png
#   inflating: conv_768_r2_dataset/images/18422_0003.png
#   inflating: conv_768_r2_dataset/images/29610_0001.png
#   inflating: conv_768_r2_dataset/images/27128_0003.png
#   inflating: conv_768_r2_dataset/images/30765_0001.png
#   inflating: conv_768_r2_dataset/images/12466_0003.png
#   inflating: conv_768_r2_dataset/images/21358_0000.png
#   inflating: conv_768_r2_dataset/images/28126_0000.png
#   inflating: conv_768_r2_dataset/images/13483_0002.png
#   inflating: conv_768_r2_dataset/images/4404_0000.png
#   inflating: conv_768_r2_dataset/images/14388_0000.png
#   inflating: conv_768_r2_dataset/images/10892_0001.png
#   inflating: conv_768_r2_dataset/images/4777_0001.png
#   inflating: conv_768_r2_dataset/images/928_0003.png
#   inflating: conv_768_r2_dataset/images/26480_0001.png
#   inflating: conv_768_r2_dataset/images/30394_0003.png
#   inflating: conv_768_r2_dataset/images/2279_0002.png
#   inflating: conv_768_r2_dataset/images/26101_0003.png
#   inflating: conv_768_r2_dataset/images/24782_0001.png
#   inflating: conv_768_r2_dataset/images/18900_0003.png
#   inflating: conv_768_r2_dataset/images/17143_0002.png
#   inflating: conv_768_r2_dataset/images/4658_0000.png
#   inflating: conv_768_r2_dataset/images/6390_0002.png
#   inflating: conv_768_r2_dataset/images/28318_0000.png
#   inflating: conv_768_r2_dataset/images/19997_0003.png
#   inflating: conv_768_r2_dataset/images/4265_0002.png
#   inflating: conv_768_r2_dataset/images/28429_0000.png
#   inflating: conv_768_r2_dataset/images/31709_0003.png
#   inflating: conv_768_r2_dataset/images/29307_0002.png
#   inflating: conv_768_r2_dataset/images/10912_0000.png
#   inflating: conv_768_r2_dataset/images/23828_0001.png
#   inflating: conv_768_r2_dataset/images/30201_0002.png
#   inflating: conv_768_r2_dataset/images/16890_0001.png
#   inflating: conv_768_r2_dataset/images/25945_0000.png
#   inflating: conv_768_r2_dataset/images/660_0002.png
#   inflating: conv_768_r2_dataset/images/9904_0001.png
#   inflating: conv_768_r2_dataset/images/23959_0002.png
#   inflating: conv_768_r2_dataset/images/26664_0003.png
#   inflating: conv_768_r2_dataset/images/30084_0000.png
#   inflating: conv_768_r2_dataset/images/21155_0003.png
#   inflating: conv_768_r2_dataset/images/4776_0002.png
#   inflating: conv_768_r2_dataset/images/18449_0001.png
#   inflating: conv_768_r2_dataset/images/435_0001.png
#   inflating: conv_768_r2_dataset/images/13189_0003.png
#   inflating: conv_768_r2_dataset/images/127_0003.png
#   inflating: conv_768_r2_dataset/images/32126_0003.png
#   inflating: conv_768_r2_dataset/images/7359_0002.png
#   inflating: conv_768_r2_dataset/images/20955_0000.png
#   inflating: conv_768_r2_dataset/images/16609_0003.png
#   inflating: conv_768_r2_dataset/images/6318_0003.png
#   inflating: conv_768_r2_dataset/images/5777_0000.png
#   inflating: conv_768_r2_dataset/images/14756_0000.png
#   inflating: conv_768_r2_dataset/images/29424_0002.png
#   inflating: conv_768_r2_dataset/images/2696_0000.png
#   inflating: conv_768_r2_dataset/images/7970_0001.png
#   inflating: conv_768_r2_dataset/images/5102_0001.png
#   inflating: conv_768_r2_dataset/images/21321_0001.png
#   inflating: conv_768_r2_dataset/images/144_0001.png
#   inflating: conv_768_r2_dataset/images/8502_0001.png
#   inflating: conv_768_r2_dataset/images/27781_0001.png
#   inflating: conv_768_r2_dataset/images/144_0000.png
#   inflating: conv_768_r2_dataset/images/19048_0003.png
#   inflating: conv_768_r2_dataset/images/3409_0002.png
#   inflating: conv_768_r2_dataset/images/10488_0000.png
#   inflating: conv_768_r2_dataset/images/4944_0001.png
#   inflating: conv_768_r2_dataset/images/8222_0002.png
#   inflating: conv_768_r2_dataset/images/26664_0001.png
#   inflating: conv_768_r2_dataset/images/18445_0001.png
#   inflating: conv_768_r2_dataset/images/24097_0002.png
#   inflating: conv_768_r2_dataset/images/12026_0003.png
#   inflating: conv_768_r2_dataset/images/6021_0000.png
#   inflating: conv_768_r2_dataset/images/4658_0003.png
#   inflating: conv_768_r2_dataset/images/22059_0001.png
#   inflating: conv_768_r2_dataset/images/20563_0000.png
#   inflating: conv_768_r2_dataset/images/21039_0002.png
#   inflating: conv_768_r2_dataset/images/18401_0001.png
#   inflating: conv_768_r2_dataset/images/10892_0000.png
#   inflating: conv_768_r2_dataset/images/10651_0000.png
#   inflating: conv_768_r2_dataset/images/8227_0001.png
#   inflating: conv_768_r2_dataset/images/30224_0001.png
#   inflating: conv_768_r2_dataset/images/32151_0002.png
#   inflating: conv_768_r2_dataset/images/23961_0001.png
#   inflating: conv_768_r2_dataset/images/28052_0000.png
#   inflating: conv_768_r2_dataset/images/28823_0001.png
#   inflating: conv_768_r2_dataset/images/29180_0001.png
#   inflating: conv_768_r2_dataset/images/29213_0001.png
#   inflating: conv_768_r2_dataset/images/22718_0003.png
#   inflating: conv_768_r2_dataset/images/21195_0000.png
#   inflating: conv_768_r2_dataset/images/29809_0002.png
#   inflating: conv_768_r2_dataset/images/31406_0001.png
#   inflating: conv_768_r2_dataset/images/12244_0003.png
#   inflating: conv_768_r2_dataset/images/25430_0002.png
#   inflating: conv_768_r2_dataset/images/10992_0002.png
#   inflating: conv_768_r2_dataset/images/16564_0003.png
#   inflating: conv_768_r2_dataset/images/26982_0000.png
#   inflating: conv_768_r2_dataset/images/9387_0001.png
#   inflating: conv_768_r2_dataset/images/2447_0002.png
#   inflating: conv_768_r2_dataset/images/13034_0000.png
#   inflating: conv_768_r2_dataset/images/10044_0003.png
#   inflating: conv_768_r2_dataset/images/23959_0000.png
#   inflating: conv_768_r2_dataset/images/28823_0000.png
#   inflating: conv_768_r2_dataset/images/6121_0001.png
#   inflating: conv_768_r2_dataset/images/22310_0002.png
#   inflating: conv_768_r2_dataset/images/686_0000.png
#   inflating: conv_768_r2_dataset/images/32527_0000.png
#   inflating: conv_768_r2_dataset/images/29223_0002.png
#   inflating: conv_768_r2_dataset/images/20794_0003.png
#   inflating: conv_768_r2_dataset/images/24194_0003.png
#   inflating: conv_768_r2_dataset/images/5287_0001.png
#   inflating: conv_768_r2_dataset/images/8842_0003.png
#   inflating: conv_768_r2_dataset/images/22544_0001.png
#   inflating: conv_768_r2_dataset/images/12026_0001.png
#   inflating: conv_768_r2_dataset/images/8388_0000.png
#   inflating: conv_768_r2_dataset/images/28436_0003.png
#   inflating: conv_768_r2_dataset/images/28940_0000.png
#   inflating: conv_768_r2_dataset/images/22718_0000.png
#   inflating: conv_768_r2_dataset/images/15842_0000.png
#   inflating: conv_768_r2_dataset/images/17126_0003.png
#   inflating: conv_768_r2_dataset/images/20302_0003.png
#   inflating: conv_768_r2_dataset/images/1220_0000.png
#   inflating: conv_768_r2_dataset/images/24961_0003.png
#   inflating: conv_768_r2_dataset/images/26664_0002.png
#   inflating: conv_768_r2_dataset/images/4412_0002.png
#   inflating: conv_768_r2_dataset/images/11448_0000.png
#   inflating: conv_768_r2_dataset/images/29809_0003.png
#   inflating: conv_768_r2_dataset/images/18900_0002.png
#   inflating: conv_768_r2_dataset/images/4639_0001.png
#   inflating: conv_768_r2_dataset/images/25472_0000.png
#   inflating: conv_768_r2_dataset/images/12476_0002.png
#   inflating: conv_768_r2_dataset/images/12026_0002.png
#   inflating: conv_768_r2_dataset/images/15329_0003.png
#   inflating: conv_768_r2_dataset/images/5287_0002.png
#   inflating: conv_768_r2_dataset/images/18426_0002.png
#   inflating: conv_768_r2_dataset/images/12466_0000.png
#   inflating: conv_768_r2_dataset/images/14674_0001.png
#   inflating: conv_768_r2_dataset/images/23252_0001.png
#   inflating: conv_768_r2_dataset/images/2174_0001.png
#   inflating: conv_768_r2_dataset/images/6807_0003.png
#   inflating: conv_768_r2_dataset/images/7902_0001.png
#   inflating: conv_768_r2_dataset/images/5086_0002.png
#   inflating: conv_768_r2_dataset/images/7970_0002.png
#   inflating: conv_768_r2_dataset/images/31139_0003.png
#   inflating: conv_768_r2_dataset/images/9470_0000.png
#   inflating: conv_768_r2_dataset/images/21358_0003.png
#   inflating: conv_768_r2_dataset/images/20831_0000.png
#   inflating: conv_768_r2_dataset/images/17422_0003.png
#   inflating: conv_768_r2_dataset/images/203_0001.png
#   inflating: conv_768_r2_dataset/images/660_0003.png
#   inflating: conv_768_r2_dataset/images/6730_0003.png
#   inflating: conv_768_r2_dataset/images/1690_0002.png
#   inflating: conv_768_r2_dataset/images/30394_0000.png
#   inflating: conv_768_r2_dataset/images/1955_0003.png
#   inflating: conv_768_r2_dataset/images/15005_0000.png
#   inflating: conv_768_r2_dataset/images/22741_0002.png
#   inflating: conv_768_r2_dataset/images/1850_0003.png
#   inflating: conv_768_r2_dataset/images/8343_0001.png
#   inflating: conv_768_r2_dataset/images/32741_0003.png
#   inflating: conv_768_r2_dataset/images/203_0003.png
#   inflating: conv_768_r2_dataset/images/16163_0000.png
#   inflating: conv_768_r2_dataset/images/6611_0003.png
#   inflating: conv_768_r2_dataset/images/30876_0001.png
#   inflating: conv_768_r2_dataset/images/23665_0000.png
#   inflating: conv_768_r2_dataset/images/21021_0001.png
#   inflating: conv_768_r2_dataset/images/24241_0003.png
#   inflating: conv_768_r2_dataset/images/28791_0001.png
#   inflating: conv_768_r2_dataset/images/26982_0002.png
#   inflating: conv_768_r2_dataset/images/13260_0002.png
#   inflating: conv_768_r2_dataset/images/30201_0001.png
#   inflating: conv_768_r2_dataset/images/25430_0000.png
#   inflating: conv_768_r2_dataset/images/29610_0000.png
#   inflating: conv_768_r2_dataset/images/9453_0003.png
#   inflating: conv_768_r2_dataset/images/19377_0003.png
#   inflating: conv_768_r2_dataset/images/12784_0002.png
#   inflating: conv_768_r2_dataset/images/31800_0000.png
#   inflating: conv_768_r2_dataset/images/12452_0001.png
#   inflating: conv_768_r2_dataset/images/22310_0003.png
#   inflating: conv_768_r2_dataset/images/4066_0002.png
#   inflating: conv_768_r2_dataset/images/2344_0002.png
#   inflating: conv_768_r2_dataset/images/5777_0001.png
#   inflating: conv_768_r2_dataset/images/29143_0003.png
#   inflating: conv_768_r2_dataset/images/27879_0003.png
#   inflating: conv_768_r2_dataset/images/7706_0002.png
#   inflating: conv_768_r2_dataset/images/25430_0001.png
#   inflating: conv_768_r2_dataset/images/30250_0000.png
#   inflating: conv_768_r2_dataset/images/12784_0003.png
#   inflating: conv_768_r2_dataset/images/9904_0000.png
#   inflating: conv_768_r2_dataset/images/16564_0000.png
#   inflating: conv_768_r2_dataset/images/27587_0001.png
#   inflating: conv_768_r2_dataset/images/28963_0002.png
#   inflating: conv_768_r2_dataset/images/11448_0002.png
#   inflating: conv_768_r2_dataset/images/27587_0002.png
#   inflating: conv_768_r2_dataset/images/22953_0000.png
#   inflating: conv_768_r2_dataset/images/28657_0000.png
#   inflating: conv_768_r2_dataset/images/2500_0003.png
#   inflating: conv_768_r2_dataset/images/10703_0001.png
#   inflating: conv_768_r2_dataset/images/27340_0002.png
#   inflating: conv_768_r2_dataset/images/1500_0002.png
#   inflating: conv_768_r2_dataset/images/13034_0001.png
#   inflating: conv_768_r2_dataset/images/24961_0000.png
#   inflating: conv_768_r2_dataset/images/6730_0001.png
#   inflating: conv_768_r2_dataset/images/30250_0003.png
#   inflating: conv_768_r2_dataset/images/127_0001.png
#   inflating: conv_768_r2_dataset/images/25472_0001.png
#   inflating: conv_768_r2_dataset/images/19179_0001.png
#   inflating: conv_768_r2_dataset/images/20440_0000.png
#   inflating: conv_768_r2_dataset/images/29180_0003.png
#   inflating: conv_768_r2_dataset/images/22310_0001.png
#   inflating: conv_768_r2_dataset/images/19084_0000.png
#   inflating: conv_768_r2_dataset/images/2696_0002.png
#   inflating: conv_768_r2_dataset/images/16659_0001.png
#   inflating: conv_768_r2_dataset/images/11645_0001.png
#   inflating: conv_768_r2_dataset/images/23243_0001.png
#   inflating: conv_768_r2_dataset/images/23828_0002.png
#   inflating: conv_768_r2_dataset/images/22544_0002.png
#   inflating: conv_768_r2_dataset/images/32412_0002.png
#   inflating: conv_768_r2_dataset/images/5832_0002.png
#   inflating: conv_768_r2_dataset/images/27803_0003.png
#   inflating: conv_768_r2_dataset/images/15842_0002.png
#   inflating: conv_768_r2_dataset/images/26174_0001.png
#   inflating: conv_768_r2_dataset/images/7706_0003.png
#   inflating: conv_768_r2_dataset/images/11662_0003.png
#   inflating: conv_768_r2_dataset/images/10392_0002.png
#   inflating: conv_768_r2_dataset/images/31139_0001.png
#   inflating: conv_768_r2_dataset/images/22059_0000.png
#   inflating: conv_768_r2_dataset/images/31675_0001.png
#   inflating: conv_768_r2_dataset/images/8752_0001.png
#   inflating: conv_768_r2_dataset/images/30294_0002.png
#   inflating: conv_768_r2_dataset/images/127_0000.png
#   inflating: conv_768_r2_dataset/images/6611_0002.png
#   inflating: conv_768_r2_dataset/images/1157_0002.png
#   inflating: conv_768_r2_dataset/images/32009_0003.png
#   inflating: conv_768_r2_dataset/images/17422_0002.png
#   inflating: conv_768_r2_dataset/images/9777_0002.png
#   inflating: conv_768_r2_dataset/images/1878_0002.png
#   inflating: conv_768_r2_dataset/images/22741_0000.png
#   inflating: conv_768_r2_dataset/images/21358_0002.png
#   inflating: conv_768_r2_dataset/images/10666_0003.png
#   inflating: conv_768_r2_dataset/images/16214_0000.png
#   inflating: conv_768_r2_dataset/images/7706_0000.png
#   inflating: conv_768_r2_dataset/images/29296_0000.png
#   inflating: conv_768_r2_dataset/images/22995_0000.png
#   inflating: conv_768_r2_dataset/images/4066_0001.png
#   inflating: conv_768_r2_dataset/images/21112_0003.png
#   inflating: conv_768_r2_dataset/images/4658_0002.png
#   inflating: conv_768_r2_dataset/images/1123_0000.png
#   inflating: conv_768_r2_dataset/images/9791_0002.png
#   inflating: conv_768_r2_dataset/images/30080_0002.png
#   inflating: conv_768_r2_dataset/images/32126_0000.png
#   inflating: conv_768_r2_dataset/images/14756_0002.png
#   inflating: conv_768_r2_dataset/images/15551_0000.png

# %%
# train csv
# !gdown 1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# To: /content/train.csv
# 100% 16.4M/16.4M [00:00<00:00, 103MB/s]

# %%
# b0 ~ b7
# !gdown 1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# !unzip ./encoder.zip -d ./encoder
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# To: /content/encoder.zip
# 100% 720M/720M [00:04<00:00, 156MB/s]
# Archive:  ./encoder.zip
#   inflating: ./encoder/efficientnet-b0-08094119.pth
#   inflating: ./encoder/efficientnet-b1-dbc7070a.pth
#   inflating: ./encoder/efficientnet-b2-27687264.pth
#   inflating: ./encoder/efficientnet-b3-c8376fa2.pth
#   inflating: ./encoder/efficientnet-b4-e116e8b3.pth
#   inflating: ./encoder/efficientnet-b5-586e6cc6.pth
#   inflating: ./encoder/efficientnet-b6-c76e70fd.pth
#   inflating: ./encoder/efficientnet-b7-dcc49843.pth

# %% [markdown]
# # Import

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision.all import *
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import os
import cv2
import gc
import random
from albumentations import *
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from lovasz import lovasz_hinge
import rasterio
from rasterio.windows import Window
from tqdm.notebook import tqdm

from PIL import Image
import tifffile as tiff

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Parameter & Etc..

# %%
dataset_name = 'effib4_conv_origin_768_r2_bds_diceth'
head_epochs = 5
full_epochs = 50
lr_max = 0.5e-2
lr_slice = slice(2e-4,2e-3)
bs = 4
nfolds = 4
fold = 0
SEED = 2020
TRAIN = '/content/conv_768_r2_dataset/images'
MASKS = '/content/conv_768_r2_dataset/masks'
LABELS = './train.csv'
NUM_WORKERS = 4
mean = np.array([0.78054955,  0.7566257, 0.7735184])
std = np.array([0.25334089, 0.26656769, 0.26202731])

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    #the following line gives ~10% speedup
    #but may lead to some stochasticity in the results 
    torch.backends.cudnn.benchmark = True
    
seed_everything(SEED)

# %% [markdown]
# # Data preprocessing

# %%
# # https://www.kaggle.com/iafoss/256x256-images
# mean = np.array([0.65459856,0.48386562,0.69428385])
# std = np.array([0.15167958,0.23584107,0.13146145])


# https://www.kaggle.com/datasets/thedevastator/hubmap-2022-256x256
def img2tensor(img,dtype:np.dtype=np.float32):
    if img.ndim==2 : img = np.expand_dims(img,2)
    img = np.transpose(img,(2,0,1))
    return torch.from_numpy(img.astype(dtype, copy=False))



class HuBMAPDataset(Dataset):
    def __init__(self, fold=fold, train=True, tfms=None):
        ids = pd.read_csv(LABELS).id.astype(str).values
        kf = KFold(n_splits=nfolds,random_state=SEED,shuffle=True)
        ids = set(ids[list(kf.split(ids))[fold][0 if train else 1]])
        self.fnames = [fname for fname in os.listdir(TRAIN) if fname.split('_')[0] in ids]
        self.train = train
        self.tfms = tfms
        
    def __len__(self):
        return len(self.fnames)
    
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.cvtColor(cv2.imread(os.path.join(TRAIN,fname)), cv2.COLOR_BGR2RGB)
        mask = cv2.imread(os.path.join(MASKS,fname),cv2.IMREAD_GRAYSCALE)
        if self.tfms is not None:
            augmented = self.tfms(image=img,mask=mask)
            img,mask = augmented['image'],augmented['mask']
        return img2tensor((img/255.0 - mean)/std),img2tensor(mask)
    


# version 1 0.65 version
def get_aug(p=1.0):
    return Compose([
        HorizontalFlip(p=0.5),
        VerticalFlip(),
        # GridDropout(ratio=0.4),
        RandomRotate90(p=1),
        #Morphology
        ShiftScaleRotate(shift_limit=0, scale_limit=(-0.2,0.2), rotate_limit=(-30,30), 
                         interpolation=1, border_mode=0, value=(0,0,0), p=0.5),
        GaussNoise(var_limit=(0,50.0), mean=0, p=0.5),
        GaussianBlur(blur_limit=(3,7), p=0.5),
        #Color
        RandomBrightnessContrast(brightness_limit=0.35, contrast_limit=0.5, 
                                 brightness_by_max=True,p=0.5),
        HueSaturationValue(hue_shift_limit=30, sat_shift_limit=30, 
                           val_shift_limit=0, p=0.5),
        OneOf([
            OpticalDistortion(p=0.3),
            GridDistortion(p=.1),
            IAAPiecewiseAffine(p=0.3),
        ], p=0.3),
    ], p=p)

# %%
#example of train images with masks
ds = HuBMAPDataset()
dl = DataLoader(ds,batch_size=8,shuffle=False,num_workers=NUM_WORKERS)
imgs,masks = next(iter(dl))

plt.figure(figsize=(16,16))
for i,(img,mask) in enumerate(zip(imgs,masks)):
    img = ((img.permute(1,2,0)*std + mean)*255.0).numpy().astype(np.uint8)
    plt.subplot(8,8,i+1)
    plt.imshow(img,vmin=0,vmax=255)
    plt.imshow(mask.squeeze().numpy(), alpha=0.2)
    plt.axis('off')
    plt.subplots_adjust(wspace=None, hspace=None)
    
del ds,dl,imgs,masks

# %% [markdown]
# # Model - EfficientUnet

# %%
class FPN(nn.Module):
    def __init__(self, input_channels:list, output_channels:list):
        super().__init__()
        self.convs = nn.ModuleList(
            [nn.Sequential(nn.Conv2d(in_ch, out_ch*2, kernel_size=3, padding=1),
             nn.ReLU(inplace=True), nn.BatchNorm2d(out_ch*2),
             nn.Conv2d(out_ch*2, out_ch, kernel_size=3, padding=1))
            for in_ch, out_ch in zip(input_channels, output_channels)])
        
    def forward(self, xs:list, last_layer):
        hcs = [F.interpolate(c(x),scale_factor=2**(len(self.convs)-i),mode='bilinear') 
               for i,(c,x) in enumerate(zip(self.convs, xs))]
        hcs.append(last_layer)
        return torch.cat(hcs, dim=1)

class UnetBlock(Module):
    def __init__(self, up_in_c:int, x_in_c:int, nf:int=None, blur:bool=False,
                 self_attention:bool=False, **kwargs):
        super().__init__()
        self.shuf = PixelShuffle_ICNR(up_in_c, up_in_c//2, blur=blur, **kwargs)
        self.bn = nn.BatchNorm2d(x_in_c)
        ni = up_in_c//2 + x_in_c
        nf = nf if nf is not None else max(up_in_c//2,32)
        self.conv1 = ConvLayer(ni, nf, norm_type=None, **kwargs)
        self.conv2 = ConvLayer(nf, nf, norm_type=None,
            xtra=SelfAttention(nf) if self_attention else None, **kwargs)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, up_in:Tensor, left_in:Tensor) -> Tensor:
        s = left_in
        up_out = self.shuf(up_in)
        cat_x = self.relu(torch.cat([up_out, self.bn(s)], dim=1))
        return self.conv2(self.conv1(cat_x))
        
class _ASPPModule(nn.Module):
    def __init__(self, inplanes, planes, kernel_size, padding, dilation, groups=1):
        super().__init__()
        self.atrous_conv = nn.Conv2d(inplanes, planes, kernel_size=kernel_size,
                stride=1, padding=padding, dilation=dilation, bias=False, groups=groups)
        self.bn = nn.BatchNorm2d(planes)
        self.relu = nn.ReLU()

        self._init_weight()

    def forward(self, x):
        x = self.atrous_conv(x)
        x = self.bn(x)

        return self.relu(x)

    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

class ASPP(nn.Module):
    def __init__(self, inplanes=512, mid_c=256, dilations=[6, 12, 18, 24], out_c=None):
        super().__init__()
        self.aspps = [_ASPPModule(inplanes, mid_c, 1, padding=0, dilation=1)] + \
            [_ASPPModule(inplanes, mid_c, 3, padding=d, dilation=d,groups=4) for d in dilations]
        self.aspps = nn.ModuleList(self.aspps)
        self.global_pool = nn.Sequential(nn.AdaptiveMaxPool2d((1, 1)),
                        nn.Conv2d(inplanes, mid_c, 1, stride=1, bias=False),
                        nn.BatchNorm2d(mid_c), nn.ReLU())
        out_c = out_c if out_c is not None else mid_c
        self.out_conv = nn.Sequential(nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False),
                                    nn.BatchNorm2d(out_c), nn.ReLU(inplace=True))
        self.conv1 = nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False)
        self._init_weight()

    def forward(self, x):
        x0 = self.global_pool(x)
        xs = [aspp(x) for aspp in self.aspps]
        x0 = F.interpolate(x0, size=xs[0].size()[2:], mode='bilinear', align_corners=True)
        x = torch.cat([x0] + xs, dim=1)
        return self.out_conv(x)
    
    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
pretrained_root = './encoder/'
efficient_net_encoders = {
    "efficientnet-b0": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (3, 5, 9, 16),
        "weight_path": pretrained_root + "efficientnet-b0-08094119.pth"
    },
    "efficientnet-b1": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b1-dbc7070a.pth"
    },
    "efficientnet-b2": {
        "out_channels": (3, 32, 24, 48, 120, 352),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b2-27687264.pth"
    },
    "efficientnet-b3": {
        "out_channels": (3, 40, 32, 48, 136, 384),
        "stage_idxs": (5, 8, 18, 26),
        "weight_path": pretrained_root + "efficientnet-b3-c8376fa2.pth"
    },
    "efficientnet-b4": {
        "out_channels": (3, 48, 32, 56, 160, 448),
        "stage_idxs": (6, 10, 22, 32),
        "weight_path": pretrained_root + "efficientnet-b4-e116e8b3.pth"
    },
    "efficientnet-b5": {
        "out_channels": (3, 48, 40, 64, 176, 512),
        "stage_idxs": (8, 13, 27, 39),
        "weight_path": pretrained_root + "efficientnet-b5-586e6cc6.pth"
    },
    "efficientnet-b6": {
        "out_channels": (3, 56, 40, 72, 200, 576),
        "stage_idxs": (9, 15, 31, 45),
        "weight_path": pretrained_root + "efficientnet-b6-c76e70fd.pth"
    },
    "efficientnet-b7": {
        "out_channels": (3, 64, 48, 80, 224, 640),
        "stage_idxs": (11, 18, 38, 55),
        "weight_path": pretrained_root + "efficientnet-b7-dcc49843.pth"
    }
}

# %%
import sys
# sys.path.insert(0, '../input/efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master')

from efficientnet_pytorch import EfficientNet
from efficientnet_pytorch.utils import url_map, url_map_advprop, get_model_params


class EfficientNetEncoder(EfficientNet):
    def __init__(self, stage_idxs, out_channels, model_name, depth=5):

        blocks_args, global_params = get_model_params(model_name, override_params=None)
        super().__init__(blocks_args, global_params)
        
        cfg = efficient_net_encoders[model_name]

        self._stage_idxs = stage_idxs
        self._out_channels = out_channels
        self._depth = depth
        self._in_channels = 3

        del self._fc
        self.load_state_dict(torch.load(cfg['weight_path']))

    def get_stages(self):
        return [
            nn.Identity(),
            nn.Sequential(self._conv_stem, self._bn0, self._swish),
            self._blocks[:self._stage_idxs[0]],
            self._blocks[self._stage_idxs[0]:self._stage_idxs[1]],
            self._blocks[self._stage_idxs[1]:self._stage_idxs[2]],
            self._blocks[self._stage_idxs[2]:],
        ]

    def forward(self, x):
        stages = self.get_stages()

        block_number = 0.
        drop_connect_rate = self._global_params.drop_connect_rate

        features = []
        for i in range(self._depth + 1):

            # Identity and Sequential stages
            if i < 2:
                x = stages[i](x)

            # Block stages need drop_connect rate
            else:
                for module in stages[i]:
                    drop_connect = drop_connect_rate * block_number / len(self._blocks)
                    block_number += 1.
                    x = module(x, drop_connect)

            features.append(x)

        return features

    def load_state_dict(self, state_dict, **kwargs):
        state_dict.pop("_fc.bias")
        state_dict.pop("_fc.weight")
        super().load_state_dict(state_dict, **kwargs)  
        

class EffUnet(nn.Module):
    def __init__(self, model_name, stride=1):
        super().__init__()
        
        cfg = efficient_net_encoders[model_name]
        stage_idxs = cfg['stage_idxs']
        out_channels = cfg['out_channels']
        
        self.encoder = EfficientNetEncoder(stage_idxs, out_channels, model_name)

        #aspp with customized dilatations
        self.aspp = ASPP(out_channels[-1], 256, out_c=384, 
                         dilations=[stride*1, stride*2, stride*3, stride*4])
        # self.drop_aspp = nn.Dropout2d(0.5)
        #decoder
        self.dec4 = UnetBlock(384, out_channels[-2], 256)
        self.dec3 = UnetBlock(256, out_channels[-3], 128)
        self.dec2 = UnetBlock(128, out_channels[-4], 64)
        self.dec1 = UnetBlock(64, out_channels[-5], 32)
        self.fpn = FPN([384, 256, 128, 64], [16]*4)
        # self.drop = nn.Dropout2d(0.1)
        self.final_conv = ConvLayer(32+16*4, 1, ks=1, norm_type=None, act_cls=None)
        
    def forward(self, x):
        enc0, enc1, enc2, enc3, enc4 = self.encoder(x)[-5:]
        enc5 = self.aspp(enc4)
        # dec3 = self.dec4(self.drop_aspp(enc5), enc3)
        dec3 = self.dec4(enc5, enc3)
        dec2 = self.dec3(dec3,enc2)
        dec1 = self.dec2(dec2,enc1)
        dec0 = self.dec1(dec1,enc0)
        x = self.fpn([enc5, dec3, dec2, dec1], dec0)
        # x = self.final_conv(self.drop(x))
        x = self.final_conv(x)
        x = F.interpolate(x,scale_factor=2,mode='bilinear')
        return x
    
#split the model to encoder and decoder for fast.ai
split_layers = lambda m: [
                list(m.encoder.parameters()),
                list(m.aspp.parameters())+list(m.dec4.parameters())+
                list(m.dec3.parameters())+list(m.dec2.parameters())+
                list(m.dec1.parameters())+list(m.fpn.parameters())+
                list(m.final_conv.parameters())
            ]

# %% [markdown]
# # Loss & Metrics

# %%
def symmetric_lovasz(outputs, targets):
    return 0.5*(lovasz_hinge(outputs, targets) + lovasz_hinge(-outputs, 1.0 - targets))

# %%
class Dice_soft(Metric):
    def __init__(self, axis=1): 
        self.axis = axis 
    def reset(self): self.inter,self.union = 0,0
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        self.inter += (pred*targ).float().sum().item()
        self.union += (pred+targ).float().sum().item()
    @property
    def value(self): return 2.0 * self.inter/self.union if self.union > 0 else None
    
# dice with automatic threshold selection
class Dice_th(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.05), axis=1): 
        self.axis = axis
        self.ths = ths
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 
                2.0*self.inter/self.union, torch.zeros_like(self.union))
        return dices.max()

# %% [markdown]
# # Model evaluation

# %%
#iterator like wrapper that returns predicted and gt masks
class Model_pred:
    def __init__(self, model, dl, tta:bool=True, half:bool=False):
        self.model = model
        self.dl = dl
        self.tta = tta
        self.half = half
        
    def __iter__(self):
        self.model.eval()
        name_list = self.dl.dataset.fnames
        count=0
        with torch.no_grad():
            for x,y in iter(self.dl):
                x = x.cuda()
                if self.half: x = x.half()
                p = self.model(x)
                py = torch.sigmoid(p).detach()
                if self.tta:
                    #x,y,xy flips as TTA
                    flips = [[-1],[-2],[-2,-1]]
                    for f in flips:
                        p = self.model(torch.flip(x,f))
                        p = torch.flip(p,f)
                        py += torch.sigmoid(p).detach()
                    py /= (1+len(flips))
                if y is not None and len(y.shape)==4 and py.shape != y.shape:
                    py = F.upsample(py, size=(y.shape[-2],y.shape[-1]), mode="bilinear")
                py = py.permute(0,2,3,1).float().cpu()
                batch_size = len(py)
                for i in range(batch_size):
                    taget = y[i].detach().cpu() if y is not None else None
                    yield py[i],taget,name_list[count]
                    count += 1
                    
    def __len__(self):
        return len(self.dl.dataset)
    
class Dice_th_pred(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.01), axis=1): 
        self.axis = axis
        self.ths = ths
        self.reset()
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self,p,t):
        pred,targ = flatten_check(p, t)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 2.0*self.inter/self.union, 
                            torch.zeros_like(self.union))
        return dices
    
def save_img(data,name,out):
    data = data.float().cpu().numpy()
    img = cv2.imencode('.png',(data*255).astype(np.uint8))[1]
    out.writestr(name, img)

# %% [markdown]
# # Train

# %%
# ## callbacks - early stopping, save model
# cbs=[EarlyStoppingCallback(monitor='valid_loss', min_delta=0, patience=5),
#      SaveModelCallback(monitor='dice_th',comp=np.greater)]

# %%
dice = Dice_th_pred(np.arange(0.2,0.7,0.01))
for fold in range(1):
    # ds_t = HuBMAPDataset(fold=fold, train=True, tfms=get_aug())
    ds_t = HuBMAPDataset(fold=fold, train=True)
    ds_v = HuBMAPDataset(fold=fold, train=False)
    data = ImageDataLoaders.from_dsets(ds_t,ds_v,bs=bs,
                num_workers=NUM_WORKERS,pin_memory=True).cuda()
    model = EffUnet('efficientnet-b4').cuda()
    learn = Learner(data, model, loss_func=symmetric_lovasz,
                metrics=[Dice_soft(),Dice_th()], 
                splitter=split_layers,
                cbs=WandbCallback())
    # .to_fp16(clip=0.5)
    
    #start with training the head
    learn.freeze_to(-1) #doesn't work
    for param in learn.opt.param_groups[0]['params']:
        param.requires_grad = False
    learn.fit_one_cycle(head_epochs, lr_max=lr_max)

    #continue training full model
    learn.unfreeze()
    learn.fit_one_cycle(full_epochs, lr_max=lr_slice,
        # cbs=SaveModelCallback(monitor='valid_loss',comp=np.less))
        cbs=SaveModelCallback(monitor='dice_th',comp=np.greater))
    torch.save(learn.model.state_dict(),f'model_{fold}.pth')
    
    #model evaluation on val and saving the masks
    mp = Model_pred(learn.model,learn.dls.loaders[1])
    with zipfile.ZipFile('val_masks_tta.zip', 'a') as out:
        for p in progress_bar(mp):
            dice.accumulate(p[0],p[1])
            save_img(p[0],p[2],out)
    gc.collect()
# Out:
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'HuBMAPDataset' object has no attribute 'items'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.669066</td>
#       <td>28.697601</td>
#       <td>0.069928</td>
#       <td>0.163111</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.483034</td>
#       <td>1.464766</td>
#       <td>0.374031</td>
#       <td>0.555915</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.366126</td>
#       <td>1.705701</td>
#       <td>0.475373</td>
#       <td>0.583702</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.279377</td>
#       <td>1.339789</td>
#       <td>0.492963</td>
#       <td>0.631469</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.257564</td>
#       <td>1.334115</td>
#       <td>0.531827</td>
#       <td>0.644273</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.189229</td>
#       <td>1.294873</td>
#       <td>0.534342</td>
#       <td>0.661396</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.171045</td>
#       <td>1.312017</td>
#       <td>0.562890</td>
#       <td>0.659790</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.104069</td>
#       <td>1.237327</td>
#       <td>0.599081</td>
#       <td>0.742215</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.034800</td>
#       <td>1.221888</td>
#       <td>0.657405</td>
#       <td>0.747821</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.983145</td>
#       <td>1.185539</td>
#       <td>0.678936</td>
#       <td>0.774095</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.958413</td>
#       <td>1.196493</td>
#       <td>0.679469</td>
#       <td>0.771714</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.870869</td>
#       <td>1.172830</td>
#       <td>0.645422</td>
#       <td>0.755861</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.878439</td>
#       <td>1.157091</td>
#       <td>0.704693</td>
#       <td>0.783506</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.782508</td>
#       <td>1.114249</td>
#       <td>0.734964</td>
#       <td>0.806426</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.802696</td>
#       <td>1.109985</td>
#       <td>0.703395</td>
#       <td>0.768249</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.712696</td>
#       <td>1.105591</td>
#       <td>0.765134</td>
#       <td>0.811511</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.714839</td>
#       <td>1.206727</td>
#       <td>0.770371</td>
#       <td>0.825349</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.649713</td>
#       <td>1.029262</td>
#       <td>0.769228</td>
#       <td>0.824085</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.627908</td>
#       <td>1.170878</td>
#       <td>0.773358</td>
#       <td>0.805199</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.583007</td>
#       <td>1.086599</td>
#       <td>0.817236</td>
#       <td>0.851217</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.519848</td>
#       <td>1.081987</td>
#       <td>0.822220</td>
#       <td>0.850326</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.470501</td>
#       <td>1.506333</td>
#       <td>0.809521</td>
#       <td>0.831466</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.454636</td>
#       <td>1.185193</td>
#       <td>0.823432</td>
#       <td>0.851154</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.470457</td>
#       <td>1.057422</td>
#       <td>0.814170</td>
#       <td>0.843764</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.409242</td>
#       <td>1.346637</td>
#       <td>0.838226</td>
#       <td>0.861008</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.437464</td>
#       <td>1.219992</td>
#       <td>0.812441</td>
#       <td>0.837678</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.367402</td>
#       <td>1.238737</td>
#       <td>0.837168</td>
#       <td>0.854036</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.364958</td>
#       <td>1.312810</td>
#       <td>0.820341</td>
#       <td>0.837366</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.350780</td>
#       <td>1.643571</td>
#       <td>0.793955</td>
#       <td>0.805483</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.361674</td>
#       <td>1.297357</td>
#       <td>0.831683</td>
#       <td>0.849465</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.347752</td>
#       <td>1.210441</td>
#       <td>0.822409</td>
#       <td>0.839689</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.291962</td>
#       <td>1.309055</td>
#       <td>0.847138</td>
#       <td>0.857550</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.293603</td>
#       <td>1.232081</td>
#       <td>0.841063</td>
#       <td>0.854467</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.298061</td>
#       <td>1.273741</td>
#       <td>0.846859</td>
#       <td>0.858894</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.250322</td>
#       <td>1.358319</td>
#       <td>0.849796</td>
#       <td>0.859428</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.236126</td>
#       <td>1.381840</td>
#       <td>0.841934</td>
#       <td>0.852855</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.234144</td>
#       <td>1.432261</td>
#       <td>0.848496</td>
#       <td>0.857390</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.243076</td>
#       <td>1.410791</td>
#       <td>0.844913</td>
#       <td>0.854118</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.239152</td>
#       <td>1.522816</td>
#       <td>0.848149</td>
#       <td>0.856977</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.231014</td>
#       <td>1.541983</td>
#       <td>0.848691</td>
#       <td>0.858079</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.200540</td>
#       <td>1.466141</td>
#       <td>0.852118</td>
#       <td>0.859151</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.199248</td>
#       <td>1.538983</td>
#       <td>0.852062</td>
#       <td>0.859752</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.201312</td>
#       <td>1.551615</td>
#       <td>0.849025</td>
#       <td>0.857769</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.179733</td>
#       <td>1.632308</td>
#       <td>0.852949</td>
#       <td>0.859714</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.185959</td>
#       <td>1.614210</td>
#       <td>0.853195</td>
#       <td>0.860992</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.167519</td>
#       <td>1.619460</td>
#       <td>0.854914</td>
#       <td>0.862147</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.160443</td>
#       <td>1.752346</td>
#       <td>0.848682</td>
#       <td>0.857341</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.149447</td>
#       <td>1.692791</td>
#       <td>0.854199</td>
#       <td>0.861023</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.165213</td>
#       <td>1.734013</td>
#       <td>0.850884</td>
#       <td>0.858985</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.149000</td>
#       <td>1.773285</td>
#       <td>0.850745</td>
#       <td>0.859302</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.153830</td>
#       <td>1.782602</td>
#       <td>0.852236</td>
#       <td>0.859511</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.150229</td>
#       <td>1.783582</td>
#       <td>0.851851</td>
#       <td>0.859937</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.159584</td>
#       <td>1.795396</td>
#       <td>0.851821</td>
#       <td>0.859695</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.152086</td>
#       <td>1.770829</td>
#       <td>0.852001</td>
#       <td>0.859616</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.153317</td>
#       <td>1.760305</td>
#       <td>0.851928</td>
#       <td>0.859886</td>
#       <td>03:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice_th value: 0.6613963842391968.
# Better model found at epoch 2 with dice_th value: 0.742214560508728.
# Better model found at epoch 3 with dice_th value: 0.7478211522102356.
# Better model found at epoch 4 with dice_th value: 0.7740950584411621.
# Better model found at epoch 7 with dice_th value: 0.7835060954093933.
# Better model found at epoch 8 with dice_th value: 0.8064264059066772.
# Better model found at epoch 10 with dice_th value: 0.8115109205245972.
# Better model found at epoch 11 with dice_th value: 0.8253487944602966.
# Better model found at epoch 14 with dice_th value: 0.8512170314788818.
# Better model found at epoch 19 with dice_th value: 0.8610076308250427.
# Better model found at epoch 40 with dice_th value: 0.86214679479599.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='352' class='' max='352' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [352/352 01:28&lt;00:00]
#     </div>

# %%
dices = dice.value
noise_ths = dice.ths
best_dice = dices.max()
best_thr = noise_ths[dices.argmax()]
plt.figure(figsize=(8,4))
plt.plot(noise_ths, dices, color='blue')
plt.vlines(x=best_thr, ymin=dices.min(), ymax=dices.max(), colors='black')
d = dices.max() - dices.min()
plt.text(noise_ths[-1]-0.1, best_dice-0.1*d, f'DICE = {best_dice:.3f}', fontsize=12);
plt.text(noise_ths[-1]-0.1, best_dice-0.2*d, f'TH = {best_thr:.3f}', fontsize=12);
plt.show()

# %%
# !mkdir {dataset_name}
# !mv ./model_0.pth ./{dataset_name}
# !mv ./model_1.pth ./{dataset_name}
# !mv ./model_2.pth ./{dataset_name}
# !mv ./model_3.pth ./{dataset_name}

# %%
# !zip /content/drive/MyDrive/data/kaggle/main_test/{dataset_name}.zip -r ./{dataset_name}
# Out:
# updating: effib4_conv_origin_768_r2_binary_dataset/ (stored 0%)
# updating: effib4_conv_origin_768_r2_binary_dataset/model_0.pth (deflated 7%)
