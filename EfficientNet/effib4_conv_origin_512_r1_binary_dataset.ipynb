# %% [markdown]
# <a href="https://colab.research.google.com/github/heokwon/i-seg-you/blob/main/fast_ai_starter_efficientnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Wed Sep  7 13:30:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Download

# %%
# !pip install rasterio efficientnet_pytorch wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 15.5 MB/s
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Collecting wandb
#   Downloading wandb-0.13.2-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 57.2 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio) (57.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (22.1.0)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.21.6)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2022.6.15)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.12.1+cu113)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 77.7 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 88.5 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.1.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 47.0 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 32.1 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 74.4 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 95.0 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 97.6 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 97.8 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 92.9 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 75.3 MB/s
# Building wheels for collected packages: efficientnet-pytorch, pathtools
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=b9a7bbef20450837145d09d83d754a11aeb0f2081ab0429a733c1dfff44a78c2
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=996a5e569d8197ccc91f53a56045c6951687000f42fd8f8f59b23d3b6ee21f5c
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built efficientnet-pytorch pathtools
# Installing collected packages: smmap, gitdb, snuggs, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, cligj, click-plugins, affine, wandb, rasterio, efficientnet-pytorch
# Successfully installed GitPython-3.1.27 affine-2.3.1 click-plugins-1.1.1 cligj-0.7.2 docker-pycreds-0.4.0 efficientnet-pytorch-0.7.1 gitdb-4.0.9 pathtools-0.1.2 rasterio-1.2.10 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 snuggs-1.4.7 wandb-0.13.2

# %%
# !git clone https://github.com/albumentations-team/albumentations.git
# Out:
# Cloning into 'albumentations'...
# remote: Enumerating objects: 5186, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 5186 (delta 145), reused 128 (delta 85), pack-reused 4960
# Receiving objects: 100% (5186/5186), 99.75 MiB | 21.05 MiB/s, done.
# Resolving deltas: 100% (3580/3580), done.

# %% [markdown]
# # Wandb login

# %%
import os

os.environ["WANDB_NOTEBOOK_NAME"] = "effib4_conv_origin_512_r2_binary_dataset .ipynb"

# %%
import wandb
wandb.login()
# Out:
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find effib4_conv_origin_512_r2_binary_dataset .ipynb.
# wandb: Currently logged in as: jcjang. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # Project Name

# %%
from fastai.callback.wandb import *

# start logging a wandb run
wandb.init(project='HuBMAP + HPA - Hacking the Human Body => Main_testing')
wandb.run.name = 'effib4_conv_origin_512_r1_binary_dataset_test2'
# Out:
# Tracking run with wandb version 0.13.2
# Run data is saved locally in <code>/content/wandb/run-20220907_235755-30waj9o1</code>
# Syncing run <strong><a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing/runs/30waj9o1" target="_blank">fresh-bush-10</a></strong> to <a href="https://wandb.ai/jcjang/HuBMAP%20%2B%20HPA%20-%20Hacking%20the%20Human%20Body%20%3D%3E%20Main_testing" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# # Load Dataset

# %%
import zipfile

zip_path = '/content/drive/MyDrive/Colab Notebooks/alpaco/Team_1. CODEnter [ Save Form : Name_FileName_Date ]/3. 공모전/참고/Dataset/Converting/Main_dataset/conv_origin_768_r2_binary_dataset.zip'
fantasy_zip = zipfile.ZipFile(zip_path)
fantasy_zip.extractall('/content')

fantasy_zip.close()

# %%
# !gdown 1-EgqXvM6qZ8ZR8AzfKWrX0VvWSswU5yI
# !unzip /content/conv_origin_512_r1_binary_dataset.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: conv_512_r1_dataset/images/20478_0006.png
#   inflating: conv_512_r1_dataset/images/20831_0021.png
#   inflating: conv_512_r1_dataset/images/6318_0021.png
#   inflating: conv_512_r1_dataset/images/7706_0029.png
#   inflating: conv_512_r1_dataset/images/3959_0022.png
#   inflating: conv_512_r1_dataset/images/7569_0023.png
#   inflating: conv_512_r1_dataset/images/2174_0027.png
#   inflating: conv_512_r1_dataset/images/11645_0019.png
#   inflating: conv_512_r1_dataset/images/25641_0009.png
#   inflating: conv_512_r1_dataset/images/18445_0020.png
#   inflating: conv_512_r1_dataset/images/16728_0022.png
#   inflating: conv_512_r1_dataset/images/28963_0005.png
#   inflating: conv_512_r1_dataset/images/16890_0021.png
#   inflating: conv_512_r1_dataset/images/10611_0006.png
#   inflating: conv_512_r1_dataset/images/27298_0008.png
#   inflating: conv_512_r1_dataset/images/19377_0012.png
#   inflating: conv_512_r1_dataset/images/27340_0004.png
#   inflating: conv_512_r1_dataset/images/9769_0014.png
#   inflating: conv_512_r1_dataset/images/17126_0016.png
#   inflating: conv_512_r1_dataset/images/22718_0025.png
#   inflating: conv_512_r1_dataset/images/26982_0003.png
#   inflating: conv_512_r1_dataset/images/15732_0011.png
#   inflating: conv_512_r1_dataset/images/30394_0019.png
#   inflating: conv_512_r1_dataset/images/5552_0009.png
#   inflating: conv_512_r1_dataset/images/676_0014.png
#   inflating: conv_512_r1_dataset/images/5832_0004.png
#   inflating: conv_512_r1_dataset/images/18445_0013.png
#   inflating: conv_512_r1_dataset/images/4561_0006.png
#   inflating: conv_512_r1_dataset/images/10611_0021.png
#   inflating: conv_512_r1_dataset/images/16728_0025.png
#   inflating: conv_512_r1_dataset/images/23252_0013.png
#   inflating: conv_512_r1_dataset/images/25945_0018.png
#   inflating: conv_512_r1_dataset/images/2079_0013.png
#   inflating: conv_512_r1_dataset/images/13034_0025.png
#   inflating: conv_512_r1_dataset/images/2874_0018.png
#   inflating: conv_512_r1_dataset/images/21195_0028.png
#   inflating: conv_512_r1_dataset/images/8894_0015.png
#   inflating: conv_512_r1_dataset/images/30194_0032.png
#   inflating: conv_512_r1_dataset/images/20563_0014.png
#   inflating: conv_512_r1_dataset/images/29610_0023.png
#   inflating: conv_512_r1_dataset/images/25430_0009.png
#   inflating: conv_512_r1_dataset/images/28189_0008.png
#   inflating: conv_512_r1_dataset/images/19507_0022.png
#   inflating: conv_512_r1_dataset/images/22995_0034.png
#   inflating: conv_512_r1_dataset/images/10651_0027.png
#   inflating: conv_512_r1_dataset/images/28045_0018.png
#   inflating: conv_512_r1_dataset/images/9387_0007.png
#   inflating: conv_512_r1_dataset/images/11448_0011.png
#   inflating: conv_512_r1_dataset/images/27128_0008.png
#   inflating: conv_512_r1_dataset/images/25516_0020.png
#   inflating: conv_512_r1_dataset/images/30355_0008.png
#   inflating: conv_512_r1_dataset/images/28045_0028.png
#   inflating: conv_512_r1_dataset/images/23252_0025.png
#   inflating: conv_512_r1_dataset/images/23828_0027.png
#   inflating: conv_512_r1_dataset/images/1168_0012.png
#   inflating: conv_512_r1_dataset/images/16362_0020.png
#   inflating: conv_512_r1_dataset/images/21129_0034.png
#   inflating: conv_512_r1_dataset/images/10610_0016.png
#   inflating: conv_512_r1_dataset/images/29809_0019.png
#   inflating: conv_512_r1_dataset/images/62_0017.png
#   inflating: conv_512_r1_dataset/images/16163_0008.png
#   inflating: conv_512_r1_dataset/images/12827_0013.png
#   inflating: conv_512_r1_dataset/images/4265_0012.png
#   inflating: conv_512_r1_dataset/images/26664_0007.png
#   inflating: conv_512_r1_dataset/images/10392_0033.png
#   inflating: conv_512_r1_dataset/images/24833_0021.png
#   inflating: conv_512_r1_dataset/images/21086_0013.png
#   inflating: conv_512_r1_dataset/images/29424_0002.png
#   inflating: conv_512_r1_dataset/images/15499_0008.png
#   inflating: conv_512_r1_dataset/images/8388_0004.png
#   inflating: conv_512_r1_dataset/images/31733_0001.png
#   inflating: conv_512_r1_dataset/images/5317_0001.png
#   inflating: conv_512_r1_dataset/images/25620_0013.png
#   inflating: conv_512_r1_dataset/images/18401_0029.png
#   inflating: conv_512_r1_dataset/images/8876_0007.png
#   inflating: conv_512_r1_dataset/images/26664_0032.png
#   inflating: conv_512_r1_dataset/images/27879_0019.png
#   inflating: conv_512_r1_dataset/images/30876_0034.png
#   inflating: conv_512_r1_dataset/images/2696_0029.png
#   inflating: conv_512_r1_dataset/images/2874_0013.png
#   inflating: conv_512_r1_dataset/images/17455_0033.png
#   inflating: conv_512_r1_dataset/images/127_0004.png
#   inflating: conv_512_r1_dataset/images/23051_0026.png
#   inflating: conv_512_r1_dataset/images/21321_0016.png
#   inflating: conv_512_r1_dataset/images/7706_0015.png
#   inflating: conv_512_r1_dataset/images/16659_0023.png
#   inflating: conv_512_r1_dataset/images/2174_0016.png
#   inflating: conv_512_r1_dataset/images/18792_0014.png
#   inflating: conv_512_r1_dataset/images/16711_0008.png
#   inflating: conv_512_r1_dataset/images/13483_0018.png
#   inflating: conv_512_r1_dataset/images/24194_0002.png
#   inflating: conv_512_r1_dataset/images/11890_0002.png
#   inflating: conv_512_r1_dataset/images/22741_0002.png
#   inflating: conv_512_r1_dataset/images/6730_0013.png
#   inflating: conv_512_r1_dataset/images/660_0034.png
#   inflating: conv_512_r1_dataset/images/9358_0013.png
#   inflating: conv_512_r1_dataset/images/24961_0004.png
#   inflating: conv_512_r1_dataset/images/24222_0004.png
#   inflating: conv_512_r1_dataset/images/31139_0010.png
#   inflating: conv_512_r1_dataset/images/3959_0027.png
#   inflating: conv_512_r1_dataset/images/24961_0003.png
#   inflating: conv_512_r1_dataset/images/17422_0018.png
#   inflating: conv_512_r1_dataset/images/29809_0003.png
#   inflating: conv_512_r1_dataset/images/9769_0027.png
#   inflating: conv_512_r1_dataset/images/30474_0012.png
#   inflating: conv_512_r1_dataset/images/27471_0008.png
#   inflating: conv_512_r1_dataset/images/25298_0033.png
#   inflating: conv_512_r1_dataset/images/17187_0003.png
#   inflating: conv_512_r1_dataset/images/23252_0008.png
#   inflating: conv_512_r1_dataset/images/8842_0027.png
#   inflating: conv_512_r1_dataset/images/24833_0031.png
#   inflating: conv_512_r1_dataset/images/29690_0012.png
#   inflating: conv_512_r1_dataset/images/28940_0008.png
#   inflating: conv_512_r1_dataset/images/26101_0033.png
#   inflating: conv_512_r1_dataset/images/20955_0003.png
#   inflating: conv_512_r1_dataset/images/8894_0013.png
#   inflating: conv_512_r1_dataset/images/10912_0008.png
#   inflating: conv_512_r1_dataset/images/30224_0017.png
#   inflating: conv_512_r1_dataset/images/31571_0022.png
#   inflating: conv_512_r1_dataset/images/21039_0027.png
#   inflating: conv_512_r1_dataset/images/351_0022.png
#   inflating: conv_512_r1_dataset/images/7706_0021.png
#   inflating: conv_512_r1_dataset/images/22035_0021.png
#   inflating: conv_512_r1_dataset/images/8231_0015.png
#   inflating: conv_512_r1_dataset/images/28318_0026.png
#   inflating: conv_512_r1_dataset/images/16163_0018.png
#   inflating: conv_512_r1_dataset/images/9453_0009.png
#   inflating: conv_512_r1_dataset/images/144_0014.png
#   inflating: conv_512_r1_dataset/images/23243_0021.png
#   inflating: conv_512_r1_dataset/images/8502_0002.png
#   inflating: conv_512_r1_dataset/images/12784_0011.png
#   inflating: conv_512_r1_dataset/images/30474_0005.png
#   inflating: conv_512_r1_dataset/images/31571_0017.png
#   inflating: conv_512_r1_dataset/images/20520_0021.png
#   inflating: conv_512_r1_dataset/images/6120_0034.png
#   inflating: conv_512_r1_dataset/images/4301_0021.png
#   inflating: conv_512_r1_dataset/images/15706_0003.png
#   inflating: conv_512_r1_dataset/images/19048_0026.png
#   inflating: conv_512_r1_dataset/images/21501_0025.png
#   inflating: conv_512_r1_dataset/images/9387_0008.png
#   inflating: conv_512_r1_dataset/images/12483_0026.png
#   inflating: conv_512_r1_dataset/images/30294_0034.png
#   inflating: conv_512_r1_dataset/images/4776_0016.png
#   inflating: conv_512_r1_dataset/images/10610_0012.png
#   inflating: conv_512_r1_dataset/images/22059_0022.png
#   inflating: conv_512_r1_dataset/images/928_0022.png
#   inflating: conv_512_r1_dataset/images/26101_0007.png
#   inflating: conv_512_r1_dataset/images/30080_0033.png
#   inflating: conv_512_r1_dataset/images/31698_0015.png
#   inflating: conv_512_r1_dataset/images/23961_0021.png
#   inflating: conv_512_r1_dataset/images/24961_0014.png
#   inflating: conv_512_r1_dataset/images/27879_0011.png
#   inflating: conv_512_r1_dataset/images/32231_0016.png
#   inflating: conv_512_r1_dataset/images/30474_0027.png
#   inflating: conv_512_r1_dataset/images/20247_0019.png
#   inflating: conv_512_r1_dataset/images/351_0029.png
#   inflating: conv_512_r1_dataset/images/21321_0011.png
#   inflating: conv_512_r1_dataset/images/27861_0024.png
#   inflating: conv_512_r1_dataset/images/2668_0007.png
#   inflating: conv_512_r1_dataset/images/28657_0017.png
#   inflating: conv_512_r1_dataset/images/20440_0003.png
#   inflating: conv_512_r1_dataset/images/23665_0010.png
#   inflating: conv_512_r1_dataset/images/5995_0013.png
#   inflating: conv_512_r1_dataset/images/10488_0026.png
#   inflating: conv_512_r1_dataset/images/4944_0001.png
#   inflating: conv_512_r1_dataset/images/9445_0019.png
#   inflating: conv_512_r1_dataset/images/30765_0023.png
#   inflating: conv_512_r1_dataset/images/32741_0027.png
#   inflating: conv_512_r1_dataset/images/25298_0009.png
#   inflating: conv_512_r1_dataset/images/21501_0012.png
#   inflating: conv_512_r1_dataset/images/26319_0002.png
#   inflating: conv_512_r1_dataset/images/2344_0022.png
#   inflating: conv_512_r1_dataset/images/24522_0017.png
#   inflating: conv_512_r1_dataset/images/6807_0011.png
#   inflating: conv_512_r1_dataset/images/10971_0014.png
#   inflating: conv_512_r1_dataset/images/7169_0029.png
#   inflating: conv_512_r1_dataset/images/6120_0025.png
#   inflating: conv_512_r1_dataset/images/30394_0001.png
#   inflating: conv_512_r1_dataset/images/5583_0024.png
#   inflating: conv_512_r1_dataset/images/5099_0013.png
#   inflating: conv_512_r1_dataset/images/15124_0027.png
#   inflating: conv_512_r1_dataset/images/8227_0003.png
#   inflating: conv_512_r1_dataset/images/26982_0018.png
#   inflating: conv_512_r1_dataset/images/7569_0028.png
#   inflating: conv_512_r1_dataset/images/20302_0019.png
#   inflating: conv_512_r1_dataset/images/28963_0011.png
#   inflating: conv_512_r1_dataset/images/2447_0023.png
#   inflating: conv_512_r1_dataset/images/9450_0013.png
#   inflating: conv_512_r1_dataset/images/30424_0017.png
#   inflating: conv_512_r1_dataset/images/21195_0029.png
#   inflating: conv_512_r1_dataset/images/27128_0024.png
#   inflating: conv_512_r1_dataset/images/30294_0032.png
#   inflating: conv_512_r1_dataset/images/19569_0013.png
#   inflating: conv_512_r1_dataset/images/27298_0033.png
#   inflating: conv_512_r1_dataset/images/26886_0016.png
#   inflating: conv_512_r1_dataset/images/32151_0015.png
#   inflating: conv_512_r1_dataset/images/31675_0033.png
#   inflating: conv_512_r1_dataset/images/24100_0029.png
#   inflating: conv_512_r1_dataset/images/16214_0008.png
#   inflating: conv_512_r1_dataset/images/18900_0006.png
#   inflating: conv_512_r1_dataset/images/26174_0014.png
#   inflating: conv_512_r1_dataset/images/737_0008.png
#   inflating: conv_512_r1_dataset/images/1955_0016.png
#   inflating: conv_512_r1_dataset/images/20247_0018.png
#   inflating: conv_512_r1_dataset/images/12026_0026.png
#   inflating: conv_512_r1_dataset/images/18777_0008.png
#   inflating: conv_512_r1_dataset/images/2424_0016.png
#   inflating: conv_512_r1_dataset/images/30355_0014.png
#   inflating: conv_512_r1_dataset/images/28940_0021.png
#   inflating: conv_512_r1_dataset/images/9791_0033.png
#   inflating: conv_512_r1_dataset/images/23640_0033.png
#   inflating: conv_512_r1_dataset/images/3057_0004.png
#   inflating: conv_512_r1_dataset/images/5552_0033.png
#   inflating: conv_512_r1_dataset/images/32009_0006.png
#   inflating: conv_512_r1_dataset/images/29809_0004.png
#   inflating: conv_512_r1_dataset/images/12244_0009.png
#   inflating: conv_512_r1_dataset/images/23252_0020.png
#   inflating: conv_512_r1_dataset/images/18426_0021.png
#   inflating: conv_512_r1_dataset/images/30224_0030.png
#   inflating: conv_512_r1_dataset/images/23880_0012.png
#   inflating: conv_512_r1_dataset/images/31139_0032.png
#   inflating: conv_512_r1_dataset/images/5995_0019.png
#   inflating: conv_512_r1_dataset/images/9791_0015.png
#   inflating: conv_512_r1_dataset/images/15329_0032.png
#   inflating: conv_512_r1_dataset/images/22016_0032.png
#   inflating: conv_512_r1_dataset/images/9769_0008.png
#   inflating: conv_512_r1_dataset/images/20302_0024.png
#   inflating: conv_512_r1_dataset/images/8227_0021.png
#   inflating: conv_512_r1_dataset/images/7902_0017.png
#   inflating: conv_512_r1_dataset/images/21195_0007.png
#   inflating: conv_512_r1_dataset/images/30765_0014.png
#   inflating: conv_512_r1_dataset/images/11629_0021.png
#   inflating: conv_512_r1_dataset/images/164_0013.png
#   inflating: conv_512_r1_dataset/images/13483_0017.png
#   inflating: conv_512_r1_dataset/images/16728_0002.png
#   inflating: conv_512_r1_dataset/images/24269_0002.png
#   inflating: conv_512_r1_dataset/images/28748_0034.png
#   inflating: conv_512_r1_dataset/images/17455_0013.png
#   inflating: conv_512_r1_dataset/images/27232_0008.png
#   inflating: conv_512_r1_dataset/images/2279_0012.png
#   inflating: conv_512_r1_dataset/images/203_0018.png
#   inflating: conv_512_r1_dataset/images/10703_0015.png
#   inflating: conv_512_r1_dataset/images/16216_0028.png
#   inflating: conv_512_r1_dataset/images/8151_0019.png
#   inflating: conv_512_r1_dataset/images/5995_0015.png
#   inflating: conv_512_r1_dataset/images/13189_0002.png
#   inflating: conv_512_r1_dataset/images/32412_0012.png
#   inflating: conv_512_r1_dataset/images/31406_0026.png
#   inflating: conv_512_r1_dataset/images/21321_0013.png
#   inflating: conv_512_r1_dataset/images/27781_0020.png
#   inflating: conv_512_r1_dataset/images/27879_0025.png
#   inflating: conv_512_r1_dataset/images/9904_0014.png
#   inflating: conv_512_r1_dataset/images/22310_0003.png
#   inflating: conv_512_r1_dataset/images/27232_0019.png
#   inflating: conv_512_r1_dataset/images/21155_0014.png
#   inflating: conv_512_r1_dataset/images/31698_0018.png
#   inflating: conv_512_r1_dataset/images/21129_0020.png
#   inflating: conv_512_r1_dataset/images/4944_0020.png
#   inflating: conv_512_r1_dataset/images/10610_0021.png
#   inflating: conv_512_r1_dataset/images/6730_0019.png
#   inflating: conv_512_r1_dataset/images/62_0020.png
#   inflating: conv_512_r1_dataset/images/23051_0007.png
#   inflating: conv_512_r1_dataset/images/26101_0019.png
#   inflating: conv_512_r1_dataset/images/10971_0007.png
#   inflating: conv_512_r1_dataset/images/31406_0031.png
#   inflating: conv_512_r1_dataset/images/13034_0018.png
#   inflating: conv_512_r1_dataset/images/2079_0018.png
#   inflating: conv_512_r1_dataset/images/1123_0025.png
#   inflating: conv_512_r1_dataset/images/9445_0016.png
#   inflating: conv_512_r1_dataset/images/29307_0002.png
#   inflating: conv_512_r1_dataset/images/18777_0024.png
#   inflating: conv_512_r1_dataset/images/9445_0020.png
#   inflating: conv_512_r1_dataset/images/22016_0029.png
#   inflating: conv_512_r1_dataset/images/8151_0003.png
#   inflating: conv_512_r1_dataset/images/10971_0029.png
#   inflating: conv_512_r1_dataset/images/20831_0019.png
#   inflating: conv_512_r1_dataset/images/9358_0007.png
#   inflating: conv_512_r1_dataset/images/10392_0029.png
#   inflating: conv_512_r1_dataset/images/22718_0002.png
#   inflating: conv_512_r1_dataset/images/20478_0026.png
#   inflating: conv_512_r1_dataset/images/17187_0004.png
#   inflating: conv_512_r1_dataset/images/14407_0033.png
#   inflating: conv_512_r1_dataset/images/9450_0015.png
#   inflating: conv_512_r1_dataset/images/12784_0028.png
#   inflating: conv_512_r1_dataset/images/30294_0003.png
#   inflating: conv_512_r1_dataset/images/32231_0028.png
#   inflating: conv_512_r1_dataset/images/20440_0013.png
#   inflating: conv_512_r1_dataset/images/2344_0026.png
#   inflating: conv_512_r1_dataset/images/28657_0025.png
#   inflating: conv_512_r1_dataset/images/203_0032.png
#   inflating: conv_512_r1_dataset/images/19569_0022.png
#   inflating: conv_512_r1_dataset/images/24833_0025.png
#   inflating: conv_512_r1_dataset/images/18792_0010.png
#   inflating: conv_512_r1_dataset/images/28052_0016.png
#   inflating: conv_512_r1_dataset/images/2447_0008.png
#   inflating: conv_512_r1_dataset/images/28262_0006.png
#   inflating: conv_512_r1_dataset/images/32126_0020.png
#   inflating: conv_512_r1_dataset/images/8388_0033.png
#   inflating: conv_512_r1_dataset/images/11662_0001.png
#   inflating: conv_512_r1_dataset/images/20247_0026.png
#   inflating: conv_512_r1_dataset/images/19360_0022.png
#   inflating: conv_512_r1_dataset/images/8752_0009.png
#   inflating: conv_512_r1_dataset/images/676_0016.png
#   inflating: conv_512_r1_dataset/images/23252_0014.png
#   inflating: conv_512_r1_dataset/images/127_0011.png
#   inflating: conv_512_r1_dataset/images/10392_0011.png
#   inflating: conv_512_r1_dataset/images/22718_0018.png
#   inflating: conv_512_r1_dataset/images/27879_0009.png
#   inflating: conv_512_r1_dataset/images/10666_0020.png
#   inflating: conv_512_r1_dataset/images/8502_0022.png
#   inflating: conv_512_r1_dataset/images/9769_0021.png
#   inflating: conv_512_r1_dataset/images/1184_0021.png
#   inflating: conv_512_r1_dataset/images/30581_0008.png
#   inflating: conv_512_r1_dataset/images/4776_0004.png
#   inflating: conv_512_r1_dataset/images/9358_0024.png
#   inflating: conv_512_r1_dataset/images/6730_0002.png
#   inflating: conv_512_r1_dataset/images/9387_0034.png
#   inflating: conv_512_r1_dataset/images/4802_0016.png
#   inflating: conv_512_r1_dataset/images/21358_0026.png
#   inflating: conv_512_r1_dataset/images/13396_0007.png
#   inflating: conv_512_r1_dataset/images/6807_0034.png
#   inflating: conv_512_r1_dataset/images/15706_0034.png
#   inflating: conv_512_r1_dataset/images/24241_0015.png
#   inflating: conv_512_r1_dataset/images/10892_0001.png
#   inflating: conv_512_r1_dataset/images/5583_0007.png
#   inflating: conv_512_r1_dataset/images/19533_0013.png
#   inflating: conv_512_r1_dataset/images/22016_0013.png
#   inflating: conv_512_r1_dataset/images/4301_0015.png
#   inflating: conv_512_r1_dataset/images/27340_0023.png
#   inflating: conv_512_r1_dataset/images/27587_0032.png
#   inflating: conv_512_r1_dataset/images/8116_0021.png
#   inflating: conv_512_r1_dataset/images/27781_0023.png
#   inflating: conv_512_r1_dataset/images/18426_0027.png
#   inflating: conv_512_r1_dataset/images/737_0007.png
#   inflating: conv_512_r1_dataset/images/28791_0017.png
#   inflating: conv_512_r1_dataset/images/30581_0034.png
#   inflating: conv_512_r1_dataset/images/1850_0007.png
#   inflating: conv_512_r1_dataset/images/23961_0013.png
#   inflating: conv_512_r1_dataset/images/32741_0001.png
#   inflating: conv_512_r1_dataset/images/29213_0029.png
#   inflating: conv_512_r1_dataset/images/7169_0014.png
#   inflating: conv_512_r1_dataset/images/30765_0009.png
#   inflating: conv_512_r1_dataset/images/8343_0003.png
#   inflating: conv_512_r1_dataset/images/4062_0027.png
#   inflating: conv_512_r1_dataset/images/5785_0009.png
#   inflating: conv_512_r1_dataset/images/13189_0003.png
#   inflating: conv_512_r1_dataset/images/28823_0033.png
#   inflating: conv_512_r1_dataset/images/22953_0013.png
#   inflating: conv_512_r1_dataset/images/25430_0022.png
#   inflating: conv_512_r1_dataset/images/14183_0022.png
#   inflating: conv_512_r1_dataset/images/9437_0009.png
#   inflating: conv_512_r1_dataset/images/30355_0010.png
#   inflating: conv_512_r1_dataset/images/10651_0012.png
#   inflating: conv_512_r1_dataset/images/1731_0027.png
#   inflating: conv_512_r1_dataset/images/8638_0025.png
#   inflating: conv_512_r1_dataset/images/14674_0034.png
#   inflating: conv_512_r1_dataset/images/7169_0024.png
#   inflating: conv_512_r1_dataset/images/5099_0034.png
#   inflating: conv_512_r1_dataset/images/15551_0004.png
#   inflating: conv_512_r1_dataset/images/2447_0024.png
#   inflating: conv_512_r1_dataset/images/4301_0013.png
#   inflating: conv_512_r1_dataset/images/13034_0002.png
#   inflating: conv_512_r1_dataset/images/26319_0013.png
#   inflating: conv_512_r1_dataset/images/14183_0003.png
#   inflating: conv_512_r1_dataset/images/21195_0015.png
#   inflating: conv_512_r1_dataset/images/20428_0016.png
#   inflating: conv_512_r1_dataset/images/12233_0013.png
#   inflating: conv_512_r1_dataset/images/32412_0033.png
#   inflating: conv_512_r1_dataset/images/25945_0014.png
#   inflating: conv_512_r1_dataset/images/11645_0033.png
#   inflating: conv_512_r1_dataset/images/16564_0016.png
#   inflating: conv_512_r1_dataset/images/4066_0029.png
#   inflating: conv_512_r1_dataset/images/29143_0024.png
#   inflating: conv_512_r1_dataset/images/4561_0021.png
#   inflating: conv_512_r1_dataset/images/27350_0020.png
#   inflating: conv_512_r1_dataset/images/16149_0018.png
#   inflating: conv_512_r1_dataset/images/2279_0010.png
#   inflating: conv_512_r1_dataset/images/8450_0013.png
#   inflating: conv_512_r1_dataset/images/12784_0009.png
#   inflating: conv_512_r1_dataset/images/737_0024.png
#   inflating: conv_512_r1_dataset/images/1229_0020.png
#   inflating: conv_512_r1_dataset/images/17422_0015.png
#   inflating: conv_512_r1_dataset/images/28963_0015.png
#   inflating: conv_512_r1_dataset/images/4658_0004.png
#   inflating: conv_512_r1_dataset/images/29610_0022.png
#   inflating: conv_512_r1_dataset/images/28189_0032.png
#   inflating: conv_512_r1_dataset/images/31898_0020.png
#   inflating: conv_512_r1_dataset/images/29238_0006.png
#   inflating: conv_512_r1_dataset/images/20955_0033.png
#   inflating: conv_512_r1_dataset/images/27232_0014.png
#   inflating: conv_512_r1_dataset/images/26319_0012.png
#   inflating: conv_512_r1_dataset/images/7169_0017.png
#   inflating: conv_512_r1_dataset/images/5552_0010.png
#   inflating: conv_512_r1_dataset/images/9517_0012.png
#   inflating: conv_512_r1_dataset/images/28791_0028.png
#   inflating: conv_512_r1_dataset/images/22035_0015.png
#   inflating: conv_512_r1_dataset/images/1229_0008.png
#   inflating: conv_512_r1_dataset/images/1690_0003.png
#   inflating: conv_512_r1_dataset/images/435_0029.png
#   inflating: conv_512_r1_dataset/images/14674_0028.png
#   inflating: conv_512_r1_dataset/images/7569_0008.png
#   inflating: conv_512_r1_dataset/images/25430_0033.png
#   inflating: conv_512_r1_dataset/images/19533_0025.png
#   inflating: conv_512_r1_dataset/images/16564_0002.png
#   inflating: conv_512_r1_dataset/images/5785_0027.png
#   inflating: conv_512_r1_dataset/images/29690_0010.png
#   inflating: conv_512_r1_dataset/images/12476_0022.png
#   inflating: conv_512_r1_dataset/images/1220_0001.png
#   inflating: conv_512_r1_dataset/images/20794_0012.png
#   inflating: conv_512_r1_dataset/images/24833_0016.png
#   inflating: conv_512_r1_dataset/images/1500_0022.png
#   inflating: conv_512_r1_dataset/images/21358_0014.png
#   inflating: conv_512_r1_dataset/images/928_0023.png
#   inflating: conv_512_r1_dataset/images/14396_0024.png
#   inflating: conv_512_r1_dataset/images/10992_0020.png
#   inflating: conv_512_r1_dataset/images/5785_0014.png
#   inflating: conv_512_r1_dataset/images/5932_0015.png
#   inflating: conv_512_r1_dataset/images/23243_0019.png
#   inflating: conv_512_r1_dataset/images/144_0021.png
#   inflating: conv_512_r1_dataset/images/15706_0022.png
#   inflating: conv_512_r1_dataset/images/23760_0011.png
#   inflating: conv_512_r1_dataset/images/31571_0010.png
#   inflating: conv_512_r1_dataset/images/24097_0034.png
#   inflating: conv_512_r1_dataset/images/29223_0034.png
#   inflating: conv_512_r1_dataset/images/28262_0025.png
#   inflating: conv_512_r1_dataset/images/29809_0010.png
#   inflating: conv_512_r1_dataset/images/28940_0018.png
#   inflating: conv_512_r1_dataset/images/20302_0018.png
#   inflating: conv_512_r1_dataset/images/16216_0033.png
#   inflating: conv_512_r1_dataset/images/28823_0032.png
#   inflating: conv_512_r1_dataset/images/14183_0009.png
#   inflating: conv_512_r1_dataset/images/11645_0032.png
#   inflating: conv_512_r1_dataset/images/22544_0027.png
#   inflating: conv_512_r1_dataset/images/17143_0027.png
#   inflating: conv_512_r1_dataset/images/31733_0014.png
#   inflating: conv_512_r1_dataset/images/5785_0003.png
#   inflating: conv_512_r1_dataset/images/25298_0026.png
#   inflating: conv_512_r1_dataset/images/30581_0002.png
#   inflating: conv_512_r1_dataset/images/26480_0016.png
#   inflating: conv_512_r1_dataset/images/6730_0009.png
#   inflating: conv_512_r1_dataset/images/27879_0003.png
#   inflating: conv_512_r1_dataset/images/25298_0023.png
#   inflating: conv_512_r1_dataset/images/6611_0003.png
#   inflating: conv_512_r1_dataset/images/26174_0010.png
#   inflating: conv_512_r1_dataset/images/1690_0020.png
#   inflating: conv_512_r1_dataset/images/1229_0009.png
#   inflating: conv_512_r1_dataset/images/2079_0008.png
#   inflating: conv_512_r1_dataset/images/21155_0016.png
#   inflating: conv_512_r1_dataset/images/21501_0019.png
#   inflating: conv_512_r1_dataset/images/14388_0026.png
#   inflating: conv_512_r1_dataset/images/10611_0034.png
#   inflating: conv_512_r1_dataset/images/23009_0002.png
#   inflating: conv_512_r1_dataset/images/21039_0012.png
#   inflating: conv_512_r1_dataset/images/30765_0003.png
#   inflating: conv_512_r1_dataset/images/29223_0021.png
#   inflating: conv_512_r1_dataset/images/12476_0020.png
#   inflating: conv_512_r1_dataset/images/19997_0029.png
#   inflating: conv_512_r1_dataset/images/24097_0015.png
#   inflating: conv_512_r1_dataset/images/13942_0026.png
#   inflating: conv_512_r1_dataset/images/2696_0017.png
#   inflating: conv_512_r1_dataset/images/23760_0002.png
#   inflating: conv_512_r1_dataset/images/28429_0008.png
#   inflating: conv_512_r1_dataset/images/4404_0023.png
#   inflating: conv_512_r1_dataset/images/5287_0026.png
#   inflating: conv_512_r1_dataset/images/12244_0032.png
#   inflating: conv_512_r1_dataset/images/18777_0015.png
#   inflating: conv_512_r1_dataset/images/28436_0013.png
#   inflating: conv_512_r1_dataset/images/31727_0017.png
#   inflating: conv_512_r1_dataset/images/13483_0002.png
#   inflating: conv_512_r1_dataset/images/31958_0018.png
#   inflating: conv_512_r1_dataset/images/16659_0001.png
#   inflating: conv_512_r1_dataset/images/32231_0019.png
#   inflating: conv_512_r1_dataset/images/2696_0031.png
#   inflating: conv_512_r1_dataset/images/19533_0020.png
#   inflating: conv_512_r1_dataset/images/30876_0021.png
#   inflating: conv_512_r1_dataset/images/12784_0010.png
#   inflating: conv_512_r1_dataset/images/23640_0009.png
#   inflating: conv_512_r1_dataset/images/435_0021.png
#   inflating: conv_512_r1_dataset/images/6807_0022.png
#   inflating: conv_512_r1_dataset/images/22133_0020.png
#   inflating: conv_512_r1_dataset/images/7169_0022.png
#   inflating: conv_512_r1_dataset/images/4066_0025.png
#   inflating: conv_512_r1_dataset/images/20428_0002.png
#   inflating: conv_512_r1_dataset/images/1184_0013.png
#   inflating: conv_512_r1_dataset/images/9791_0034.png
#   inflating: conv_512_r1_dataset/images/2279_0023.png
#   inflating: conv_512_r1_dataset/images/27803_0009.png
#   inflating: conv_512_r1_dataset/images/28436_0008.png
#   inflating: conv_512_r1_dataset/images/28318_0033.png
#   inflating: conv_512_r1_dataset/images/21112_0023.png
#   inflating: conv_512_r1_dataset/images/8343_0019.png
#   inflating: conv_512_r1_dataset/images/29223_0022.png
#   inflating: conv_512_r1_dataset/images/17455_0028.png
#   inflating: conv_512_r1_dataset/images/29223_0003.png
#   inflating: conv_512_r1_dataset/images/1878_0027.png
#   inflating: conv_512_r1_dataset/images/14407_0029.png
#   inflating: conv_512_r1_dataset/images/26886_0010.png
#   inflating: conv_512_r1_dataset/images/28126_0012.png
#   inflating: conv_512_r1_dataset/images/24241_0014.png
#   inflating: conv_512_r1_dataset/images/5102_0034.png
#   inflating: conv_512_r1_dataset/images/13034_0001.png
#   inflating: conv_512_r1_dataset/images/8343_0023.png
#   inflating: conv_512_r1_dataset/images/435_0033.png
#   inflating: conv_512_r1_dataset/images/27340_0015.png
#   inflating: conv_512_r1_dataset/images/10610_0003.png
#   inflating: conv_512_r1_dataset/images/4301_0029.png
#   inflating: conv_512_r1_dataset/images/6390_0003.png
#   inflating: conv_512_r1_dataset/images/9387_0021.png
#   inflating: conv_512_r1_dataset/images/928_0012.png
#   inflating: conv_512_r1_dataset/images/4777_0028.png
#   inflating: conv_512_r1_dataset/images/24241_0013.png
#   inflating: conv_512_r1_dataset/images/17187_0021.png
#   inflating: conv_512_r1_dataset/images/9517_0014.png
#   inflating: conv_512_r1_dataset/images/8222_0028.png
#   inflating: conv_512_r1_dataset/images/21112_0027.png
#   inflating: conv_512_r1_dataset/images/1168_0029.png
#   inflating: conv_512_r1_dataset/images/5102_0020.png
#   inflating: conv_512_r1_dataset/images/22236_0034.png
#   inflating: conv_512_r1_dataset/images/10912_0018.png
#   inflating: conv_512_r1_dataset/images/9777_0024.png
#   inflating: conv_512_r1_dataset/images/23051_0008.png
#   inflating: conv_512_r1_dataset/images/22035_0013.png
#   inflating: conv_512_r1_dataset/images/13942_0032.png
#   inflating: conv_512_r1_dataset/images/8842_0015.png
#   inflating: conv_512_r1_dataset/images/7569_0027.png
#   inflating: conv_512_r1_dataset/images/2279_0017.png
#   inflating: conv_512_r1_dataset/images/30500_0001.png
#   inflating: conv_512_r1_dataset/images/4066_0016.png
#   inflating: conv_512_r1_dataset/images/28318_0007.png
#   inflating: conv_512_r1_dataset/images/19533_0028.png
#   inflating: conv_512_r1_dataset/images/9517_0006.png
#   inflating: conv_512_r1_dataset/images/32126_0029.png
#   inflating: conv_512_r1_dataset/images/1690_0018.png
#   inflating: conv_512_r1_dataset/images/10044_0020.png
#   inflating: conv_512_r1_dataset/images/26982_0025.png
#   inflating: conv_512_r1_dataset/images/29809_0020.png
#   inflating: conv_512_r1_dataset/images/22953_0009.png
#   inflating: conv_512_r1_dataset/images/17143_0033.png
#   inflating: conv_512_r1_dataset/images/5287_0027.png
#   inflating: conv_512_r1_dataset/images/24100_0034.png
#   inflating: conv_512_r1_dataset/images/17422_0034.png
#   inflating: conv_512_r1_dataset/images/12471_0006.png
#   inflating: conv_512_r1_dataset/images/24269_0017.png
#   inflating: conv_512_r1_dataset/images/5099_0007.png
#   inflating: conv_512_r1_dataset/images/351_0028.png
#   inflating: conv_512_r1_dataset/images/3057_0023.png
#   inflating: conv_512_r1_dataset/images/28045_0016.png
#   inflating: conv_512_r1_dataset/images/10971_0010.png
#   inflating: conv_512_r1_dataset/images/8343_0027.png
#   inflating: conv_512_r1_dataset/images/21129_0016.png
#   inflating: conv_512_r1_dataset/images/9437_0008.png
#   inflating: conv_512_r1_dataset/images/29238_0031.png
#   inflating: conv_512_r1_dataset/images/25472_0014.png
#   inflating: conv_512_r1_dataset/images/4658_0029.png
#   inflating: conv_512_r1_dataset/images/21021_0027.png
#   inflating: conv_512_r1_dataset/images/8876_0023.png
#   inflating: conv_512_r1_dataset/images/19360_0012.png
#   inflating: conv_512_r1_dataset/images/10666_0028.png
#   inflating: conv_512_r1_dataset/images/31571_0003.png
#   inflating: conv_512_r1_dataset/images/9437_0020.png
#   inflating: conv_512_r1_dataset/images/31709_0019.png
#   inflating: conv_512_r1_dataset/images/7902_0016.png
#   inflating: conv_512_r1_dataset/images/10971_0002.png
#   inflating: conv_512_r1_dataset/images/14388_0032.png
#   inflating: conv_512_r1_dataset/images/15732_0027.png
#   inflating: conv_512_r1_dataset/images/3083_0014.png
#   inflating: conv_512_r1_dataset/images/4944_0025.png
#   inflating: conv_512_r1_dataset/images/5785_0020.png
#   inflating: conv_512_r1_dataset/images/32231_0008.png
#   inflating: conv_512_r1_dataset/images/30500_0021.png
#   inflating: conv_512_r1_dataset/images/14396_0012.png
#   inflating: conv_512_r1_dataset/images/10610_0031.png
#   inflating: conv_512_r1_dataset/images/30194_0021.png
#   inflating: conv_512_r1_dataset/images/737_0015.png
#   inflating: conv_512_r1_dataset/images/25641_0034.png
#   inflating: conv_512_r1_dataset/images/25472_0025.png
#   inflating: conv_512_r1_dataset/images/11662_0019.png
#   inflating: conv_512_r1_dataset/images/28189_0027.png
#   inflating: conv_512_r1_dataset/images/24522_0003.png
#   inflating: conv_512_r1_dataset/images/28963_0014.png
#   inflating: conv_512_r1_dataset/images/27340_0017.png
#   inflating: conv_512_r1_dataset/images/22236_0007.png
#   inflating: conv_512_r1_dataset/images/27861_0029.png
#   inflating: conv_512_r1_dataset/images/25298_0021.png
#   inflating: conv_512_r1_dataset/images/11890_0019.png
#   inflating: conv_512_r1_dataset/images/7970_0004.png
#   inflating: conv_512_r1_dataset/images/5086_0021.png
#   inflating: conv_512_r1_dataset/images/7970_0008.png
#   inflating: conv_512_r1_dataset/images/20428_0021.png
#   inflating: conv_512_r1_dataset/images/4944_0017.png
#   inflating: conv_512_r1_dataset/images/16890_0023.png
#   inflating: conv_512_r1_dataset/images/28429_0010.png
#   inflating: conv_512_r1_dataset/images/8450_0016.png
#   inflating: conv_512_r1_dataset/images/25430_0017.png
#   inflating: conv_512_r1_dataset/images/7902_0013.png
#   inflating: conv_512_r1_dataset/images/15842_0020.png
#   inflating: conv_512_r1_dataset/images/5317_0014.png
#   inflating: conv_512_r1_dataset/images/23094_0027.png
#   inflating: conv_512_r1_dataset/images/31727_0023.png
#   inflating: conv_512_r1_dataset/images/9769_0017.png
#   inflating: conv_512_r1_dataset/images/24269_0007.png
#   inflating: conv_512_r1_dataset/images/928_0009.png
#   inflating: conv_512_r1_dataset/images/9445_0034.png
#   inflating: conv_512_r1_dataset/images/20955_0011.png
#   inflating: conv_512_r1_dataset/images/28657_0008.png
#   inflating: conv_512_r1_dataset/images/5583_0022.png
#   inflating: conv_512_r1_dataset/images/19360_0002.png
#   inflating: conv_512_r1_dataset/images/2793_0014.png
#   inflating: conv_512_r1_dataset/images/27803_0022.png
#   inflating: conv_512_r1_dataset/images/19360_0006.png
#   inflating: conv_512_r1_dataset/images/8222_0000.png
#   inflating: conv_512_r1_dataset/images/6121_0013.png
#   inflating: conv_512_r1_dataset/images/27616_0028.png
#   inflating: conv_512_r1_dataset/images/20247_0031.png
#   inflating: conv_512_r1_dataset/images/12174_0011.png
#   inflating: conv_512_r1_dataset/images/4658_0007.png
#   inflating: conv_512_r1_dataset/images/10610_0009.png
#   inflating: conv_512_r1_dataset/images/30474_0032.png
#   inflating: conv_512_r1_dataset/images/6318_0003.png
#   inflating: conv_512_r1_dataset/images/8402_0014.png
#   inflating: conv_512_r1_dataset/images/4777_0026.png
#   inflating: conv_512_r1_dataset/images/30250_0010.png
#   inflating: conv_512_r1_dataset/images/2500_0014.png
#   inflating: conv_512_r1_dataset/images/15551_0020.png
#   inflating: conv_512_r1_dataset/images/26780_0026.png
#   inflating: conv_512_r1_dataset/images/12483_0015.png
#   inflating: conv_512_r1_dataset/images/676_0021.png
#   inflating: conv_512_r1_dataset/images/28262_0021.png
#   inflating: conv_512_r1_dataset/images/30084_0022.png
#   inflating: conv_512_r1_dataset/images/21039_0019.png
#   inflating: conv_512_r1_dataset/images/9517_0020.png
#   inflating: conv_512_r1_dataset/images/27340_0003.png
#   inflating: conv_512_r1_dataset/images/30355_0006.png
#   inflating: conv_512_r1_dataset/images/9231_0006.png
#   inflating: conv_512_r1_dataset/images/15732_0023.png
#   inflating: conv_512_r1_dataset/images/5583_0019.png
#   inflating: conv_512_r1_dataset/images/19569_0010.png
#   inflating: conv_512_r1_dataset/images/2174_0025.png
#   inflating: conv_512_r1_dataset/images/29143_0021.png
#   inflating: conv_512_r1_dataset/images/29424_0008.png
#   inflating: conv_512_r1_dataset/images/8222_0011.png
#   inflating: conv_512_r1_dataset/images/31290_0002.png
#   inflating: conv_512_r1_dataset/images/16728_0015.png
#   inflating: conv_512_r1_dataset/images/22310_0024.png
#   inflating: conv_512_r1_dataset/images/27587_0019.png
#   inflating: conv_512_r1_dataset/images/31727_0012.png
#   inflating: conv_512_r1_dataset/images/18401_0019.png
#   inflating: conv_512_r1_dataset/images/6722_0025.png
#   inflating: conv_512_r1_dataset/images/21321_0017.png
#   inflating: conv_512_r1_dataset/images/13507_0019.png
#   inflating: conv_512_r1_dataset/images/24222_0031.png
#   inflating: conv_512_r1_dataset/images/6121_0002.png
#   inflating: conv_512_r1_dataset/images/10703_0012.png
#   inflating: conv_512_r1_dataset/images/26174_0024.png
#   inflating: conv_512_r1_dataset/images/23760_0010.png
#   inflating: conv_512_r1_dataset/images/17422_0010.png
#   inflating: conv_512_r1_dataset/images/15706_0024.png
#   inflating: conv_512_r1_dataset/images/5932_0024.png
#   inflating: conv_512_r1_dataset/images/23760_0003.png
#   inflating: conv_512_r1_dataset/images/29820_0028.png
#   inflating: conv_512_r1_dataset/images/32412_0007.png
#   inflating: conv_512_r1_dataset/images/14396_0015.png
#   inflating: conv_512_r1_dataset/images/18422_0019.png
#   inflating: conv_512_r1_dataset/images/32009_0021.png
#   inflating: conv_512_r1_dataset/images/19179_0013.png
#   inflating: conv_512_r1_dataset/images/11629_0027.png
#   inflating: conv_512_r1_dataset/images/28126_0018.png
#   inflating: conv_512_r1_dataset/images/13260_0031.png
#   inflating: conv_512_r1_dataset/images/15860_0026.png
#   inflating: conv_512_r1_dataset/images/15787_0006.png
#   inflating: conv_512_r1_dataset/images/21021_0024.png
#   inflating: conv_512_r1_dataset/images/26664_0003.png
#   inflating: conv_512_r1_dataset/images/28429_0019.png
#   inflating: conv_512_r1_dataset/images/5086_0020.png
#   inflating: conv_512_r1_dataset/images/27232_0016.png
#   inflating: conv_512_r1_dataset/images/29307_0014.png
#   inflating: conv_512_r1_dataset/images/20794_0002.png
#   inflating: conv_512_r1_dataset/images/30294_0007.png
#   inflating: conv_512_r1_dataset/images/3959_0019.png
#   inflating: conv_512_r1_dataset/images/19084_0014.png
#   inflating: conv_512_r1_dataset/images/1184_0019.png
#   inflating: conv_512_r1_dataset/images/18422_0003.png
#   inflating: conv_512_r1_dataset/images/22718_0008.png
#   inflating: conv_512_r1_dataset/images/26101_0023.png
#   inflating: conv_512_r1_dataset/images/8151_0017.png
#   inflating: conv_512_r1_dataset/images/16890_0032.png
#   inflating: conv_512_r1_dataset/images/7706_0018.png
#   inflating: conv_512_r1_dataset/images/10611_0016.png
#   inflating: conv_512_r1_dataset/images/23243_0023.png
#   inflating: conv_512_r1_dataset/images/19084_0034.png
#   inflating: conv_512_r1_dataset/images/21155_0015.png
#   inflating: conv_512_r1_dataset/images/29307_0006.png
#   inflating: conv_512_r1_dataset/images/2943_0029.png
#   inflating: conv_512_r1_dataset/images/6611_0028.png
#   inflating: conv_512_r1_dataset/images/8450_0031.png
#   inflating: conv_512_r1_dataset/images/15706_0015.png
#   inflating: conv_512_r1_dataset/images/1690_0029.png
#   inflating: conv_512_r1_dataset/images/21129_0011.png
#   inflating: conv_512_r1_dataset/images/5287_0029.png
#   inflating: conv_512_r1_dataset/images/5099_0011.png
#   inflating: conv_512_r1_dataset/images/32126_0021.png
#   inflating: conv_512_r1_dataset/images/17422_0006.png
#   inflating: conv_512_r1_dataset/images/26101_0006.png
#   inflating: conv_512_r1_dataset/images/22741_0034.png
#   inflating: conv_512_r1_dataset/images/10892_0033.png
#   inflating: conv_512_r1_dataset/images/19179_0034.png
#   inflating: conv_512_r1_dataset/images/17143_0004.png
#   inflating: conv_512_r1_dataset/images/6121_0021.png
#   inflating: conv_512_r1_dataset/images/30080_0012.png
#   inflating: conv_512_r1_dataset/images/14396_0021.png
#   inflating: conv_512_r1_dataset/images/686_0007.png
#   inflating: conv_512_r1_dataset/images/27350_0032.png
#   inflating: conv_512_r1_dataset/images/30224_0022.png
#   inflating: conv_512_r1_dataset/images/2079_0020.png
#   inflating: conv_512_r1_dataset/images/30355_0020.png
#   inflating: conv_512_r1_dataset/images/23961_0008.png
#   inflating: conv_512_r1_dataset/images/10703_0032.png
#   inflating: conv_512_r1_dataset/images/686_0002.png
#   inflating: conv_512_r1_dataset/images/28657_0014.png
#   inflating: conv_512_r1_dataset/images/27587_0013.png
#   inflating: conv_512_r1_dataset/images/15192_0029.png
#   inflating: conv_512_r1_dataset/images/2447_0033.png
#   inflating: conv_512_r1_dataset/images/30394_0015.png
#   inflating: conv_512_r1_dataset/images/737_0013.png
#   inflating: conv_512_r1_dataset/images/16214_0014.png
#   inflating: conv_512_r1_dataset/images/31290_0031.png
#   inflating: conv_512_r1_dataset/images/24100_0018.png
#   inflating: conv_512_r1_dataset/images/29809_0017.png
#   inflating: conv_512_r1_dataset/images/5099_0010.png
#   inflating: conv_512_r1_dataset/images/26480_0020.png
#   inflating: conv_512_r1_dataset/images/18422_0007.png
#   inflating: conv_512_r1_dataset/images/15005_0017.png
#   inflating: conv_512_r1_dataset/images/2447_0017.png
#   inflating: conv_512_r1_dataset/images/29307_0007.png
#   inflating: conv_512_r1_dataset/images/32527_0013.png
#   inflating: conv_512_r1_dataset/images/30294_0015.png
#   inflating: conv_512_r1_dataset/images/15551_0001.png
#   inflating: conv_512_r1_dataset/images/9517_0021.png
#   inflating: conv_512_r1_dataset/images/22995_0008.png
#   inflating: conv_512_r1_dataset/images/4777_0004.png
#   inflating: conv_512_r1_dataset/images/144_0022.png
#   inflating: conv_512_r1_dataset/images/15842_0025.png
#   inflating: conv_512_r1_dataset/images/10611_0020.png
#   inflating: conv_512_r1_dataset/images/29610_0033.png
#   inflating: conv_512_r1_dataset/images/24100_0009.png
#   inflating: conv_512_r1_dataset/images/27350_0003.png
#   inflating: conv_512_r1_dataset/images/16728_0010.png
#   inflating: conv_512_r1_dataset/images/8876_0003.png
#   inflating: conv_512_r1_dataset/images/18422_0032.png
#   inflating: conv_512_r1_dataset/images/10392_0025.png
#   inflating: conv_512_r1_dataset/images/17828_0002.png
#   inflating: conv_512_r1_dataset/images/25945_0031.png
#   inflating: conv_512_r1_dataset/images/20831_0011.png
#   inflating: conv_512_r1_dataset/images/7359_0017.png
#   inflating: conv_512_r1_dataset/images/24833_0003.png
#   inflating: conv_512_r1_dataset/images/13189_0022.png
#   inflating: conv_512_r1_dataset/images/27298_0001.png
#   inflating: conv_512_r1_dataset/images/29223_0024.png
#   inflating: conv_512_r1_dataset/images/24100_0027.png
#   inflating: conv_512_r1_dataset/images/22995_0003.png
#   inflating: conv_512_r1_dataset/images/9407_0028.png
#   inflating: conv_512_r1_dataset/images/24194_0017.png
#   inflating: conv_512_r1_dataset/images/8638_0009.png
#   inflating: conv_512_r1_dataset/images/15499_0022.png
#   inflating: conv_512_r1_dataset/images/10912_0001.png
#   inflating: conv_512_r1_dataset/images/3959_0011.png
#   inflating: conv_512_r1_dataset/images/12174_0027.png
#   inflating: conv_512_r1_dataset/images/8116_0026.png
#   inflating: conv_512_r1_dataset/images/28748_0020.png
#   inflating: conv_512_r1_dataset/images/29820_0013.png
#   inflating: conv_512_r1_dataset/images/20428_0008.png
#   inflating: conv_512_r1_dataset/images/23009_0021.png
#   inflating: conv_512_r1_dataset/images/15499_0028.png
#   inflating: conv_512_r1_dataset/images/3057_0002.png
#   inflating: conv_512_r1_dataset/images/23959_0004.png
#   inflating: conv_512_r1_dataset/images/7902_0003.png
#   inflating: conv_512_r1_dataset/images/19997_0021.png
#   inflating: conv_512_r1_dataset/images/144_0008.png
#   inflating: conv_512_r1_dataset/images/26982_0032.png
#   inflating: conv_512_r1_dataset/images/10651_0029.png
#   inflating: conv_512_r1_dataset/images/28052_0023.png
#   inflating: conv_512_r1_dataset/images/4802_0020.png
#   inflating: conv_512_r1_dataset/images/1220_0027.png
#   inflating: conv_512_r1_dataset/images/7902_0007.png
#   inflating: conv_512_r1_dataset/images/30424_0029.png
#   inflating: conv_512_r1_dataset/images/6390_0025.png
#   inflating: conv_512_r1_dataset/images/29307_0018.png
#   inflating: conv_512_r1_dataset/images/21112_0029.png
#   inflating: conv_512_r1_dataset/images/23252_0017.png
#   inflating: conv_512_r1_dataset/images/29610_0011.png
#   inflating: conv_512_r1_dataset/images/7169_0008.png
#   inflating: conv_512_r1_dataset/images/31290_0019.png
#   inflating: conv_512_r1_dataset/images/15787_0001.png
#   inflating: conv_512_r1_dataset/images/27468_0012.png
#   inflating: conv_512_r1_dataset/images/30194_0011.png
#   inflating: conv_512_r1_dataset/images/12476_0007.png
#   inflating: conv_512_r1_dataset/images/22953_0017.png
#   inflating: conv_512_r1_dataset/images/28189_0021.png
#   inflating: conv_512_r1_dataset/images/26319_0034.png
#   inflating: conv_512_r1_dataset/images/15732_0020.png
#   inflating: conv_512_r1_dataset/images/15192_0017.png
#   inflating: conv_512_r1_dataset/images/30224_0018.png
#   inflating: conv_512_r1_dataset/images/10992_0033.png
#   inflating: conv_512_r1_dataset/images/4301_0009.png
#   inflating: conv_512_r1_dataset/images/27128_0016.png
#   inflating: conv_512_r1_dataset/images/435_0027.png
#   inflating: conv_512_r1_dataset/images/10044_0015.png
#   inflating: conv_512_r1_dataset/images/22133_0016.png
#   inflating: conv_512_r1_dataset/images/1500_0027.png
#   inflating: conv_512_r1_dataset/images/32151_0027.png
#   inflating: conv_512_r1_dataset/images/30424_0026.png
#   inflating: conv_512_r1_dataset/images/14183_0034.png
#   inflating: conv_512_r1_dataset/images/9470_0022.png
#   inflating: conv_512_r1_dataset/images/30414_0010.png
#   inflating: conv_512_r1_dataset/images/15551_0012.png
#   inflating: conv_512_r1_dataset/images/17828_0011.png
#   inflating: conv_512_r1_dataset/images/5287_0032.png
#   inflating: conv_512_r1_dataset/images/13507_0015.png
#   inflating: conv_512_r1_dataset/images/28791_0018.png
#   inflating: conv_512_r1_dataset/images/3959_0016.png
#   inflating: conv_512_r1_dataset/images/28262_0008.png
#   inflating: conv_512_r1_dataset/images/5102_0016.png
#   inflating: conv_512_r1_dataset/images/26664_0004.png
#   inflating: conv_512_r1_dataset/images/11497_0032.png
#   inflating: conv_512_r1_dataset/images/28189_0033.png
#   inflating: conv_512_r1_dataset/images/4639_0001.png
#   inflating: conv_512_r1_dataset/images/8388_0013.png
#   inflating: conv_512_r1_dataset/images/32325_0029.png
#   inflating: conv_512_r1_dataset/images/5932_0009.png
#   inflating: conv_512_r1_dataset/images/25945_0019.png
#   inflating: conv_512_r1_dataset/images/31406_0010.png
#   inflating: conv_512_r1_dataset/images/15005_0022.png
#   inflating: conv_512_r1_dataset/images/32151_0011.png
#   inflating: conv_512_r1_dataset/images/25641_0031.png
#   inflating: conv_512_r1_dataset/images/25641_0032.png
#   inflating: conv_512_r1_dataset/images/12784_0014.png
#   inflating: conv_512_r1_dataset/images/30084_0010.png
#   inflating: conv_512_r1_dataset/images/8842_0004.png
#   inflating: conv_512_r1_dataset/images/2500_0031.png
#   inflating: conv_512_r1_dataset/images/29820_0009.png
#   inflating: conv_512_r1_dataset/images/10610_0017.png
#   inflating: conv_512_r1_dataset/images/9791_0002.png
#   inflating: conv_512_r1_dataset/images/24100_0033.png
#   inflating: conv_512_r1_dataset/images/26174_0007.png
#   inflating: conv_512_r1_dataset/images/21812_0013.png
#   inflating: conv_512_r1_dataset/images/27232_0023.png
# ...
#   inflating: conv_512_r1_dataset/images/26982_0014.png
#   inflating: conv_512_r1_dataset/images/16609_0016.png
#   inflating: conv_512_r1_dataset/images/10892_0022.png
#   inflating: conv_512_r1_dataset/images/23665_0011.png
#   inflating: conv_512_r1_dataset/images/24522_0022.png
#   inflating: conv_512_r1_dataset/images/4265_0002.png
#   inflating: conv_512_r1_dataset/images/15329_0019.png
#   inflating: conv_512_r1_dataset/images/5317_0008.png
#   inflating: conv_512_r1_dataset/images/8450_0021.png
#   inflating: conv_512_r1_dataset/images/13189_0021.png
#   inflating: conv_512_r1_dataset/images/29180_0011.png
#   inflating: conv_512_r1_dataset/images/6807_0018.png
#   inflating: conv_512_r1_dataset/images/25430_0024.png
#   inflating: conv_512_r1_dataset/images/9777_0003.png
#   inflating: conv_512_r1_dataset/images/28823_0021.png
#   inflating: conv_512_r1_dataset/images/686_0008.png
#   inflating: conv_512_r1_dataset/images/24222_0011.png
#   inflating: conv_512_r1_dataset/images/28823_0003.png
#   inflating: conv_512_r1_dataset/images/20794_0016.png
#   inflating: conv_512_r1_dataset/images/15192_0025.png
#   inflating: conv_512_r1_dataset/images/23243_0002.png
#   inflating: conv_512_r1_dataset/images/30194_0017.png
#   inflating: conv_512_r1_dataset/images/15732_0028.png
#   inflating: conv_512_r1_dataset/images/29143_0002.png
#   inflating: conv_512_r1_dataset/images/4777_0009.png
#   inflating: conv_512_r1_dataset/images/4944_0004.png
#   inflating: conv_512_r1_dataset/images/23828_0011.png
#   inflating: conv_512_r1_dataset/images/25641_0013.png
#   inflating: conv_512_r1_dataset/images/31799_0024.png
#   inflating: conv_512_r1_dataset/images/10392_0018.png
#   inflating: conv_512_r1_dataset/images/1955_0034.png
#   inflating: conv_512_r1_dataset/images/24269_0021.png
#   inflating: conv_512_r1_dataset/images/30474_0024.png
#   inflating: conv_512_r1_dataset/images/28748_0003.png
#   inflating: conv_512_r1_dataset/images/14183_0025.png
#   inflating: conv_512_r1_dataset/images/16163_0034.png
#   inflating: conv_512_r1_dataset/images/2447_0010.png
#   inflating: conv_512_r1_dataset/images/29809_0018.png
#   inflating: conv_512_r1_dataset/images/22953_0032.png
#   inflating: conv_512_r1_dataset/images/20831_0026.png
#   inflating: conv_512_r1_dataset/images/20955_0025.png
#   inflating: conv_512_r1_dataset/images/9904_0021.png
#   inflating: conv_512_r1_dataset/images/32009_0001.png
#   inflating: conv_512_r1_dataset/images/9517_0034.png
#   inflating: conv_512_r1_dataset/images/8116_0019.png
#   inflating: conv_512_r1_dataset/images/30084_0020.png
#   inflating: conv_512_r1_dataset/images/30581_0006.png
#   inflating: conv_512_r1_dataset/images/3959_0013.png
#   inflating: conv_512_r1_dataset/images/164_0008.png
#   inflating: conv_512_r1_dataset/images/13189_0019.png
#   inflating: conv_512_r1_dataset/images/19533_0012.png
#   inflating: conv_512_r1_dataset/images/30394_0020.png
#   inflating: conv_512_r1_dataset/images/31709_0031.png
#   inflating: conv_512_r1_dataset/images/9517_0009.png
#   inflating: conv_512_r1_dataset/images/8402_0024.png
#   inflating: conv_512_r1_dataset/images/24222_0028.png
#   inflating: conv_512_r1_dataset/images/23640_0008.png
#   inflating: conv_512_r1_dataset/images/12827_0017.png
#   inflating: conv_512_r1_dataset/images/8894_0004.png
#   inflating: conv_512_r1_dataset/images/19360_0028.png
#   inflating: conv_512_r1_dataset/images/127_0008.png
#   inflating: conv_512_r1_dataset/images/15860_0032.png
#   inflating: conv_512_r1_dataset/images/30500_0027.png
#   inflating: conv_512_r1_dataset/images/17455_0021.png
#   inflating: conv_512_r1_dataset/images/4776_0025.png
#   inflating: conv_512_r1_dataset/images/31290_0023.png
#   inflating: conv_512_r1_dataset/images/24100_0024.png
#   inflating: conv_512_r1_dataset/images/30294_0028.png
#   inflating: conv_512_r1_dataset/images/15124_0032.png
#   inflating: conv_512_r1_dataset/images/21112_0018.png
#   inflating: conv_512_r1_dataset/images/31958_0009.png
#   inflating: conv_512_r1_dataset/images/5317_0009.png
#   inflating: conv_512_r1_dataset/images/11448_0008.png
#   inflating: conv_512_r1_dataset/images/1229_0016.png
#   inflating: conv_512_r1_dataset/images/6120_0001.png
#   inflating: conv_512_r1_dataset/images/4265_0003.png
#   inflating: conv_512_r1_dataset/images/15860_0018.png
#   inflating: conv_512_r1_dataset/images/12827_0025.png
#   inflating: conv_512_r1_dataset/images/20563_0022.png
#   inflating: conv_512_r1_dataset/images/4777_0034.png
#   inflating: conv_512_r1_dataset/images/9517_0003.png
#   inflating: conv_512_r1_dataset/images/16728_0033.png
#   inflating: conv_512_r1_dataset/images/27781_0027.png
#   inflating: conv_512_r1_dataset/images/28748_0013.png
#   inflating: conv_512_r1_dataset/images/25689_0028.png
#   inflating: conv_512_r1_dataset/images/27468_0010.png
#   inflating: conv_512_r1_dataset/images/14388_0008.png
#   inflating: conv_512_r1_dataset/images/15499_0034.png
#   inflating: conv_512_r1_dataset/images/9387_0029.png
#   inflating: conv_512_r1_dataset/images/3083_0012.png
#   inflating: conv_512_r1_dataset/images/25620_0021.png
#   inflating: conv_512_r1_dataset/images/30201_0011.png
#   inflating: conv_512_r1_dataset/images/4777_0003.png
#   inflating: conv_512_r1_dataset/images/9453_0016.png
#   inflating: conv_512_r1_dataset/images/203_0022.png
#   inflating: conv_512_r1_dataset/images/25620_0031.png
#   inflating: conv_512_r1_dataset/images/1690_0001.png
#   inflating: conv_512_r1_dataset/images/4639_0008.png
#   inflating: conv_512_r1_dataset/images/4777_0022.png
#   inflating: conv_512_r1_dataset/images/18449_0009.png
#   inflating: conv_512_r1_dataset/images/18401_0010.png
#   inflating: conv_512_r1_dataset/images/31727_0009.png
#   inflating: conv_512_r1_dataset/images/11645_0002.png
#   inflating: conv_512_r1_dataset/images/3959_0028.png
#   inflating: conv_512_r1_dataset/images/10611_0014.png
#   inflating: conv_512_r1_dataset/images/28748_0033.png
#   inflating: conv_512_r1_dataset/images/20302_0001.png
#   inflating: conv_512_r1_dataset/images/1220_0003.png
#   inflating: conv_512_r1_dataset/images/18445_0027.png
#   inflating: conv_512_r1_dataset/images/21155_0001.png
#   inflating: conv_512_r1_dataset/images/8876_0018.png
#   inflating: conv_512_r1_dataset/images/31698_0003.png
#   inflating: conv_512_r1_dataset/images/1157_0019.png
#   inflating: conv_512_r1_dataset/images/20563_0025.png
#   inflating: conv_512_r1_dataset/images/14396_0026.png
#   inflating: conv_512_r1_dataset/images/4412_0034.png
#   inflating: conv_512_r1_dataset/images/3054_0001.png
#   inflating: conv_512_r1_dataset/images/435_0003.png
#   inflating: conv_512_r1_dataset/images/6730_0011.png
#   inflating: conv_512_r1_dataset/images/15329_0024.png
#   inflating: conv_512_r1_dataset/images/7397_0019.png
#   inflating: conv_512_r1_dataset/images/27616_0018.png
#   inflating: conv_512_r1_dataset/images/2344_0032.png
#   inflating: conv_512_r1_dataset/images/31698_0002.png
#   inflating: conv_512_r1_dataset/images/23828_0001.png
#   inflating: conv_512_r1_dataset/images/30765_0021.png
#   inflating: conv_512_r1_dataset/images/14388_0034.png
#   inflating: conv_512_r1_dataset/images/20831_0016.png
#   inflating: conv_512_r1_dataset/images/11064_0003.png
#   inflating: conv_512_r1_dataset/images/11890_0015.png
#   inflating: conv_512_r1_dataset/images/29809_0021.png
#   inflating: conv_512_r1_dataset/images/17422_0032.png
#   inflating: conv_512_r1_dataset/images/7706_0034.png
#   inflating: conv_512_r1_dataset/images/6120_0017.png
#   inflating: conv_512_r1_dataset/images/3409_0007.png
#   inflating: conv_512_r1_dataset/images/16214_0018.png
#   inflating: conv_512_r1_dataset/images/30194_0026.png
#   inflating: conv_512_r1_dataset/images/9387_0004.png
#   inflating: conv_512_r1_dataset/images/16362_0032.png
#   inflating: conv_512_r1_dataset/images/16216_0012.png
#   inflating: conv_512_r1_dataset/images/1955_0010.png
#   inflating: conv_512_r1_dataset/images/31571_0007.png
#   inflating: conv_512_r1_dataset/images/5785_0032.png
#   inflating: conv_512_r1_dataset/images/30414_0026.png
#   inflating: conv_512_r1_dataset/images/29180_0031.png
#   inflating: conv_512_r1_dataset/images/20440_0020.png
#   inflating: conv_512_r1_dataset/images/3409_0013.png
#   inflating: conv_512_r1_dataset/images/30201_0029.png
#   inflating: conv_512_r1_dataset/images/13942_0031.png
#   inflating: conv_512_r1_dataset/images/3959_0029.png
#   inflating: conv_512_r1_dataset/images/12026_0013.png
#   inflating: conv_512_r1_dataset/images/11064_0013.png
#   inflating: conv_512_r1_dataset/images/5287_0023.png
#   inflating: conv_512_r1_dataset/images/4265_0011.png
#   inflating: conv_512_r1_dataset/images/23243_0026.png
#   inflating: conv_512_r1_dataset/images/28823_0002.png
#   inflating: conv_512_r1_dataset/images/16659_0009.png
#   inflating: conv_512_r1_dataset/images/351_0023.png
#   inflating: conv_512_r1_dataset/images/4776_0023.png
#   inflating: conv_512_r1_dataset/images/11629_0010.png
#   inflating: conv_512_r1_dataset/images/20247_0013.png
#   inflating: conv_512_r1_dataset/images/928_0016.png
#   inflating: conv_512_r1_dataset/images/4561_0026.png
#   inflating: conv_512_r1_dataset/images/203_0025.png
#   inflating: conv_512_r1_dataset/images/26480_0027.png
#   inflating: conv_512_r1_dataset/images/14756_0004.png
#   inflating: conv_512_r1_dataset/images/12827_0019.png
#   inflating: conv_512_r1_dataset/images/5932_0031.png
#   inflating: conv_512_r1_dataset/images/6807_0007.png
#   inflating: conv_512_r1_dataset/images/2279_0015.png
#   inflating: conv_512_r1_dataset/images/8638_0032.png
#   inflating: conv_512_r1_dataset/images/3303_0001.png
#   inflating: conv_512_r1_dataset/images/29610_0013.png
#   inflating: conv_512_r1_dataset/images/13189_0029.png
#   inflating: conv_512_r1_dataset/images/29809_0009.png
#   inflating: conv_512_r1_dataset/images/20428_0009.png
#   inflating: conv_512_r1_dataset/images/23640_0015.png
#   inflating: conv_512_r1_dataset/images/21358_0009.png
#   inflating: conv_512_r1_dataset/images/24269_0025.png
#   inflating: conv_512_r1_dataset/images/62_0021.png
#   inflating: conv_512_r1_dataset/images/15551_0008.png
#   inflating: conv_512_r1_dataset/images/21129_0006.png
#   inflating: conv_512_r1_dataset/images/27471_0031.png
#   inflating: conv_512_r1_dataset/images/20831_0029.png
#   inflating: conv_512_r1_dataset/images/18792_0026.png
#   inflating: conv_512_r1_dataset/images/12483_0008.png
#   inflating: conv_512_r1_dataset/images/8752_0008.png
#   inflating: conv_512_r1_dataset/images/1157_0008.png
#   inflating: conv_512_r1_dataset/images/6807_0003.png
#   inflating: conv_512_r1_dataset/images/4404_0010.png
#   inflating: conv_512_r1_dataset/images/15124_0009.png
#   inflating: conv_512_r1_dataset/images/18121_0017.png
#   inflating: conv_512_r1_dataset/images/9450_0016.png
#   inflating: conv_512_r1_dataset/images/24522_0016.png
#   inflating: conv_512_r1_dataset/images/30500_0007.png
#   inflating: conv_512_r1_dataset/images/12784_0004.png
#   inflating: conv_512_r1_dataset/images/27861_0003.png
#   inflating: conv_512_r1_dataset/images/30581_0031.png
#   inflating: conv_512_r1_dataset/images/30250_0004.png
#   inflating: conv_512_r1_dataset/images/30876_0011.png
#   inflating: conv_512_r1_dataset/images/8227_0013.png
#   inflating: conv_512_r1_dataset/images/8151_0014.png
#   inflating: conv_512_r1_dataset/images/28429_0007.png
#   inflating: conv_512_r1_dataset/images/5086_0026.png
#   inflating: conv_512_r1_dataset/images/16216_0004.png
#   inflating: conv_512_r1_dataset/images/13507_0032.png
#   inflating: conv_512_r1_dataset/images/660_0025.png
#   inflating: conv_512_r1_dataset/images/23665_0012.png
#   inflating: conv_512_r1_dataset/images/13189_0009.png
#   inflating: conv_512_r1_dataset/images/9358_0031.png
#   inflating: conv_512_r1_dataset/images/2943_0010.png
#   inflating: conv_512_r1_dataset/images/9777_0020.png
#   inflating: conv_512_r1_dataset/images/21195_0031.png
#   inflating: conv_512_r1_dataset/images/16214_0034.png
#   inflating: conv_512_r1_dataset/images/13189_0010.png
#   inflating: conv_512_r1_dataset/images/23959_0024.png
#   inflating: conv_512_r1_dataset/images/28436_0012.png
#   inflating: conv_512_r1_dataset/images/2344_0020.png
#   inflating: conv_512_r1_dataset/images/14407_0003.png
#   inflating: conv_512_r1_dataset/images/14756_0018.png
#   inflating: conv_512_r1_dataset/images/18900_0002.png
#   inflating: conv_512_r1_dataset/images/19997_0002.png
#   inflating: conv_512_r1_dataset/images/28963_0019.png
#   inflating: conv_512_r1_dataset/images/28436_0025.png
#   inflating: conv_512_r1_dataset/images/7970_0015.png
#   inflating: conv_512_r1_dataset/images/5287_0024.png
#   inflating: conv_512_r1_dataset/images/28318_0003.png
#   inflating: conv_512_r1_dataset/images/10666_0009.png
#   inflating: conv_512_r1_dataset/images/8876_0012.png
#   inflating: conv_512_r1_dataset/images/9445_0024.png
#   inflating: conv_512_r1_dataset/images/16163_0020.png
#   inflating: conv_512_r1_dataset/images/13189_0023.png
#   inflating: conv_512_r1_dataset/images/351_0018.png
#   inflating: conv_512_r1_dataset/images/5102_0003.png
#   inflating: conv_512_r1_dataset/images/20440_0022.png
#   inflating: conv_512_r1_dataset/images/14407_0013.png
#   inflating: conv_512_r1_dataset/images/6021_0026.png
#   inflating: conv_512_r1_dataset/images/20428_0029.png
#   inflating: conv_512_r1_dataset/images/27587_0015.png
#   inflating: conv_512_r1_dataset/images/4062_0017.png
#   inflating: conv_512_r1_dataset/images/4658_0017.png
#   inflating: conv_512_r1_dataset/images/12827_0033.png
#   inflating: conv_512_r1_dataset/images/30394_0033.png
#   inflating: conv_512_r1_dataset/images/12452_0026.png
#   inflating: conv_512_r1_dataset/images/27128_0021.png
#   inflating: conv_512_r1_dataset/images/9769_0003.png
#   inflating: conv_512_r1_dataset/images/7902_0033.png
#   inflating: conv_512_r1_dataset/images/1850_0003.png
#   inflating: conv_512_r1_dataset/images/9437_0034.png
#   inflating: conv_512_r1_dataset/images/9453_0026.png
#   inflating: conv_512_r1_dataset/images/30294_0026.png
#   inflating: conv_512_r1_dataset/images/19377_0024.png
#   inflating: conv_512_r1_dataset/images/6794_0027.png
#   inflating: conv_512_r1_dataset/images/16216_0022.png
#   inflating: conv_512_r1_dataset/images/22059_0026.png
#   inflating: conv_512_r1_dataset/images/30201_0026.png
#   inflating: conv_512_r1_dataset/images/23009_0019.png
#   inflating: conv_512_r1_dataset/images/22310_0026.png
#   inflating: conv_512_r1_dataset/images/4412_0033.png
#   inflating: conv_512_r1_dataset/images/30355_0023.png
#   inflating: conv_512_r1_dataset/images/7902_0019.png
#   inflating: conv_512_r1_dataset/images/15842_0028.png
#   inflating: conv_512_r1_dataset/images/29296_0011.png
#   inflating: conv_512_r1_dataset/images/20440_0033.png
#   inflating: conv_512_r1_dataset/images/30080_0019.png
#   inflating: conv_512_r1_dataset/images/14388_0020.png
#   inflating: conv_512_r1_dataset/images/25620_0011.png
#   inflating: conv_512_r1_dataset/images/27616_0024.png
#   inflating: conv_512_r1_dataset/images/29223_0012.png
#   inflating: conv_512_r1_dataset/images/9437_0032.png
#   inflating: conv_512_r1_dataset/images/17126_0020.png
#   inflating: conv_512_r1_dataset/images/12476_0015.png
#   inflating: conv_512_r1_dataset/images/16214_0027.png
#   inflating: conv_512_r1_dataset/images/28791_0019.png
#   inflating: conv_512_r1_dataset/images/3054_0019.png
#   inflating: conv_512_r1_dataset/images/20794_0015.png
#   inflating: conv_512_r1_dataset/images/10992_0007.png
#   inflating: conv_512_r1_dataset/images/21021_0004.png
#   inflating: conv_512_r1_dataset/images/21086_0012.png
#   inflating: conv_512_r1_dataset/images/6611_0015.png
#   inflating: conv_512_r1_dataset/images/27471_0026.png
#   inflating: conv_512_r1_dataset/images/22133_0010.png

# %%
# train csv
# !gdown 1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# To: /content/train.csv
# 100% 16.4M/16.4M [00:00<00:00, 169MB/s]

# %%
# b0 ~ b7
# !gdown 1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# !unzip ./encoder.zip -d ./encoder
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Sn2pPVCUz2dpzHB935ai-CU9UmTZDyxp
# To: /content/encoder.zip
# 100% 720M/720M [00:08<00:00, 84.8MB/s]
# Archive:  ./encoder.zip
#   inflating: ./encoder/efficientnet-b0-08094119.pth
#   inflating: ./encoder/efficientnet-b1-dbc7070a.pth
#   inflating: ./encoder/efficientnet-b2-27687264.pth
#   inflating: ./encoder/efficientnet-b3-c8376fa2.pth
#   inflating: ./encoder/efficientnet-b4-e116e8b3.pth
#   inflating: ./encoder/efficientnet-b5-586e6cc6.pth
#   inflating: ./encoder/efficientnet-b6-c76e70fd.pth
#   inflating: ./encoder/efficientnet-b7-dcc49843.pth

# %% [markdown]
# # Import

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision.all import *
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import os
import cv2
import gc
import random
from albumentations import *
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from lovasz import lovasz_hinge
import rasterio
from rasterio.windows import Window
from tqdm.notebook import tqdm

from PIL import Image
import tifffile as tiff

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Parameter & Etc..

# %%
dataset_name = 'conv_origin_512_r2_binary_dataset'
head_epochs = 5
full_epochs = 30
lr_max = 0.5e-2
lr_slice = slice(2e-4,2e-3)
bs = 8
nfolds = 4
fold = 0
SEED = 2020
TRAIN = '/content/conv_512_r1_dataset/images'
MASKS = '/content/conv_512_r1_dataset/masks'
LABELS = './train.csv'
NUM_WORKERS = 4
mean = np.array([0.77330088, 0.7439894, 0.76476664])
std = np.array([0.22989798, 0.2464437, 0.24098049])

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    #the following line gives ~10% speedup
    #but may lead to some stochasticity in the results 
    torch.backends.cudnn.benchmark = True
    
seed_everything(SEED)

# %% [markdown]
# # Data preprocessing

# %%
# # https://www.kaggle.com/iafoss/256x256-images
# mean = np.array([0.65459856,0.48386562,0.69428385])
# std = np.array([0.15167958,0.23584107,0.13146145])


# https://www.kaggle.com/datasets/thedevastator/hubmap-2022-256x256
def img2tensor(img,dtype:np.dtype=np.float32):
    if img.ndim==2 : img = np.expand_dims(img,2)
    img = np.transpose(img,(2,0,1))
    return torch.from_numpy(img.astype(dtype, copy=False))



class HuBMAPDataset(Dataset):
    def __init__(self, fold=fold, train=True, tfms=None):
        ids = pd.read_csv(LABELS).id.astype(str).values
        kf = KFold(n_splits=nfolds,random_state=SEED,shuffle=True)
        ids = set(ids[list(kf.split(ids))[fold][0 if train else 1]])
        self.fnames = [fname for fname in os.listdir(TRAIN) if fname.split('_')[0] in ids]
        self.train = train
        self.tfms = tfms
        
    def __len__(self):
        return len(self.fnames)
    
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.cvtColor(cv2.imread(os.path.join(TRAIN,fname)), cv2.COLOR_BGR2RGB)
        mask = cv2.imread(os.path.join(MASKS,fname),cv2.IMREAD_GRAYSCALE)
        if self.tfms is not None:
            augmented = self.tfms(image=img,mask=mask)
            img,mask = augmented['image'],augmented['mask']
        return img2tensor((img/255.0 - mean)/std),img2tensor(mask)
    


# version 1 0.65 version
def get_aug(p=1.0):
    return Compose([
        HorizontalFlip(p=0.5),
        VerticalFlip(),
        # GridDropout(ratio=0.4),
        RandomRotate90(p=1),
        #Morphology
        ShiftScaleRotate(shift_limit=0, scale_limit=(-0.2,0.2), rotate_limit=(-30,30), 
                         interpolation=1, border_mode=0, value=(0,0,0), p=0.5),
        GaussNoise(var_limit=(0,50.0), mean=0, p=0.5),
        GaussianBlur(blur_limit=(3,7), p=0.5),
        #Color
        RandomBrightnessContrast(brightness_limit=0.35, contrast_limit=0.5, 
                                 brightness_by_max=True,p=0.5),
        HueSaturationValue(hue_shift_limit=30, sat_shift_limit=30, 
                           val_shift_limit=0, p=0.5),
        OneOf([
            OpticalDistortion(p=0.3),
            GridDistortion(p=.1),
            IAAPiecewiseAffine(p=0.3),
        ], p=0.3),
    ], p=p)

# %%
#example of train images with masks
ds = HuBMAPDataset()
dl = DataLoader(ds,batch_size=8,shuffle=False,num_workers=NUM_WORKERS)
imgs,masks = next(iter(dl))

plt.figure(figsize=(16,16))
for i,(img,mask) in enumerate(zip(imgs,masks)):
    img = ((img.permute(1,2,0)*std + mean)*255.0).numpy().astype(np.uint8)
    plt.subplot(8,8,i+1)
    plt.imshow(img,vmin=0,vmax=255)
    plt.imshow(mask.squeeze().numpy(), alpha=0.2)
    plt.axis('off')
    plt.subplots_adjust(wspace=None, hspace=None)
    
del ds,dl,imgs,masks

# %% [markdown]
# # Model - EfficientUnet

# %%
class FPN(nn.Module):
    def __init__(self, input_channels:list, output_channels:list):
        super().__init__()
        self.convs = nn.ModuleList(
            [nn.Sequential(nn.Conv2d(in_ch, out_ch*2, kernel_size=3, padding=1),
             nn.ReLU(inplace=True), nn.BatchNorm2d(out_ch*2),
             nn.Conv2d(out_ch*2, out_ch, kernel_size=3, padding=1))
            for in_ch, out_ch in zip(input_channels, output_channels)])
        
    def forward(self, xs:list, last_layer):
        hcs = [F.interpolate(c(x),scale_factor=2**(len(self.convs)-i),mode='bilinear') 
               for i,(c,x) in enumerate(zip(self.convs, xs))]
        hcs.append(last_layer)
        return torch.cat(hcs, dim=1)

class UnetBlock(Module):
    def __init__(self, up_in_c:int, x_in_c:int, nf:int=None, blur:bool=False,
                 self_attention:bool=False, **kwargs):
        super().__init__()
        self.shuf = PixelShuffle_ICNR(up_in_c, up_in_c//2, blur=blur, **kwargs)
        self.bn = nn.BatchNorm2d(x_in_c)
        ni = up_in_c//2 + x_in_c
        nf = nf if nf is not None else max(up_in_c//2,32)
        self.conv1 = ConvLayer(ni, nf, norm_type=None, **kwargs)
        self.conv2 = ConvLayer(nf, nf, norm_type=None,
            xtra=SelfAttention(nf) if self_attention else None, **kwargs)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, up_in:Tensor, left_in:Tensor) -> Tensor:
        s = left_in
        up_out = self.shuf(up_in)
        cat_x = self.relu(torch.cat([up_out, self.bn(s)], dim=1))
        return self.conv2(self.conv1(cat_x))
        
class _ASPPModule(nn.Module):
    def __init__(self, inplanes, planes, kernel_size, padding, dilation, groups=1):
        super().__init__()
        self.atrous_conv = nn.Conv2d(inplanes, planes, kernel_size=kernel_size,
                stride=1, padding=padding, dilation=dilation, bias=False, groups=groups)
        self.bn = nn.BatchNorm2d(planes)
        self.relu = nn.ReLU()

        self._init_weight()

    def forward(self, x):
        x = self.atrous_conv(x)
        x = self.bn(x)

        return self.relu(x)

    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

class ASPP(nn.Module):
    def __init__(self, inplanes=512, mid_c=256, dilations=[6, 12, 18, 24], out_c=None):
        super().__init__()
        self.aspps = [_ASPPModule(inplanes, mid_c, 1, padding=0, dilation=1)] + \
            [_ASPPModule(inplanes, mid_c, 3, padding=d, dilation=d,groups=4) for d in dilations]
        self.aspps = nn.ModuleList(self.aspps)
        self.global_pool = nn.Sequential(nn.AdaptiveMaxPool2d((1, 1)),
                        nn.Conv2d(inplanes, mid_c, 1, stride=1, bias=False),
                        nn.BatchNorm2d(mid_c), nn.ReLU())
        out_c = out_c if out_c is not None else mid_c
        self.out_conv = nn.Sequential(nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False),
                                    nn.BatchNorm2d(out_c), nn.ReLU(inplace=True))
        self.conv1 = nn.Conv2d(mid_c*(2+len(dilations)), out_c, 1, bias=False)
        self._init_weight()

    def forward(self, x):
        x0 = self.global_pool(x)
        xs = [aspp(x) for aspp in self.aspps]
        x0 = F.interpolate(x0, size=xs[0].size()[2:], mode='bilinear', align_corners=True)
        x = torch.cat([x0] + xs, dim=1)
        return self.out_conv(x)
    
    def _init_weight(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                torch.nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

# %%
pretrained_root = './encoder/'
efficient_net_encoders = {
    "efficientnet-b0": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (3, 5, 9, 16),
        "weight_path": pretrained_root + "efficientnet-b0-08094119.pth"
    },
    "efficientnet-b1": {
        "out_channels": (3, 32, 24, 40, 112, 320),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b1-dbc7070a.pth"
    },
    "efficientnet-b2": {
        "out_channels": (3, 32, 24, 48, 120, 352),
        "stage_idxs": (5, 8, 16, 23),
        "weight_path": pretrained_root + "efficientnet-b2-27687264.pth"
    },
    "efficientnet-b3": {
        "out_channels": (3, 40, 32, 48, 136, 384),
        "stage_idxs": (5, 8, 18, 26),
        "weight_path": pretrained_root + "efficientnet-b3-c8376fa2.pth"
    },
    "efficientnet-b4": {
        "out_channels": (3, 48, 32, 56, 160, 448),
        "stage_idxs": (6, 10, 22, 32),
        "weight_path": pretrained_root + "efficientnet-b4-e116e8b3.pth"
    },
    "efficientnet-b5": {
        "out_channels": (3, 48, 40, 64, 176, 512),
        "stage_idxs": (8, 13, 27, 39),
        "weight_path": pretrained_root + "efficientnet-b5-586e6cc6.pth"
    },
    "efficientnet-b6": {
        "out_channels": (3, 56, 40, 72, 200, 576),
        "stage_idxs": (9, 15, 31, 45),
        "weight_path": pretrained_root + "efficientnet-b6-c76e70fd.pth"
    },
    "efficientnet-b7": {
        "out_channels": (3, 64, 48, 80, 224, 640),
        "stage_idxs": (11, 18, 38, 55),
        "weight_path": pretrained_root + "efficientnet-b7-dcc49843.pth"
    }
}

# %%
import sys
# sys.path.insert(0, '../input/efficientnet-pytorch/EfficientNet-PyTorch/EfficientNet-PyTorch-master')

from efficientnet_pytorch import EfficientNet
from efficientnet_pytorch.utils import url_map, url_map_advprop, get_model_params


class EfficientNetEncoder(EfficientNet):
    def __init__(self, stage_idxs, out_channels, model_name, depth=5):

        blocks_args, global_params = get_model_params(model_name, override_params=None)
        super().__init__(blocks_args, global_params)
        
        cfg = efficient_net_encoders[model_name]

        self._stage_idxs = stage_idxs
        self._out_channels = out_channels
        self._depth = depth
        self._in_channels = 3

        del self._fc
        self.load_state_dict(torch.load(cfg['weight_path']))

    def get_stages(self):
        return [
            nn.Identity(),
            nn.Sequential(self._conv_stem, self._bn0, self._swish),
            self._blocks[:self._stage_idxs[0]],
            self._blocks[self._stage_idxs[0]:self._stage_idxs[1]],
            self._blocks[self._stage_idxs[1]:self._stage_idxs[2]],
            self._blocks[self._stage_idxs[2]:],
        ]

    def forward(self, x):
        stages = self.get_stages()

        block_number = 0.
        drop_connect_rate = self._global_params.drop_connect_rate

        features = []
        for i in range(self._depth + 1):

            # Identity and Sequential stages
            if i < 2:
                x = stages[i](x)

            # Block stages need drop_connect rate
            else:
                for module in stages[i]:
                    drop_connect = drop_connect_rate * block_number / len(self._blocks)
                    block_number += 1.
                    x = module(x, drop_connect)

            features.append(x)

        return features

    def load_state_dict(self, state_dict, **kwargs):
        state_dict.pop("_fc.bias")
        state_dict.pop("_fc.weight")
        super().load_state_dict(state_dict, **kwargs)  
        

class EffUnet(nn.Module):
    def __init__(self, model_name, stride=1):
        super().__init__()
        
        cfg = efficient_net_encoders[model_name]
        stage_idxs = cfg['stage_idxs']
        out_channels = cfg['out_channels']
        
        self.encoder = EfficientNetEncoder(stage_idxs, out_channels, model_name)

        #aspp with customized dilatations
        self.aspp = ASPP(out_channels[-1], 256, out_c=384, 
                         dilations=[stride*1, stride*2, stride*3, stride*4])
        # self.drop_aspp = nn.Dropout2d(0.5)
        #decoder
        self.dec4 = UnetBlock(384, out_channels[-2], 256)
        self.dec3 = UnetBlock(256, out_channels[-3], 128)
        self.dec2 = UnetBlock(128, out_channels[-4], 64)
        self.dec1 = UnetBlock(64, out_channels[-5], 32)
        self.fpn = FPN([384, 256, 128, 64], [16]*4)
        # self.drop = nn.Dropout2d(0.1)
        self.final_conv = ConvLayer(32+16*4, 1, ks=1, norm_type=None, act_cls=None)
        
    def forward(self, x):
        enc0, enc1, enc2, enc3, enc4 = self.encoder(x)[-5:]
        enc5 = self.aspp(enc4)
        # dec3 = self.dec4(self.drop_aspp(enc5), enc3)
        dec3 = self.dec4(enc5, enc3)
        dec2 = self.dec3(dec3,enc2)
        dec1 = self.dec2(dec2,enc1)
        dec0 = self.dec1(dec1,enc0)
        x = self.fpn([enc5, dec3, dec2, dec1], dec0)
        # x = self.final_conv(self.drop(x))
        x = self.final_conv(x)
        x = F.interpolate(x,scale_factor=2,mode='bilinear')
        return x
    
#split the model to encoder and decoder for fast.ai
split_layers = lambda m: [
                list(m.encoder.parameters()),
                list(m.aspp.parameters())+list(m.dec4.parameters())+
                list(m.dec3.parameters())+list(m.dec2.parameters())+
                list(m.dec1.parameters())+list(m.fpn.parameters())+
                list(m.final_conv.parameters())
            ]

# %% [markdown]
# # Loss & Metrics

# %%
def symmetric_lovasz(outputs, targets):
    return 0.5*(lovasz_hinge(outputs, targets) + lovasz_hinge(-outputs, 1.0 - targets))

# %%
class Dice_soft(Metric):
    def __init__(self, axis=1): 
        self.axis = axis 
    def reset(self): self.inter,self.union = 0,0
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        self.inter += (pred*targ).float().sum().item()
        self.union += (pred+targ).float().sum().item()
    @property
    def value(self): return 2.0 * self.inter/self.union if self.union > 0 else None
    
# dice with automatic threshold selection
class Dice_th(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.05), axis=1): 
        self.axis = axis
        self.ths = ths
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self, learn):
        pred,targ = flatten_check(torch.sigmoid(learn.pred), learn.y)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 
                2.0*self.inter/self.union, torch.zeros_like(self.union))
        return dices.max()

# %% [markdown]
# # Model evaluation

# %%
#iterator like wrapper that returns predicted and gt masks
class Model_pred:
    def __init__(self, model, dl, tta:bool=True, half:bool=False):
        self.model = model
        self.dl = dl
        self.tta = tta
        self.half = half
        
    def __iter__(self):
        self.model.eval()
        name_list = self.dl.dataset.fnames
        count=0
        with torch.no_grad():
            for x,y in iter(self.dl):
                x = x.cuda()
                if self.half: x = x.half()
                p = self.model(x)
                py = torch.sigmoid(p).detach()
                if self.tta:
                    #x,y,xy flips as TTA
                    flips = [[-1],[-2],[-2,-1]]
                    for f in flips:
                        p = self.model(torch.flip(x,f))
                        p = torch.flip(p,f)
                        py += torch.sigmoid(p).detach()
                    py /= (1+len(flips))
                if y is not None and len(y.shape)==4 and py.shape != y.shape:
                    py = F.upsample(py, size=(y.shape[-2],y.shape[-1]), mode="bilinear")
                py = py.permute(0,2,3,1).float().cpu()
                batch_size = len(py)
                for i in range(batch_size):
                    taget = y[i].detach().cpu() if y is not None else None
                    yield py[i],taget,name_list[count]
                    count += 1
                    
    def __len__(self):
        return len(self.dl.dataset)
    
class Dice_th_pred(Metric):
    def __init__(self, ths=np.arange(0.1,0.9,0.01), axis=1): 
        self.axis = axis
        self.ths = ths
        self.reset()
        
    def reset(self): 
        self.inter = torch.zeros(len(self.ths))
        self.union = torch.zeros(len(self.ths))
        
    def accumulate(self,p,t):
        pred,targ = flatten_check(p, t)
        for i,th in enumerate(self.ths):
            p = (pred > th).float()
            self.inter[i] += (p*targ).float().sum().item()
            self.union[i] += (p+targ).float().sum().item()

    @property
    def value(self):
        dices = torch.where(self.union > 0.0, 2.0*self.inter/self.union, 
                            torch.zeros_like(self.union))
        return dices
    
def save_img(data,name,out):
    data = data.float().cpu().numpy()
    img = cv2.imencode('.png',(data*255).astype(np.uint8))[1]
    out.writestr(name, img)

# %% [markdown]
# # Train

# %%
# ## callbacks - early stopping, save model
# cbs=[EarlyStoppingCallback(monitor='valid_loss', min_delta=0, patience=5),
#      SaveModelCallback(monitor='dice_th',comp=np.greater)]

# %%
dice = Dice_th_pred(np.arange(0.2,0.7,0.01))
for fold in range(1):
    # ds_t = HuBMAPDataset(fold=fold, train=True, tfms=get_aug())
    ds_t = HuBMAPDataset(fold=fold, train=True)
    ds_v = HuBMAPDataset(fold=fold, train=False)
    data = ImageDataLoaders.from_dsets(ds_t,ds_v,bs=bs,
                num_workers=NUM_WORKERS,pin_memory=True).cuda()
    model = EffUnet('efficientnet-b4').cuda()
    learn = Learner(data, model, loss_func=symmetric_lovasz,
                metrics=[Dice_soft(),Dice_th()], 
                splitter=split_layers,
                cbs=WandbCallback())
    # .to_fp16(clip=0.5)
    
    #start with training the head
    learn.freeze_to(-1) #doesn't work
    for param in learn.opt.param_groups[0]['params']:
        param.requires_grad = False
    learn.fit_one_cycle(head_epochs, lr_max=lr_max)

    #continue training full model
    learn.unfreeze()
    learn.fit_one_cycle(full_epochs, lr_max=lr_slice,
        # cbs=SaveModelCallback(monitor='valid_loss',comp=np.less))
        cbs=SaveModelCallback(monitor='dice_th',comp=np.greater))
    torch.save(learn.model.state_dict(),f'model_{fold}.pth')
    
    #model evaluation on val and saving the masks
    mp = Model_pred(learn.model,learn.dls.loaders[1])
    with zipfile.ZipFile('val_masks_tta.zip', 'a') as out:
        for p in progress_bar(mp):
            dice.accumulate(p[0],p[1])
            save_img(p[0],p[2],out)
    gc.collect()
# Out:
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'HuBMAPDataset' object has no attribute 'items'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.320648</td>
#       <td>1.342720</td>
#       <td>0.325123</td>
#       <td>0.529412</td>
#       <td>07:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.185069</td>
#       <td>1.176018</td>
#       <td>0.534916</td>
#       <td>0.662774</td>
#       <td>06:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.959999</td>
#       <td>1.031544</td>
#       <td>0.601040</td>
#       <td>0.722611</td>
#       <td>06:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.991116</td>
#       <td>0.990733</td>
#       <td>0.608748</td>
#       <td>0.739011</td>
#       <td>06:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.935284</td>
#       <td>0.986328</td>
#       <td>0.633095</td>
#       <td>0.737764</td>
#       <td>06:59</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice_soft</th>
#       <th>dice_th</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.865595</td>
#       <td>0.944033</td>
#       <td>0.653862</td>
#       <td>0.761084</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.827982</td>
#       <td>0.926002</td>
#       <td>0.680511</td>
#       <td>0.769142</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.794498</td>
#       <td>0.879420</td>
#       <td>0.724747</td>
#       <td>0.796745</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.796262</td>
#       <td>0.856243</td>
#       <td>0.710978</td>
#       <td>0.805345</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.687163</td>
#       <td>0.884510</td>
#       <td>0.718207</td>
#       <td>0.804221</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.697700</td>
#       <td>0.835278</td>
#       <td>0.727452</td>
#       <td>0.808505</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.604725</td>
#       <td>0.799081</td>
#       <td>0.773915</td>
#       <td>0.825715</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.568185</td>
#       <td>0.814322</td>
#       <td>0.763673</td>
#       <td>0.834793</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.494834</td>
#       <td>0.892553</td>
#       <td>0.714168</td>
#       <td>0.761796</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.472240</td>
#       <td>0.878942</td>
#       <td>0.801052</td>
#       <td>0.828427</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.427237</td>
#       <td>0.841156</td>
#       <td>0.809516</td>
#       <td>0.842801</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.395006</td>
#       <td>0.882835</td>
#       <td>0.804415</td>
#       <td>0.832903</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.393922</td>
#       <td>0.906986</td>
#       <td>0.813176</td>
#       <td>0.845924</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.332894</td>
#       <td>0.954712</td>
#       <td>0.821382</td>
#       <td>0.843208</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.310822</td>
#       <td>0.944408</td>
#       <td>0.828293</td>
#       <td>0.847240</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.298429</td>
#       <td>0.939269</td>
#       <td>0.838671</td>
#       <td>0.853105</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.282194</td>
#       <td>0.986913</td>
#       <td>0.824650</td>
#       <td>0.843390</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.273395</td>
#       <td>0.969673</td>
#       <td>0.830863</td>
#       <td>0.845925</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.270199</td>
#       <td>0.985282</td>
#       <td>0.835122</td>
#       <td>0.846641</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.222325</td>
#       <td>1.050705</td>
#       <td>0.835845</td>
#       <td>0.848248</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.198241</td>
#       <td>1.072044</td>
#       <td>0.841742</td>
#       <td>0.852314</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.196758</td>
#       <td>1.058420</td>
#       <td>0.837852</td>
#       <td>0.849878</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.220431</td>
#       <td>1.076283</td>
#       <td>0.838805</td>
#       <td>0.848414</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.174977</td>
#       <td>1.105145</td>
#       <td>0.845687</td>
#       <td>0.853609</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.146718</td>
#       <td>1.178982</td>
#       <td>0.844056</td>
#       <td>0.853178</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.164215</td>
#       <td>1.165675</td>
#       <td>0.845390</td>
#       <td>0.854181</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.153252</td>
#       <td>1.195234</td>
#       <td>0.847314</td>
#       <td>0.854911</td>
#       <td>14:57</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.145383</td>
#       <td>1.199664</td>
#       <td>0.846840</td>
#       <td>0.854710</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.150620</td>
#       <td>1.209842</td>
#       <td>0.847551</td>
#       <td>0.854982</td>
#       <td>14:58</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.143131</td>
#       <td>1.201805</td>
#       <td>0.847626</td>
#       <td>0.854946</td>
#       <td>14:58</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with dice_th value: 0.7610841989517212.
# Better model found at epoch 1 with dice_th value: 0.7691423296928406.
# Better model found at epoch 2 with dice_th value: 0.7967445254325867.
# Better model found at epoch 3 with dice_th value: 0.805345356464386.
# Better model found at epoch 5 with dice_th value: 0.8085053563117981.
# Better model found at epoch 6 with dice_th value: 0.8257148265838623.
# Better model found at epoch 7 with dice_th value: 0.8347925543785095.
# Better model found at epoch 10 with dice_th value: 0.8428009152412415.
# Better model found at epoch 12 with dice_th value: 0.8459242582321167.
# Better model found at epoch 14 with dice_th value: 0.8472396731376648.
# Better model found at epoch 15 with dice_th value: 0.8531050086021423.
# Better model found at epoch 23 with dice_th value: 0.8536087274551392.
# Better model found at epoch 25 with dice_th value: 0.854180634021759.
# Better model found at epoch 26 with dice_th value: 0.8549113869667053.
# Better model found at epoch 28 with dice_th value: 0.8549822568893433.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3447' class='' max='3447' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3447/3447 10:00&lt;00:00]
#     </div>

# %%
dices = dice.value
noise_ths = dice.ths
best_dice = dices.max()
best_thr = noise_ths[dices.argmax()]
plt.figure(figsize=(8,4))
plt.plot(noise_ths, dices, color='blue')
plt.vlines(x=best_thr, ymin=dices.min(), ymax=dices.max(), colors='black')
d = dices.max() - dices.min()
plt.text(noise_ths[-1]-0.1, best_dice-0.1*d, f'DICE = {best_dice:.3f}', fontsize=12);
plt.text(noise_ths[-1]-0.1, best_dice-0.2*d, f'TH = {best_thr:.3f}', fontsize=12);
plt.show()

# %%
# !mkdir effib4_conv_origin_512_r1_binary_weigth
# !mv ./model_0.pth ./effib4_conv_origin_512_r1_binary_weigth
# !mv ./model_1.pth ./conv_orginal_512_bin_b1_weigth
# !mv ./model_2.pth ./conv_orginal_512_bin_b1_weigth
# !mv ./model_3.pth ./conv_orginal_512_bin_b1_weigth

# %%
# !zip /content/drive/MyDrive/data/kaggle/main_test/effib4_conv_origin_512_r1_binary_weigth.zip -r ./effib4_conv_origin_512_r1_binary_weigth
# Out:
#   adding: effib4_conv_origin_512_r1_binary_weigth/ (stored 0%)
#   adding: effib4_conv_origin_512_r1_binary_weigth/model_0.pth (deflated 7%)
